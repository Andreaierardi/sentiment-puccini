# %% [markdown]
# <a href="https://colab.research.google.com/github/Andreaierardi/sentiment-puccini/blob/main/archivio_ricordi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Archivio Ricordi models**
#
# <br>
# <br>

# %% [markdown]
# ### Dataset
# Provided by the Ricordi Archive [link](https://www.digitalarchivioricordi.com/it/people/display/2/Giacomo%20Puccini)
#
# Evalita 2016 Sentipolc [link](http://www.di.unito.it/~tutreeb/sentipolc-evalita16/index.html)
#
#
# <br>
# <br>
#
# ---

# %% [markdown]
# <br>
# <br>
#
# # Data Retrieval
#
# <br>

# %%
from os import path
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
#stopwords.words('italian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
letters_df_na = pd.read_excel('https://github.com/Andreaierardi/sentiment-puccini/raw/main/dataset/lettere%20di%20Puccini.xlsx')

# %%
letters_df = letters_df_na.dropna()

# %%
letters_df = letters_df.rename(columns={'tabTrascrLettere_lettere::testoTab': "text"})
letters_list = [let for let in letters_df['text']]

# %%
letters_list
# Out:
# ['Maestro Verdi\nBusseto\nSento e comprendo suo grande dolore\nPuccini ',
#  "Caro Blanc,\n\nUn'altra noja - Siccome si avvicina il S. Michele e per conseguenza lo sgombero e cambiamento di domicilio, ti prego passare dal mio padrone di casa Sig Luigi Peregrini Via Solferino ventisette (27) - al quale ho scritto che rimarrei nella sua casa a patto che mi diminuisse l'affitto da 500 a 450 -  Io non ho avuto ancora risposta e il tempo stringe, se detto padrone non acconsente la riduzione chiestagli ti prego provvedere a 1/2 Gervasini per il trasloco dal 27 Solferino al 5° Luciano Manara - Ne parlai anche al comm: Giulio e siamo d'accordo per la cessione di un giorno del prelodato illustre Gervasini. Il sig. Peregrini abita in Via Solferino 27- ma ha lo studio in via S. Calimero dopo la chiesa - non ricordo il numero - sarebbe necessario che tu ci parlassi in persona tu stesso medesimo e perorassi riduzione affitto - Lapidami maledicimi ma sii gentile favorirmi e gratissimo mi avrai\nTanti saluti al Sig. Giulio\nSig. Eugenio e a te \nil tuo aff.\nG. Puccini\nTorre del Lago\n22 7mbre 91",
#  "Gentilissimo Sig Giulio\n\nMadrid 8.3.92\n\nGrazie del finale 3° -                                                                                                                                                                    Non si andrà in scena che verso il 15 o forse giovedì dell'altra settimana Si va adagio in un modo che pare incredibile - Sono contento assai delle poche prove che fin adesso abbiamo fatto - Le scene di Bussato sono molto belle -\nLa Pasqua si è accomodata ma ciò che non è in ordine è la voce che è di una stanchezza incredibile - Tamagno va benissimo, ma so che ha messo la condizione all'impresa di fargli fare due recite di più se no, non canta Edgar - Creda che tutti questi su e giù mi hanno molto scoraggiato e avvilito basta speriamo che tutto vada bene - I cori son discreti e l'orchestra idem - fanno niente di più che le note non hanno forza - par che suonino, e cantino tutti sotto il palco!! - Ieri è uscito un giornale, La Corrispondencia, dicendo ira dei del libretto e questo è molto male essendo detto giornale molto letto - Serrano il maestro mi fa una crociata atroce contro e così mi dicono anche Breton = \nLe spine ci devono esser sempre! - \nSperiamo in dio! \ne lassa che la vaga!.\nGrazie dei telegrammi di Torino - bramerei aver dei particolari \nMille saluti a tutta la sua famiglia e al Sig Tornaghi =                                                    \na Lei un'infinità \ndal tutto suo\naff G Puccini",
#  'Caro Blanc,                                                                                                                                           Hamburg 25-11-92\n\nSto benissimo - Prove vanno idem - 29 corrente prima recita - Orchestra buonissima cantanti discreti - donnet minga il diavol! - freddo Kane - Tedeschi orsi - Non capisco un H - Gran mimica - E francese di mia invenzione - Questo è quanto Avvicinandosi poi fine mese pregoti rimettere solita mensilità ai miei sottoposti - Addio saluti al Sig Tornaghi tuo aff\nG Puccini',
#  "Caro Blanc\n\nT'avverto che ho preso un bicicletto! ma pagabile a rate mensili - Verrà da te l'amministratore della Ditta A. Schlegel Foro Bonaparte 36 - e tu gli pagherai mio conto £70 come prima rata e gli altri mesi £50 - salvo poi a saldarlo completamente alla mia venuta a Milano in ottobre. Pregoti di questo favore.\nIo sto bene e lavoro - e gli affari come vanno? per Verona ho accettato la Sthele perché Carignani dice che fa Manon benissimo-\nBolcioni per Lucca ha scritturato per il tenorino il Mazzanti e per il comico Borelli io non li conosco, dimmi tu subito cosa valgono\nLui e dice gran bene ma diffido - io volevo Daddi e Carbonetti.\nRaccomandoti di star addosso al Bolcioni per le scene, che non succeda come a Trento che erano orribili. \nSaluto il Sor Giulio e i Sig Tornaghi\ntanto cose dal tuo\n\n\n\n//Torre del Lago\nMercoledi\n18 (?).7.93\naff Puccini",
#  "                                                                                                                                                        Torre del lago 7.9.94\n                                                                                                                                                                                                                                                                                      Gentilissimo Sig Giulio\nAvrà visto l'Illica = \nAdesso attendo le accorciature e la revisione di Giacosa (che ci vuole assolutamente anche per l'unità del lavoro e poi sotto forma più pensata il libretto acquista etc etc) Ora il lavoro originale c'è! e come! L'ultimo atto è bellissimo - Il Quartiere anche ma difficilissimo ho fatto togliere quel saltimbanco - bisognerà sfrondare dell'altro -                                                                                                                                                                       Sarebbe bene che anche lei gli desse una letta - per purgarlo di certe bizzarrie di cui non ce n'è proprio bisogno - Per es.: Il cavallo è il re degli animali = i fiumi son vini fatti d'acqua e molte altre alle quali Illica tiene come ai propri figli (se ne avesse) -\nQuello che bisogna ridurre e molto ... è il 2° atto barriera - \ntutta quella roba a principio è inutile e siamo d'accordo di restringerla e così anche il resto e il quartetto finale questo però è l'atto debole - questo è il mio parere - sbaglierò! meglio per me - Ma quello che mi par riuscitissimo e l'ultimo - la morte e tutto ciò che la precede commuovono veramente.\nFummo felici della notizia della signora Ginetta preghiamo Lei di salutarla tanto da parte di tutti noi - Così pure saluterà la signora Giuditta e Sig Cricri Tito Manolo Gigino et - Non mi rispose a quanto gli scrissi circa il Caselli, si vede che ha creduto di più alle calunniose e schifose informazioni d'altri che alle mie. Pazienza - Avanti sempre chi meno se lo merita - Mille saluti cordiali e in attesa del quartiere Latino riveduto accorciato e corretto con intervento del Budda giacosiano, mi dico tutto suo affezionatissimo \nG. Puccini.",
#  "//13-11-94\n//Puccini\nall'Ill\\mo/ Sig Comm Giulio Ricordi\nVia Omenoni 1\nMilano\nA.D. MDCCCXCIV\nOraculum loquit!\n       _._._\nJacobus Puccinius capitem reliquit in sestierem latinum - Parvam partem sed bonam fecit. Ita dicit auctor. Editor sed, ad tempum suum, publicus judicium dabit - Sepe, caput in Mures aut in cembalum cum magno ictu darebit. Erga Mediolanum passum suum volgebit circum finem calende Novembris.\nVale - Viro - Probo\nAmen",
#  "Gentilissimo sg Giulio\nMartedì Mattina alle 10 sarò nel suo studio.\nL'irritazione di Illica mi sorprende e la trovo strana. Quando venne qua si restò perfettamente d'accordo - e sapeva della Lupa - e deplorava non facessi la Bohème e che sarebbe sempre stato pronto a secondarmi in tutto - ora che ritorno a lui si diverte a darsi delle arie - e se poi dice che l'ho messa da parte la colpa di chi è? bastava che il lavoro fosse quale deve essere e cioè logico, stringato, interessante e equilibrato. \nMa niente per ora di tutto questo - Io devo ad occhi chiusi accettare il Vangelo d'Illica? clisteri non mi se ne piantano, sono abbastanza pronto per ricaderci. Per Boheme la vedo ma col quartiere latino come dissi l'ultima volta che conferii con Illica = colle scene di Musette che trovai io: e la morte la voglio come l'ho ideata io e son sicuro allora di fare un lavoro originale e vitale. In quanto alle barriere son sempre del mio parere che mi piace poco - trovo un atto dove di musicale c'è poco: solo la commedia corre ma non è assai.\nAvrei desiderato qualche elemento melodrammatico non bisogna dimenticare di più che della commedia ne abbiamo tante degli altri atti. In quelle lì, desideravo un canevaccio che mi facesse musicare un pò più liricamente .....\nBasta il sig Illica si calmi e si lavorerà: ma voglio anch'io dir la mia all'occorrenza e non farmi salir sulle spalle da nessuno.\nIntanto la saluto carissimamente e a rivederci a martedì\ntutto suo aff Puccini\n",
#  'Carissimo sig Giulio\nTrovo giustissima la sua lettera in tutto e per tutto ma c\'è un ma\n\ndevo finire o no questo atto? lo devo finire a Milano? la mia presenza è così necessaria costi? or che farci?\ni metronomi posso metterli qui = mandarmi un metronomo a 1/2 pacco postale e una copia di tutto ciò che è inciso e io lo scrivo subito. di caccia non me ne occupo nè tanto nè poco - solo quando viene rarissimamente Ginori faccio una passeggiata di 1/2 giornata e tutto è lì - sempre o quasi al tavolino - ora strumento e a giorni le spedisco qualche fascicolo - della composizione sono a buonissimo punto e sono contentone - mi è costata un po\' di fatica per volermi attenere alla realtà e poi per liricizzare un pò tutti questi spezzatini. E ci sono riuscito - perché voglio che si canti, si melodizzi più che si può.\nL\'atto è composto quasi tutto di ritorni logici salvo il duettino "sono andati" e la zimarra  di Colline e poco altro. mi pare d\'avere trovato per il duettino un buon principio e la frase culminante è efficace benché non troppo nuova -  ma bisogno poi non sottilizzare tanto - non è vero?\ndunque concludendo, mi lasci quà tranquillo a bevermi di questo splendido sole e a bearmi di questo paese incantevole.\nAppena messa la parola Fine volo a Milano e spero sarà verso i primi di dicembre - \nMi parla di Manon al dalverme io ritengo che la Mendioroz benché freddina sarebbe una ottima Manon - questa è la mia opinione giustificata da prova avendola avuta a Lucca e a Bologna poi adesso vedo che è tanto nelle simpatie del pubblico - per la buona Desdemona. Mugnone son contento che sia a Napoli se si fa Bohème.\nTanti saluti a tutti e in attesa del metronomo La saluta, con tutti noi, carissimamente il suo aff\nG Puccini',
#  "Carissimo sor Giulio\nHo finalmente trovato quel tal Puccini dell'asioli! ma sarà affare che si accinga a studiar musica? si metterà al mondo uno spartito di più?\nconvien riflettere - mi aggiunse che spedì 3 o 4 giorni fa un pacco raccomandato di solfeggi Toscani con accompagnamento di timpani coi sordini scritti a mano volante in caratteri gotici - detto Puccini trovasi in angustie per la non accusata recepzione - sarebbe bene tranquillizzarlo perchè caso mai il pacco si fosse perduto non gli resta che ricorrere per l'indennizzo delle 15 lire che dà la posta. Chi sa che questo possa essere un buon affare? riflettiamoci.\nCaso mai trovassi per strada un certo sig Burgmein compositore natalizio gli trasmetta i cordiali saluti del Puccini e gli dica che spera di vederlo presto-\nIntanto mi è grato dirmi di Lei\naff e devot\nabb\\mo/ devoné\nOmocaig Iniccup\n\nTorredelLago\n-Mercoledì-\n22.5.99\n\n//E di Giacosa?",
#  "Carissimo Sig. Giulio\n\nLa sua lettera mi ha fatto una sorpresa straordinaria!! ne sono ancora impressionato - Pur non di meno sono sereno e convinto che se Ella ripassa questo 3°atto la sua opinione si cambia! Non è orgoglio il mio, no. E' la convinzione di aver colorito come meglio non potevo il dramma che mi stava dinnanzi - Sa Lei come io sia scrupoloso nell'interpretare le situazioni e le parole e quanto vagli prima di buttar giù - L'appunto per aver preso un frammento d'Edgar può criticarsi da Lei, e dai pochi che lo possono riconoscere può sembrare un schivar fatica qualunque - Così come è (togliendosi dall'idea che appartiene ad altro lavoro) (4° atto Edgar abolito) mi sembra pieno di quella poesia che emana dalle parole oh di questo ne sono sicuro e si convincerà quando lo sentirà a posto e cioè sulla scena - Quanto alla frammentarietà, è cosa voluta da me: non può essere una situazione uniforme e tranquilla come in altre confabulazioni d'amore. Ritorna sempre la preoccupazione di Tosca la ben simulata caduta di Mario e relativo suo contegno davanti ai fucilatori suoi - Quanto alla fine duetto (il cosidetto inno latino) (che non ho mai avuto il bene di vederlo scritto dai poeti) i miei dubbi ce li ho anch'io - ma spero che in teatro venga fuori e magari bene. II duetto del 3° è stato sempre il gran scoglio - I poeti non mi hanno saputo dare (parlo della fine) niente di buono - e di vero soprattutto - sempre accademia accademia e solite sbrodolature amorose - Ho dovuto arangiarmi per arrivare alla fine                                                                                                                                                                  senza troppo seccare gli uditori evitando qualunque accademia -\nMugnone che più volte ha sentito questo 3° atto cantato da me ne è entusiasta da preferirlo al 4° di Boheme. Amici e quelli di casa mia ne hanno provato impressione ottima\nio per le esperienze che ho e posso avere, non ne sono scontento. - \nNon so davvero spiegare questa sua deleteria impressione - Prima di accingermi a rifare (e ci sarebbe il tempo?) farò una corsa a Milano e parleremo noi due soli col piano e musica davanti a noi - e se la sua impressione persiste cercheremo da buoni amici il modo di salvarci - come - dice Scarpia - \nRipeto che non è orgoglio il mio - è solo una difesa per un lavoro che ho pensato e che mi è costato tanto pensiero - Lo riscontro sempre più nel mio caro papà Giulio un sentimento grande di delicatezza e un affetto che (può star certo) è ricambiato a forti dosi - E la ringrazio per l'interesse che ha per me e che ha sempre avuto dal giorno che ebbi la fortuna d'incontrarlo - Dissento da Lei per questo 3° atto: sarà la prima volta che non ci troviamo d'accordo - Però io spero e arrivo a dirle sono sicuro, che Ella si ricrederà - vedremo!\nOggi viene Toscanini da me - e forse ripartirò con lui domani o l'altro. Gli telegraferò -\nHo sempre per le mani il preludio che mi costa fatica, ma che verrà - A Milano non potrò restare che poco dovendo ritornare al lavoro e a Firenze (domenica) per i tamtam.\nCaro Sig. Giulio la saluto\ncon tutto l'affetto mio\ne ansioso di vederla \npresto \nmi dico suo \naff G Puccini\nTorre del Lago 11 ott. 99",
#  "                                                                                                                                                                     27. nov. 902\nCarissimo Sig. Giulio\n\nIllica, appena io lo chiamai, venne - è da tre giorni qui, tutto intento al lavoro che viene benone pensa manomettere gran cosa del vecchio libretto. \nAnche lui è convinto di questa nuova forma d'opera che io ho voluto fare, e spero alla mia venuta a Milano di convincere anche lei - Non passa ora che il nostro signor Giulio sia rammentato da noi L'assicuro che Illica è tale e quale d'una volta e i suoi sentimenti sono i più affettuosi verso di lei - Solo deplora che la proposta di collaborazione sia sarà fatta dal Sig Giulio e non da Franchetti - e di questo proprio anch'io dò ragione a Illica, perchè dopo il successo di Germania mi sembra che Franchetti non doveva né tanto meno lei, proporre questa cosa a Illica - del resto come vede non sono cose irrimediabili nè gravi -  I pettegolezzi che ne nascono, le dicerie etc bisogna non tenerne conto - il mondo è così falso e maligno! \nIo dunque da mia parte faccio tutti gli auguri e prego anche le parti di ritornare alle stagioni fiorite così piene d'entusiasmo collaboratore d'un tempo. \nLe rimetto 3 fotografie ma sono brutte - \nHo dato ordine di farne altre più complete e migliori.\nCon tutti i saluti \nmiei e d'Illica suo \naff G Puccini",
#  "Carissimo Sig Giulio\n\nIllica parte oggi (domenica) -\nII lavoro è finito e ne siamo contenti anzi contentoni - è riuscito splendidamente fila via dritto e logico che è un piacere - ah! quell'atto al Consolato era una vera rovina! Sto strumentando l'atto I°- e presto verrò a Milano e spero che anche Lei si convincerà che il lavoro così come è stato fatto è più efficace -\nLe mando ancora due fotografie\nTanti saluti \ncordialissimi\ndal suo\nG Puccini",
#  "Mio carissimo Illica\nGiovedì\n\nSon due giorni che sono fra cielo e terra per una flussione di denti che mi ha sfigurato e tormentato - oggi sto un po' meglio - sono con poco dolore e posso scriverti. Ebbi le polemiche. interessante quella di Fèval - La risposta di Sardou è fiacca - Finalmente il Sig Giulio mi ha scritto una lettera lunga - una vera requisitoria! ma non persuasiva né conforme al vero - e... un po' poco generosa verso una persona... - Senza le prove non si accusa cosi - ma le suggestioni e i racconti l'hanno fatto giudicare troppo duramente - anche riguardo al mio male non è nel vero - Vorrei rispondergli ma ora con questo mio male ai denti non ho la testa adatta a farlo - potessi parlarci!. dalla lettera però rifulge come sole l'affetto che ha per me e di questa ne sono rimasto tanto consolato - tu sai quanto abbia sofferto del suo silenzio verso di me! era una vera croce! Vorrei però poterci parlare - non sono un confutatore io - specie per lettera. - Lui è poi poi uomo di mondo e certi giudizi assoluti verrebbero modificati s'io potessi parlarci e fanno male quando non sono corredati di vero o di prove e lasciano l'animo o perplesso o ribelle - Vorrei poter scrivere come l'animo mi dice sopra un argomento che anche tu non vuoi sentire... - mah! Quello che veramente mi attrista è il trovarmi qui coi miei pensieri senza una persona cui dire tutto quello che attraversa l'animo mio! \nHo il piano a coda venuto da Pisa - Lo vedi il Sig Giulio? quando verrà a vedermi? Ho fissato con Guarneri che da oggi a 8 (giovedi) sfascierà la gamba insieme al Prof Ceci della clinica di Pisa - Si consulteranno sul da farsi - Qui tempo orribile -\nIeri non mi alzai mai - oggi, vedremo - Son gonfio - sembro un mostro! Tu vedessi che guancia!                                                                                                         Non c'è stato verso di sapere se la Tosca a Parigi è messa da parte o rimessa all'autunno, vuoi scrivere tu e sapermelo dire? Dice che nella settimana entrante verranno Tito e Giacosa col lavoro finito.",
#  "Caro Illica\n\nScrivimi spesso. Sono qui cosi solo e triste! tu sapessi le sofferenze mie! avrei tanto bisogno d'un amico e non ne ho o se c'è qualcuno che mi vuol bene non mi capisce - Sono un temperamento molto diverso da tanti! Solo io mi comprendo e mi addoloro - ma è continuo dolore il mio - non mi dà pace - anche il lavoro non mi solleva e lavoro perchè devo - La mia vita è un mare di tristezza e mi ci fisso! mi sembra di non essere amato da nessuno capisci da nessuno - e dire che tanti mi dicono un uomo invidiabile! Come sono stato generato male! ma anche tu non entri nell'animo mio come vorrei - e forse neppure mi compatisci! Vorrei parlarti e sfogarmi con te! Ma sei così lontano e poi certo sentire i lai non è divertente - \nah se tu facessi una scappata qui - Siamo soli - Vieni colla  Sig Rachele - stacci qualche giorno -                                                                                                             Come mi farebbe bene la vostra compagnia e la nostra amicizia si cementerebbe di più! mi dici di leggere? \nnon posso - Faccio 4 note perchè devo - e trascorro il mio tempo in un'atmosfera delle più nere -\nciao scrivimi\ne vogli bene\nal tuo\nG Puccini\n24.11.903\n",
#  'Caro Blanc\n                                                                                                                                                                                     pregoti comperarmi e farmi spedire Bruges la morte romanzo di Rodenbach - e Le Carillionneur del md.mo autore - Grazie             saluti a tutti \naff tuo \nG Puccini\n\nTorre del Lago\n4.4.904',
#  "                                        Venerdi mattina\nCaro Sig Giulio                        12.3.05\nPer quanto io non disconosca il valore e la grande efficacia di alcuni quadri di M. A. pure mi sento spaventato dalla mole di lavoro e ritengo che non sia possibile farne un'opera di proporzioni ordinarie - tutti i tagli, tutti gli accorciamenti non basteranno a rendere l'opera possibilmente musicabile cioè teatrabile. Io le scrivo con tutta coscienza e franchezza. So il dolore che le recherà questa mia lettera ma più dolore sarebbe se a lavoro iniziato tutti ci accorgessimo di quanto le ho detto. Scrivo ad Illica. Tutto suo aff G Puccini\n\nSig Comm. Giulio Ricordi \nI. G. M.",
#  "Caro sig Giulio          14.3.05\nCarignani le consegnerà tutto il rimanente d'Edgar e le dirà del lavoro accanito fatto in questo mese. Mi sembra che l'opera cosi com'è debba andare bene.\nCarignani ha lavorato come un negro e, mi pare, bene.\nVoglia incaricarlo di passare le parti ai cantanti - e ne ho anche scritto a d'ormeville - ma una sua parolina al prefato autore di dolce voluttà darà la leva - A rivederci presto.\nScrissi a Giacosa ma non ebbi risposta - ho voglia di far un'opera buffa - e la farei in poco tempo - facciamo ridere se si può questo musone di pubblico e ce ne sarà grato certamente\naffi saluti\nda Puccini",
#  "21.III.05                                                                                                                                                                      \n\nCarissimo Sig Giulio\n\nVolevo telegrafare per sapere sue notizie quando ricevo la sua carissima lettera - Per Edgar faccia pure tutto ciò che crede bene riguardo a scene libretto e messa in scena = \nMontecarlo? è tutto oro come si dice - io ci credo poco - è che Lui è nato fortunatissimo anche i fiaschi passati l'hanno tenuto in piedi - figurarsi se poi ne azzecca qualcuna di buona - Io facessi il Guglielmo Tell sarei sempre il bersaglio dei fulmini di tutti i critici italiani La povera Butterfly informi e con quale famelica rabbia ci si gettarono sopra! Basta urge trovare libretto o buffo o serio - ma mi ci vuole - così non va più!! e i miei poeti? ahimè!\nTutto suo G Puccini",
#  "                                                                                                                                                                          8.11.905                         Caro Sig Giulio\nHo letto Ramuntcho - ma purtroppo non ci ho trovato l'elemento per un'opera - Io non capisco come ci si possa pensare per farne un melodramma!  - \nE' una cosina tenue tenue - idilliaca - senza un finale drammatico né sensazionale. Ci può essere materia per un primo atto e le diverse fasi possono interessare e ben riuscire L'ambiente, il paesaggio i tipi l'amore fra i due, i giochi all'aperto (non certo la Pelota) il fandango, la lite fra le madri, i contrabbandi - la partenza del soldato etc - ma al 2° atto (3 anni dopo) non sono riuscito a capire cosa ci possa trovar di interessante per un dramma in musica - Per una commedia la fine potrebbe interessare ma per la lirica, no - Lo rilegga e vedrà che mi darà ragione. Qui piove sempre! prevedo che presto verrò a Milano - di Illica niente - gli scriverò - \nLa prego darmi notizie di Giacosa - Non le sto a dire la febbre che ho per non trovare da lavorare! Cosa si fa? io proprio non so più dove battere la testa! Speravo in questo Ramuntcho! Se ha da indicarmi qualche libro me lo scriva o mi mandi - \nda Londra mi scrive Pavone che tutto procede trionfalmente e a Bologna va sempre meglio -\nCostì come va?\nTanti saluti \naff suo \nG Puccini",
#  "14.12.05 \n                                                                                                                                                                                      Il malfattore girovago, \n\nda Siena, credo, scrivesse e inviasse dolci per tenere a bocca dolce il questore - Si ha notizia che un altro bandito che aggirasi per i castelli arcuati sia per infestare il territorio di Milano ai primi della settimana ventura = Allora la questura potrà fare doppio tiro - perchè il cosidetto doge non potrà fare a meno di unirsi all'altro detto il Piacentino - Mano ai ferri, alle torture, alle forche! Hanno idea di compiere un delitto regale nientedimeno di impiccare un Re e una Regina! Occhio!                                                                                                                                    per copia esatta G Puccini",
#  "Caro Sig Giulio\n\nChe sono tutti morti? Io di giorno in giorno, di ora in ora aspetto la chiamata per Nizza e il responso dei consoli (Tito e Praga) per l'affare d'Annunzio è tanto io che il vate siamo all'oscuro di ciò che si è per combinare o si è combinato - Spero che avrà scritto a Parigi per la Femme et le Pantin. di questo credo possa farsi una bella e buona cosa - ma piccola in compenso molto\ninteressante e viva - Io sto bene - E Lei?\nTanti affettuosi saluti \nda G Puccini\n1.3.06",
# ...
#  "14.7.23\n\nCaro Carlo\n\nmi mandi delle bozze di Fosca. Le aggiunte in rosso saranno quelle della Scala quando la diresse Toscanini? Vorrei saperlo.\n\nQuando mi mandate il mio conto semestrale? Fa caldo lavoro poco- ma l'opera procede canta e oso dire minga mal. Mi duole che l'aria Manon non sia stata incisa come fu eseguita alla Scala-!! cioè senza la perorazione. bisognerà ritornarci è questione poi poi d'una lastra da rifare.\n\nTanti buoni saluti a te a Renzo\n\naff tuo\n\nG. Puccini\n\nE' vero che vai a Pesaro?",
#  'GIACOMO PUCCINI\n\nVIAREGGIO\n\nCaro Claudio – sono stato 8 giorni a cutigliano a 700 metri ma anche lì il caldo era solenne – ritornato a Viareggio – me ne rivado – andrò o a st moritz o sulle dolomiti in auto con Tonio – qui non va – troppo calore – mi dispiace che il lavoro Turandottiano langue – riprenderò a inferno calmato. Ebbi il\xa0conto che fu abbastanza [cancellatura] lauto e me ne compiaccio anche per la casa. E tu stai a milano con questi caldi? E Renzo pure? Sarà un bel clima l’italico, io te lo regalo.\n\nÈ vero che il m° Pais sarà alla scala – così pure tuo figlio?\n\nSchalk mi scrive da Baires che a fine sett: monterà manon e réprise di trittico. e mi vuole a Vienna.\n\nForse ci farò una scappata per le prove ultime di manon.\n\nTanti saluti\xa0affettuosi a te\xa0a Renzo e\xa0a tutti i tuoi\xa0\xa0e suoi\n\nda\n\nG Puccini\n\n12.8.23',
#  "6.sett.1923\n\nCaro Carlo\nE' per domenica la prèmiere di Fanciulla\nSe puoi venire mi farai un piacere - credo sarà un'esecuzione molto efficace.\nIl fresco settembre è venuto e ora si vive. Turandot procede imperterrita verso la fine...che è ancor lontana.\nCiao saluti a te\na Renzo\ntuo Giacomo",
#  "12 Sett. 1923\n\nCaro Caludio\n\nti ringrazio per la medaglia. non è cosa da prendere tanto non dico sul serio ma così con pena. Basta una medaglia come quella che diedi alle bande d'Orbetello e che Gohgon [?] fece. Avranno in archivio il tipo. Sarà un concorsetto regionale. io credevo di più. dunque qualunque medaglia va bene.\n\nCredo che il prezzo che ho detto sia troppo per il concorso\xa0 non ricordo quanto costò quella di Orbetello (la grande) mi pare che te ne occupasti. era di queste dimensioni [disegno di un cerchio] press'a poco ma un pò alticcia d'oro [disegno di uno spessore] così.\n\nQui Fanciulla bene. ti farò qualche critica più quà. Il brano duetto aggiunto quando è bene eseguito fa effetto e fa scrosciare un riscaldante applauso all'atto. Però era sbagliato nel canto (forse per colpa mia non del copista) L'ho corretto e te lo spedisco con strappate alla fine invece di mandare l'orchestra col canto. Ciao saluti a te e Renzo\n\naff tuo\xa0\n\nG Puccini\n\nTanti auguri per la lombaggine\n\n[di traverso al foglio]\n\nSchalk mi scrive che m'aspetta a Vienna per i primi ottobre per ultime prove Manon.\n\n[in alto a destra della prima facciata] vado a Lucca dove c'è una Manon Tamplini a sistema vispissimo! Prego te di dire in copisteria di mandare le parti stampate canto con l'aria 4° atto. c'è nella partiturina ma non c'è negli spartiti.",
#  "22.9.1923\n\nCaro Claudio\n\nricevuto tuo telegr: grazie. Sono contento dell'impressione che ti ha fatto il I° atto di Turandot. Speriamo che il rimanente rinforzi.\n\nStasera vado a Lucca per Manon. Grandi feste. ma alle 2 sarò nel mio letto a Viareggio e la festajolata sarà finita. se dio vuole. Vuoi telegrafare a Vienna Schalk domandando quando veramente premiere? non arrivò mai il telegramma divino che tu mi preannunciasti. In cielo si è indifferenti per le cose del piccolo mondo.\n\nQui domani finisce Fanciulla.\n\nchi dirigerà a Torino? Ti domando questo perchè sul Giornale d'Italia leggo che si darà Fanciulla. Pare che Bavagnoli vada a Napoli. Se danno il Trittico ne sono molto contento.\n\nGrazie di nuovo delle tue 2 visite. Spero che starai bene adesso. auguri caso mai e saluti affsi dal tuo\n\nG. Puccini\n\nTanti saluti a Valcarenghi",
#  "Caro Carlo\n\nnon va bene per Redaelli perché esige i viaggi in più cioè 200 lire ed è giusto. e sette giorni di lavoro a 100 lire al giorno totale 900 lire. Per il tenore perché non prendiamo Alabiso che ha fatto così bene? e per direttore il Capuana che mi dicono è un bravo giovane e ottimo interprete di Fanciulla?\n\nRedaelli va a uscio per 10 giorni di cura. da Vienna ricevo telegr: anch'io. Prove ultime il 4. 5. 6. 8 Generale 10 premiere. Io sarò a Vienna il 4 o 5. Hotel Bristol. tu vieni?\n\nVa bene quanto mi dici per correzioni materiale Manon ed Edizione. Non ho altro a dirti per ora. Ti saluto e ti ringrazio per la tua premura.\n\naff tuo\n\nG. Puccini\n\n29.9.23\n\n",
#  'GIACOMO PUCCINI\n      VIAREGGIO\n        7.ott: 1923\nCaro Carlo\nParto per Vienna – \nLa premiere sarà il 15 corr. Ho guardato la partitura Turandot atto primo e l’ho trovata abbastanza corretta e ben copiata -\nInterrompo il mio lavoro e me ne duole – ma avevo promesso a Schalk d’andare a assistere alle prove di Manon e vado - Liù però è morta e morta bene –\nC’è il gran duo! Quello mi dà pensiero – ma verrà a suppurazione anche quello.\nSaluti a te a Renzo –\nSpero vederti a Vienna mi farà piacere – ben inteso se potrai – Adami che tu sappia ha finito la commedia per Ruggeri?\nSalutamelo tanto –\n        Ciao \n                Aff tuo\n                        G Puccini\n',
#  'Wien 4 nov.1923\n\nCaro Claudio, sono ancora qui. Ho Elvira che è in letto con la lombaggine! Spero domani (lunedì) partire. Io mi sono trattenuto per fare una cura per il mio diabete e i dottori (il prof. Falta\xa0uno specialista) mi ha tenuto a regime stretto poi graduatamente mi ha nutrito per stabilire quanto posso ingerire e così è stata una cosa piuttosto lunga e noiosa, 15 giorni nel coltage sanatorium! Poi è sopraggiunta la lombago a mi’ moglie e così ho dovuto prolungare il soggiorno. meno male che il tempo è stato bello.\n\nManon grande successo e anche ho avuto notizie che a Praga è andata benone. Ma sono indietro con Turandot! Con questa lunga assenza dal lavoro! Questo mi ange.\n\nRicevo teleg: da Roma per il concorso opere al ministero e devo trovarmici il 24 corr:\n\nTonio ti porterà 100 milioni di corone da parte del Kearl. E ti dirà il modo di tramutare o di ben fruttare Korone e marchi – Ho anche parlato per questo all’addetto commerciale alla legazione.\n\nScrivimi a Viareggio dove conto essere mercoledì sera.\n\nAbbraccioti\n\nCon Renzo\n\nTuo aff\n\nGPuccini\n\n[in un angolo, in basso a sinistra] P.S Presto a fine nov:, Schalk riprenderà il Trittico',
#  'VIAREGGIO 18.11.23\n\nVIA BUONARROTI\n\nCaro Carlo\n\nRicevo la tua lettera – grazie –\n\nIl regime di Vienna mi pare giovi – il mio diabete di 20 anni non mi dà glucosio da 15 giorni e questo è bene – se ho giudizio ne troverò certo grande giovamento e giudizio l’avrò. Per il Tabarro io non sono del tuo parere – con 35 orchestranti non si può rendere quello che ho pensato – e poi che bisogno ne ho? Fossi alle prime armi! Purtroppo i miei strali hanno la ruggine – non mi parrebbe dignitoso per un autore che dal 98 è nel repertorio d’un primo teatro di Parigi andare a finire in un trianon lirique per quanto sia questo teatro ben diretto come tu dici. Carré che a me deve tanto specie per sua moglie che se non c’era Butterfly e mimì poteva andare a soffiare nel vuoto. Ma io me ne accorsi l’anno scorso con schicchi –\n\nOrribile distribuzione salvo marcoux e promesse non mantenute di sostituzione d’artisti -\n\nE intanto ho visto sul Gaulois che riprendono lo schicchi colla solita distribuzione con aggravamento di Allard! E ancora la Carré come Butterfly!\n\nMandami lo spartito trittico che lo firmerò per il m°\xa0di Gand.\xa0Ti prego di far versare per mio conto Fcs \xa01000 al Banchiere Seligman (meyer Fils et Cie 45 Bd Haussman [)]: sono per la società dei concerts modernes rappresentata da Sark\xa0Richepin [?] e dal mo Albert Wolf- Firmai per un azione da 1000 franchi – Grazie –\n\nTurandot: ho mandato a Simoni il duetto perché lo rende più lui mi ha detto che lo farà con entusiasmo.\n\nSono andato avanti un po’ a passetti di lumachina – ma mi par bene – il 24 devo essere a Roma per la commissione altra interruzione di lavoro!\n\nCiao – Tonio parlò a Renzo dei marchi e corone ma rispose ... [scritto piccolo sotto i puntini] come io la penso cioè non rispose niente... e pure così si vedrebbe più chiaro e si avrebbe lucro.',
#  'Caro Carlo\nBuon Natale a te e tutti i tuoi.   //Tanti saluti e auguri a Valcarenghi\nTurandot marcia ma è lontana dalla fine – \nE’ un lavoro accurato e importante aspetto da Simoni il duetto che ho voluto far rifare per la 4° volta poiché mi pareva buono ma non ottimo – aspetto da tempo – speriamo che mi arrivi per proseguire nella composizione. Intanto sto strumentando il 2° atto.\nTi accludo una lettera da Marsiglia vedi cosa c’è di vero in queste specie di denunzie che indica lesioni e mi e ci colpiscono.\n//Tanti saluti aff tuo\n//Puccini',
#  '[Viareggio]\nCaro Carlo\nEccoti bozza stampa Tosca corretta.\nFin’ora Simoni non si è fatto vivo e ho arenato il lavoro di composizione – sto strumentando il 2° atto per non perder tempo.\nSpero venire a Milano per l’epoca neroniana.\nTanti saluti a te a Renzo aff.tuo\nG.Puccini\n\n1 febb=1924\n',
#  's.l., 4 marzo 1924 \n\nCaro Carlo\nTi prego di mandarmi una pianta del palco scenico della Scala che deve servire a Chini per le scene di Turandot. Ciao Tanti saluti G.Puccini\n\n\n\n',
#  'VIAREGGIO\nVIA  BUONARROTI\n\nCaro Carlo\nTi unisco la lettera al Gior: d’Italia. Mi pare che vada bene. Vedesti e sollecitasti Adami? cosa c’è di nuovo? informami anche se spiacevoli cose avrai da dirmi. Ormai sono corazzato dall’esperienza – affettuosamente \ntuo\n\t\t\t\t\t\t\t\t\t\tG. Puccini\n9. 7 . 24\n',
#  'Lunedi\n\n14.VII.24\n\nVIAREGGIO\n\nVIA BUONARROTI\n\nCaro Carlo\n\nAdami mi ha scritto che spediva ma per ora non ho veduto nulla.\xa0Per la Scala vedo e sento che non c’è nulla di serio né in via di concretare – forse neppure il desiderio?\n\nTi prego mandarmi il conto semestrale avendo bisogno dei denari per la carrozzeria di Tonio –\n\nE tu quando vai a Paris?\xa0Brunelleschi mi ha scritto e gli ho risposto che tu lo vedrai a Parigi. Scrissi a Chini per la collaborazione con Grandi - per ora non ne ho avuta risposta.\n\nAnche la Carelli ha riscritto per decidere per gli artisti ed io ho risposto evasivamente richiamandola alla mia lettera al G. d’Italia. T’ho informato di tutto – ti saluto tuo affmo\n\n\xa0GPuccini\n\nRenzo è tornato?',
#  "16.7.24\n\nCaro Carlo\n\nParlai con Chini. Non contrario a collaborare con Grandi. cerca di parlare a Grandi dunque e sentire che accorda.\n\nIo sarei molto contento di questa collaborazione. come t'ho detto scrissi in risposta a Brunelleschi dicendogli che tu lo vedresti presto a Paris anche a questo rinunzio malvolentieri. Son tutti i tre preziosi artisti!. Per ora niente arrivato duetto!! aff tuo\xa0\n\nGiacomo",
#  "19.7.24\n\nCaro Carlo\n\nRicevuto il cospicuo conto. Hall [sic] Right. Tante grazie e siasempre così per il bene mio e vostro. Ebbi i versi spero andranno bene. questo vedrò nel lavorare. temo che siano insufficienti per il finale ma mi arrangerò colle diverse versioni e poi al momento chiederò ad Adami l'aiuto finale.\n\nGajanus mi scrive domandandomi Turandot dopo Nerone!! Gli risponderò la solita frase: l'opera non è finita.\n\nTi accludo ricevuta debitamente firmata. e buon sollazzo a Parigi. Salutami tanto Renzo e a te tanti\n\nda G Puccini\n\n[di traverso sulla prima facciata] Quando vengono i piccoli diritti?",
#  "Viareggio, 4 agosto 1924\n\nCarissimo Claudio\nGrazie tua cartolina - non è contrario alle mie idee di quest’agosto chè io venga a Parigi – Se mai dopo il 10 partirei – forse con Tonio e in auto chiuso comodo per poi giricchiare sulla costa della Bretagna e in altre amene regioni di Francia -  Ma vorrei che tu fossi ancora costì verso il 15 – ci sarai? Potresti anche girovagare con noi se ti piacerà farlo – Visto Chini che è contento d’associarsi con Grandi – Spero tu abbia visto Brunelleschi - La Ceka mi perseguita! anche nella Paris-Scala vedo boicottate Manon uno dei migliori successi scaligeri! a me era era riservato questo dopo 30 anni di vita vittoriosa e di artista onesto! C'è la vipera dentro a tutto questo!\nCiao mio vecchio amico ti saluto caramente spero rivederti presto tuo Giacomo \n",
#  "2 ott. 1924\n\nCaro Carlo\n\nci hai pensato a Brunelleschi? Saprai che la Scala ha telegrafato a Gigli che ha risposto favorevolmente...ma per il maggio. ora hanno ritelegrafato per vedere d'averlo un mese prima. vedremo se si potrà combinare. Io sto al solito cioè non come a Milano ma coma stavo prima cioè non bene...alla mia gola e mi deciderò di andare a Losanna farmi vedere da un grande specialista.\n\nOra sfogliando Musica d'oggi leggo un pezzo di musica di un certo Rocca! un vero ridicolo morceaux kretinoski ma come si fa a fargli l'onore della pubblicazione? Ciao ti saluto caramente\n\nsaluti a Renzo\n\ntuo G. Puccini\n\nP.S. Niente da Simoni per ora. è un affare serio!",
#  "Viareggio, [5 ottobre 1924]\n\nCaro Carlo\nti prego di dire alla Sig.na Maria di mandarmi tutte le ricevute dell'esattoria di Viareggio degli anni 21-22-23- Ricevute di fabbricati - Ricchezza mobile - terreni - tassa esercizio etc= mi debbono servire per il Senato - E così di Brunelleschi? aspetto da Simoni .......ma comincio ad impensierirmi!\nVedi Adami? andò a Viggiù? Urge urge questo maledettissimo duetto!\nLa Mason mi telegrafa che è stata scelta per la Liù - cosa ne pensi? Voce buona - ma io ho sempre dubbi quando si tratta di rôles passionali, delle americane- Vedremo.\nE di Gigli sai se ha risposto che potrà essere alla piazza fine marzo? domandalo alla Scala.\nTanti saluti a te\na Renzo\ntuo\nGiacomo\nRaccomando a Zuccoli i Gong\nP.S.\nLe ricevute Tasse\nfammele mandare al più presto\n\n",
#  '23.10.24\nCaro Carlo                                                               \nSi può sapere come hai combinato con Brunelleschi? Adami mi dice che tutto è a posto riguardo i figurini. E non si son visti i 2 pittori Chini e Bru…? E se non si son visti come possono accordarsi per le fogge ed i colori? Io fra qualche giorno vò a Berlino per la mia maledetta gola! È un mistero il mio male – tutti dicono è cosa da poco ed io non trovo calma e sono molto preoccupato e Turandot non vede ancora la fine e se dopo Berlino vedrò un po’ chiaro nel mio male attaccherò il lavoro se no ti dirò di ritirare l’opera dal cartellone della Scala perché io non voglio promettere se non potrò mantenere. \nCiao, rispondimi circa i pittori. Io tengo tanto che si vedano e bisognerà pregare Brunelleschi di venir a Milano e accordarsi con Chini. \nSaluti a te \na Renzo\naff.tuo \nGiacomo\n',
#  "li 16 Febbraio 916\nEg.Sig\\r/ Costa\nLe rimetto le polizze dell'assicurazione auto mobili. Come Ella vede dovrei pagare per sole 2 auto mobili\nGrazie e distinti saluti\nAnt. Puccini"]

# %% [markdown]
# <br>
# <br>
#
#
# # **Pre-processing data**#

# %%
train = pd.read_csv('https://raw.githubusercontent.com/Andreaierardi/sentiment-puccini/main/dataset/training_set_sentipolc16%203.csv')
train
# Out:
#                idtwitter  ...                                               text
# 0     122449983151669248  ...  Intanto la partita per Via Nazionale si compli...
# 1     125485104863780865  ...  False illusioni, sgradevoli realtà Mario Monti...
# 2     125513454315507712  ...  False illusioni, sgradevoli realtà #editoriale...
# 3     125524238290522113  ...  Mario Monti: Berlusconi risparmi all'Italia il...
# 4     125527933224886272  ...  Mario Monti: Berlusconi risparmi all'Italia il...
# ...                  ...  ...                                                ...
# 7405  135136897000415233  ...  che ci frega di mario monti, noi abbiamo mario...
# 7406  143471916534087680  ...  Strepitoso il titolo in prima di Libero sul go...
# 7407  153955345411219456  ...  @nataliacavalli Consolati, il governo #Monti h...
# 7408  190835515552047104  ...  @SheisCandida beh, beate loro! Io nn possiedo ...
# 7409  193068210763993088  ...  Caro #Renzi,se #Grillo spaccava i computer e o...
#
# [7410 rows x 9 columns]

# %%
def get_sent_feature(df):
  sent = []
  for i, j in df[['opos','oneg', 'text']].iterrows():
    if j['opos'] == 1 and j['oneg'] == 1:
      sent.append(2)
    elif j['opos'] == 0 and j['oneg'] == 1:
      sent.append(-1)
    elif j['opos'] == 1 and  j['oneg'] == 0:
      sent.append(1)
    else:
      sent.append(0)
  return sent

# %%
def get_sent_feature_binary(df):
  sent = []
  for i, j in df[['opos','oneg', 'text']].iterrows():
    if j['opos'] == 1 and j['oneg'] == 1:
      sent.append(2)
    elif j['opos'] == 0 and j['oneg'] == 1:
      sent.append(-1)
    elif j['opos'] == 1 and  j['oneg'] == 0:
      sent.append(1)
    else:
      sent.append(2)
  return sent

# %%
train['sent'] = get_sent_feature(train)

# %%
train_binary = train.copy()
train_binary['sent'] = get_sent_feature_binary(train)
train_binary = train_binary[train_binary['sent'] !=2]

# %%
training_set = train.drop(labels=[ "idtwitter", 'subj','opos','oneg','lpos','lneg', 'top','iro'], axis=1)

# %%
training_set_binary = train_binary.drop(labels=[ "idtwitter", 'subj','opos','oneg','lpos','lneg', 'top','iro'], axis=1)

# %%
training_set
# Out:
#                                                    text  sent
# 0     Intanto la partita per Via Nazionale si compli...    -1
# 1     False illusioni, sgradevoli realtà Mario Monti...    -1
# 2     False illusioni, sgradevoli realtà #editoriale...    -1
# 3     Mario Monti: Berlusconi risparmi all'Italia il...    -1
# 4     Mario Monti: Berlusconi risparmi all'Italia il...    -1
# ...                                                 ...   ...
# 7405  che ci frega di mario monti, noi abbiamo mario...     1
# 7406  Strepitoso il titolo in prima di Libero sul go...     1
# 7407  @nataliacavalli Consolati, il governo #Monti h...    -1
# 7408  @SheisCandida beh, beate loro! Io nn possiedo ...     1
# 7409  Caro #Renzi,se #Grillo spaccava i computer e o...     1
#
# [7410 rows x 2 columns]

# %%
training_set_binary
# Out:
#                                                    text  sent
# 0     Intanto la partita per Via Nazionale si compli...    -1
# 1     False illusioni, sgradevoli realtà Mario Monti...    -1
# 2     False illusioni, sgradevoli realtà #editoriale...    -1
# 3     Mario Monti: Berlusconi risparmi all'Italia il...    -1
# 4     Mario Monti: Berlusconi risparmi all'Italia il...    -1
# ...                                                 ...   ...
# 7405  che ci frega di mario monti, noi abbiamo mario...     1
# 7406  Strepitoso il titolo in prima di Libero sul go...     1
# 7407  @nataliacavalli Consolati, il governo #Monti h...    -1
# 7408  @SheisCandida beh, beate loro! Io nn possiedo ...     1
# 7409  Caro #Renzi,se #Grillo spaccava i computer e o...     1
#
# 4     507080190225563648  ...  .@matteorenzi @MiurSocial #labuonascuola basta...
# ...                  ...  ...                                                ...
# 1938  645372190645481472  ...  Anche prodotti alimentari tipici pugliesi in v...
# 1939  645628412225265664  ...         intensità di vita  https://t.co/jv4aARxzhz
# 1940  645919232367161344  ...  Oggi tutti che iniziano l'università e io sul ...
# 1941  648567080107790336  ...  @GliIntoccabili @nonleggerlo Ma Ferrero? il co...
# 1942  648595040999239680  ...  Non vedi l'ora che venga qui, almeno lo sentir...
#
# [1943 rows x 9 columns]

# %%
test_set['sent'] = get_sent_feature(test_set)

# %%
test_set_binary = test_set.copy()
test_set_binary['sent'] = get_sent_feature_binary(test_set)
test_set_binary = test_set_binary[test_set_binary['sent'] != 2]

# %%
test_set = test_set.drop(labels=[ "idtwitter", 'subj','opos','oneg','lpos','lneg', 'top','iro'], axis=1)

# %%
test_set_binary = test_set_binary.drop(labels=[ "idtwitter", 'subj','opos','oneg','lpos','lneg', 'top','iro'], axis=1)

# %%
test_set
# Out:
#                                                    text  sent
# 0     Tra 5 minuti presentazione piano scuola del go...     0
# 1     \@matteorenzi: Alle 10 appuntamento su http://...     1
# 2     #labuonascuola gli #evangelisti #digitali non ...    -1
# 3     Riforma scuola Tutto il discorso di  Renzi su ...     0
# 4     .@matteorenzi @MiurSocial #labuonascuola basta...     0
# ...                                                 ...   ...
# 1938  Anche prodotti alimentari tipici pugliesi in v...     0
# 1939         intensità di vita  https://t.co/jv4aARxzhz     0
# 1940  Oggi tutti che iniziano l'università e io sul ...     2
# 1941  @GliIntoccabili @nonleggerlo Ma Ferrero? il co...    -1
# 1942  Non vedi l'ora che venga qui, almeno lo sentir...     1
#
# [1943 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.utils import shuffle


x_train = training_set.drop(["sent"],axis=1)
y_train = training_set["sent"]

x_train, y_train =  shuffle(x_train, y_train)
x_train = x_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)


x_train_binary = training_set_binary.drop(["sent"],axis=1)
y_train_binary = training_set_binary["sent"]

x_train_binary, y_train_binary =  shuffle(x_train_binary, y_train_binary)
x_train_binary = x_train_binary.reset_index(drop=True)
y_train_binary = y_train_binary.reset_index(drop=True)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.20)

# %%
x_train_binary, x_valid_binary, y_train_binary, y_valid_binary = train_test_split(x_train_binary, y_train_binary, test_size=0.20)

# %%
x_test = test_set.drop(["sent"],axis=1)
y_test = test_set["sent"]

x_test, y_test =  shuffle(x_test, y_test)
x_test = x_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
x_test_binary = test_set_binary.drop(["sent"],axis=1)
y_test_binary = test_set_binary["sent"]

x_test_binary, y_test_binary =  shuffle(x_test_binary, y_test_binary)
x_test_binary = x_test_binary.reset_index(drop=True)
y_test_binary = y_test_binary.reset_index(drop=True)

# %%
print("Shapes")
print("Train")
print("x_train",x_train.shape)
print("y_train",y_train.shape)
print("")
print("Valid")
print("x_valid",x_valid.shape)
print("y_valid",y_valid.shape)
print("")
print("Test")
print("x_test",x_test.shape)
print("y_test",y_test.shape)
# Out:
# Shapes
# Train
# x_train (5928, 1)
# y_train (5928,)
#
# Valid
# x_valid (1482, 1)
# y_valid (1482,)
#
# Test
# x_test (1943, 1)
# y_test (1943,)

# %%
print("Shapes")
print("Train_binary")
print("x_train_binary",x_train_binary.shape)
print("y_train_binary",y_train_binary.shape)
print("")
print("Valid")
print("x_valid_binary",x_valid_binary.shape)
print("y_valid_binary",y_valid_binary.shape)
print("")
print("Test")
print("x_test_binary",x_test_binary.shape)
print("y_test_binary",y_test_binary.shape)
# Out:
# Shapes
# Train_binary
# x_train_binary (3323, 1)
# y_train_binary (3323,)
#
# Valid
# x_valid_binary (831, 1)
# y_valid_binary (831,)
#
# Test
# x_test_binary (1018, 1)
# y_test_binary (1018,)

# %%
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer

# Custom Transformer (Inheriting from classes)
class CleanText( BaseEstimator, TransformerMixin ):
    
   
    def __init__( self, lang = "italian"):
        self.lang = lang
        self.stemmer = SnowballStemmer(self.lang)
    
       
    def fit( self, X, y = None ):
        return self 
    
   
    def clean( self, x ):
        words   = [self.stemmer.stem(word) for word in word_tokenize(x.lower()) if word.isalpha() and word not in stopwords.words("italian")]
        return " ".join(words)
    
   
    def transform( self, X, y = None ):
        return X["text"].apply(self.clean)

# %%
class CustomFeatures( BaseEstimator, TransformerMixin ):
    
    def __init__( self ):
        return
    
    def fit( self, X, y = None ):
        return self 
        
    def transform( self, X, y = None ):
        f           = pd.DataFrame()
        f['len']    = X['text'].str.len()
        f['digits'] = X['text'].str.findall(r'\d').str.len()
        f['punct']  = X['text'].str.findall(r'[^a-zA-Z\d\s:]').str.len()
        return f[['len','digits','punct']]

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import StandardScaler


pipe = Pipeline([("extract", FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                               ('tfidf', TfidfVectorizer())])),
                                           ("custom", CustomFeatures())])),
                 ("select", SelectKBest(score_func = chi2)),
                 ("scale", StandardScaler(with_mean = False))])

pipe_binary = Pipeline([("extract", FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                               ('tfidf', TfidfVectorizer())])),
                                           ("custom", CustomFeatures())])),
                 ("select", SelectKBest(score_func = chi2)),
                 ("scale", StandardScaler(with_mean = False))])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('extract',
#                  FeatureUnion(transformer_list=[('terms',
#                                                  Pipeline(steps=[('clean',
#                                                                   CleanText()),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())])),
#                                                 ('custom', CustomFeatures())])),
#                 ('select',
#                  SelectKBest(score_func=<function chi2 at 0x7f63296be950>)),
#                 ('scale', StandardScaler(with_mean=False))])

# %%
pipe_binary.fit(x_train_binary,y_train_binary)
# Out:
# Pipeline(steps=[('extract',
#                  FeatureUnion(transformer_list=[('terms',
#                                                  Pipeline(steps=[('clean',
#                                                                   CleanText()),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())])),
#                                                 ('custom', CustomFeatures())])),
#                 ('select',
#                  SelectKBest(score_func=<function chi2 at 0x7f63296be950>)),
#                 ('scale', StandardScaler(with_mean=False))])

# %%
X_train = pipe.fit_transform(x_train,y_train)

# %%
X_train_binary= pipe_binary.fit_transform(x_train_binary,y_train_binary)

# %%
letters_df
# Out:
#        segnatura  ...                                               text
# 0     CLET000451  ...  Maestro Verdi\nBusseto\nSento e comprendo suo ...
# 2     LLET000312  ...  Caro Blanc,\n\nUn'altra noja - Siccome si avvi...
# 6     LLET000313  ...  Gentilissimo Sig Giulio\n\nMadrid 8.3.92\n\nGr...
# 13    LLET000314  ...  Caro Blanc,                                   ...
# 16    LLET000315  ...  Caro Blanc\n\nT'avverto che ho preso un bicicl...
# ...          ...  ...                                                ...
# 1443  LLET000678  ...  Viareggio, 4 agosto 1924\n\nCarissimo Claudio\...
# 1448  LLET000679  ...  2 ott. 1924\n\nCaro Carlo\n\nci hai pensato a ...
# 1454  LLET000680  ...  Viareggio, [5 ottobre 1924]\n\nCaro Carlo\nti ...
# 1461  LLET000681  ...  23.10.24\nCaro Carlo                          ...
# 1469  LLET013851  ...  li 16 Febbraio 916\nEg.Sig\r/ Costa\nLe rimett...
#
# [370 rows x 9 columns]

# %%
X_valid = pipe.transform(x_valid)
X_test = pipe.transform(x_test)
X_letters = pipe.transform(letters_df[['text']])

# %%
X_valid_binary = pipe_binary.transform(x_valid_binary)
X_test_binary = pipe_binary.transform(x_test_binary)
X_letters_binary = pipe_binary.transform(letters_df[['text']])

# %%
# extract features
pipe_extract = FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                 ('tfidf', TfidfVectorizer())])),
                             ("custom", CustomFeatures())])

# select and scale features
pipe_select_scale = Pipeline([("select", SelectKBest(score_func = chi2)),
                              ("scale", StandardScaler(with_mean = False))])


# extract features
# you can also use bi-grams:
X_extract = pipe_extract.set_params(terms__tfidf__ngram_range = (1,2)).fit_transform(x_train, y_train)

X_extract_test = pipe_extract.set_params(terms__tfidf__ngram_range = (1,2)).transform(x_test)

X_extract_letters =  pipe_extract.set_params(terms__tfidf__ngram_range = (1,2)).transform(letters_df[['text']] )
print(X_extract)

X_select_scale = pipe_select_scale.set_params(select__k = 500).fit_transform(X_extract, y_train)
print(X_select_scale)

X_select_scale_test = pipe_select_scale.set_params(select__k = 500).transform(X_extract_test)
print(X_select_scale)

X_select_scale_letters = pipe_select_scale.set_params(select__k = 500).transform(X_extract_letters)
# Out:
#   (0, 1227)	0.19582559304345395
#   (0, 2183)	0.27211243246392125
#   (0, 2186)	0.2948334027766788
#   (0, 25796)	0.2948334027766788
#   (0, 25797)	0.2948334027766788
#   (0, 27508)	0.15725151032429371
#   (0, 27513)	0.2948334027766788
#   (0, 28327)	0.1533085982263722
#   (0, 28410)	0.2948334027766788
#   (0, 32306)	0.18560563430971883
#   (0, 32334)	0.2948334027766788
#   (0, 40757)	0.1739140325261124
#   (5926, 210)	2.1184498192055816
#   (5926, 497)	3.321182735144357
#   (5926, 498)	2.1752609966751972
#   (5926, 499)	2.1638641747827365
#   (5927, 497)	2.796785461174195
#   (5927, 499)	2.1638641747827365
#   (0, 457)	7.284364578411017
#   (0, 497)	2.4471872785274207
#   (0, 499)	0.8114490655435262
#   (1, 184)	2.081536744875567
#   (1, 497)	2.9715845524975824
#   (1, 499)	1.6228981310870525
#   (2, 184)	1.8004124636542567
#   (2, 210)	3.525069565169145
#   (2, 497)	3.6125145540166685
#   (2, 498)	1.0876304983375986
#   (2, 499)	2.4343471966305787
#   (3, 497)	1.6605913675721784
#   (3, 498)	1.631445747506398
#   (3, 499)	1.3524151092392103
#   (4, 190)	2.5714976074634412
#   (4, 442)	9.184768642361933
#   (4, 497)	3.321182735144357
#   (4, 499)	1.0819320873913683
#   (5, 210)	2.070253178404598
#   (5, 497)	1.6897245494594095
#   (5, 498)	0.5438152491687993
#   (5, 499)	2.1638641747827365
#   (6, 190)	3.7450220101401053
#   (6, 497)	1.4275259124743287
#   (6, 498)	0.5438152491687993
#   :	:
#   (5921, 499)	1.3524151092392103
#   (5922, 64)	13.78508814652269
#   (5922, 497)	1.1653272754892479
#   (5922, 499)	0.27048302184784206
#   (5923, 184)	1.6725744349961014
#   (5923, 497)	3.233783189482663
#   (5923, 499)	1.0819320873913683
#   (5924, 34)	12.656665301820764
#   (5924, 210)	1.9091094119706207
#   (5924, 497)	2.155855459655109
#   (5924, 498)	0.5438152491687993
#   (5924, 499)	1.3524151092392103
#   (5925, 13)	6.564172173546397
#   (5925, 210)	1.6870503473509932
#   (5925, 237)	7.787380960811782
#   (5925, 497)	2.18498864154234
#   (5925, 498)	1.0876304983375986
#   (5925, 499)	1.6228981310870525
#   (5926, 184)	2.1639762776941525
#   (5926, 210)	2.1184498192055816
#   (5926, 497)	3.321182735144357
#   (5926, 498)	2.1752609966751972
#   (5926, 499)	2.1638641747827365
#   (5927, 497)	2.796785461174195
#   (5927, 499)	2.1638641747827365

# %%
# extract features
pipe_extract_binary = FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                 ('tfidf', TfidfVectorizer())])),
                             ("custom", CustomFeatures())])

# select and scale features
pipe_select_scale_binary = Pipeline([("select", SelectKBest(score_func = chi2)),
                              ("scale", StandardScaler(with_mean = False))])


# extract features
# you can also use bi-grams:
X_extract_binary = pipe_extract_binary.set_params(terms__tfidf__ngram_range = (1,2)).fit_transform(x_train_binary, y_train_binary)

X_extract_test_binary = pipe_extract_binary.set_params(terms__tfidf__ngram_range = (1,2)).transform(x_test_binary)

X_extract_letters_binary =  pipe_extract_binary.set_params(terms__tfidf__ngram_range = (1,2)).transform(letters_df[['text']] )
print(X_extract_binary)

X_select_scale_binary = pipe_select_scale_binary.set_params(select__k = 500).fit_transform(X_extract_binary, y_train_binary)
print(X_select_scale_binary)

X_select_scale_test_binary = pipe_select_scale_binary.set_params(select__k = 500).transform(X_extract_test_binary)
print(X_select_scale_binary)

X_select_scale_letters_binary = pipe_select_scale_binary.set_params(select__k = 500).transform(X_extract_letters_binary)
#   (3318, 287)	1.6224156934221574
#   (3318, 303)	13.766493033674218
#   (3318, 351)	6.015518658963695
#   (3318, 498)	3.8999668782186796
#   (3318, 499)	3.4802935205512044
#   (3319, 49)	13.933683216224509
#   (3319, 260)	3.0131957814002637
#   (3319, 261)	3.145677483796748
#   (3319, 287)	2.193039665753571
#   (3319, 498)	1.5485162604691816
#   (3320, 153)	4.832940170201536
#   (3320, 498)	2.2940981636580466
#   (3321, 209)	2.173308047259607
#   (3321, 359)	5.819961078380427
#   (3321, 361)	3.2217039519401007
#   (3321, 498)	4.014671786401582
#   (3322, 182)	11.116052174983857
#   (3322, 275)	11.694765908468709
#   (3322, 498)	1.9499834391093398
#   (0, 100)	9.563295800194588
#   (0, 404)	17.796792655069293
#   (0, 461)	9.944496034175517
#   (0, 471)	4.096346136109945
#   (0, 498)	3.4984996995785216
#   (1, 94)	19.058119912287083
#   (1, 191)	1.6597313208579096
#   (1, 192)	1.8388258204437782
#   (1, 287)	1.5408459399239725
#   (1, 498)	3.6992332888986006
#   (2, 77)	15.68270213564535
#   (2, 80)	41.131169559468034
#   (2, 186)	18.79827919901176
#   (2, 498)	0.6308769950059628
#   (3, 191)	1.3838202569431979
#   (3, 192)	1.533142375119485
#   (3, 258)	5.073924470092593
#   (3, 287)	1.2846981904235681
#   (3, 498)	4.014671786401582
#   (3, 499)	2.7842348164409634
#   (4, 498)	2.2654219366123214
#   (4, 499)	0.6960587041102408
#   (5, 448)	9.050623220419892
#   (5, 498)	1.863954757972163
#   (6, 498)	1.2330777629662002
#   :	:
#   (3317, 498)	4.014671786401582
#   (3318, 66)	5.47398593452214
#   (3318, 185)	29.22110971503489
#   (3318, 191)	1.7475946634593615
#   (3318, 192)	1.9361701200997827
#   (3318, 226)	21.98769477242037
#   (3318, 287)	1.6224156934221574
#   (3318, 303)	13.766493033674218
#   (3318, 351)	6.015518658963695
#   (3318, 498)	3.8999668782186796
#   (3318, 499)	3.4802935205512044
#   (3319, 49)	13.933683216224509
#   (3319, 260)	3.0131957814002637
#   (3319, 261)	3.145677483796748
#   (3319, 287)	2.193039665753571
#   (3319, 498)	1.5485162604691816
#   (3320, 153)	4.832940170201536
#   (3320, 498)	2.2940981636580466
#   (3321, 209)	2.173308047259607
#   (3321, 359)	5.819961078380427
#   (3321, 361)	3.2217039519401007
#   (3321, 498)	4.014671786401582
#   (3322, 182)	11.116052174983857
#   (3322, 275)	11.694765908468709
#   (3322, 498)	1.9499834391093398

# %%
# extract features
pipe_bi = Pipeline([("extract", FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                               ('tfidf', TfidfVectorizer(ngram_range = (1,2)))])),
                                           ("custom", CustomFeatures())])),
                 ("select", SelectKBest(score_func = chi2,k = 500)),
                 ("scale", StandardScaler(with_mean = False))])

# %%
# extract features
pipe_bi_binary = Pipeline([("extract", FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                               ('tfidf', TfidfVectorizer(ngram_range = (1,2)))])),
                                           ("custom", CustomFeatures())])),
                 ("select", SelectKBest(score_func = chi2,k = 500)),
                 ("scale", StandardScaler(with_mean = False))])

# %%
X_train_bi =pipe_bi.fit_transform(x_train,y_train)
X_valid_bi = pipe_bi.transform(x_valid)
X_test_bi = pipe_bi.transform(x_test)

X_letters_bi = pipe_bi.transform(letters_df[['text']])

# %%
X_train_bi_binary =pipe_bi_binary.fit_transform(x_train_binary,y_train_binary)
X_valid_bi_binary = pipe_bi_binary.transform(x_valid_binary)
X_test_bi_binary = pipe_bi_binary.transform(x_test_binary)

X_letters_bi_binary = pipe_bi_binary.transform(letters_df[['text']])

# %%
from sklearn import preprocessing
le_binary = preprocessing.LabelEncoder()

y_train_enc_binary = le_binary.fit_transform(y_train_binary)
y_valid_enc_binary = le_binary.transform(y_valid_binary)
y_test_enc_binary = le_binary.transform(y_test_binary)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

y_train_enc = le.fit_transform(y_train)
y_valid_enc = le.transform(y_valid)
y_test_enc = le.transform(y_test)

# %%
import numpy as np
from keras.utils import np_utils

no_of_classes = len(np.unique(y_train))
y_train_seq = np_utils.to_categorical(y_train_enc,no_of_classes)
y_valid_seq = np_utils.to_categorical(y_valid_enc,no_of_classes)
y_test_seq= np_utils.to_categorical(y_test_enc,no_of_classes)

# %%
import numpy as np
from keras.utils import np_utils

no_of_classes_binary = len(np.unique(y_train_binary))
y_train_seq_binary = np_utils.to_categorical(y_train_enc_binary,no_of_classes_binary)
y_valid_seq_binary = np_utils.to_categorical(y_valid_enc_binary,no_of_classes_binary)
y_test_seq_binary= np_utils.to_categorical(y_test_enc_binary,no_of_classes_binary)

# %% [markdown]
# <hr>
# <br>
# <br>
#
# # CV Neural Networks
#
# <br>

# %%
# !pip install keras-visualizer
# Out:
# Collecting keras-visualizer
#   Downloading keras_visualizer-2.4-py3-none-any.whl (5.4 kB)
# Installing collected packages: keras-visualizer
# Successfully installed keras-visualizer-2.4

# %%
from keras_visualizer import visualizer 
from keras.callbacks import History
import tensorflow as tf
import keras
from keras import layers
from keras import models
from keras import utils
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import Activation
from keras.regularizers import l2
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop

# %%
def createNN_tuning_binary(init_mode='uniform',drop_out=0.1, init_nodes1 =64, init_nodes2 = 64,dim = 500):
    # define model
    model = Sequential()
    model.add(Dense(init_nodes1, kernel_initializer=init_mode, activation=tf.nn.relu, input_dim=dim)) 
    model.add(Dropout(drop_out))
    model.add(Dense(init_nodes2, kernel_initializer=init_mode, activation=tf.nn.relu))
    model.add(Dense(1, kernel_initializer=init_mode, activation=tf.nn.sigmoid))
    # compile model
    model.compile(loss='binary_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
    return model

# %%
import numpy
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

def createNN_tuning(init_mode='uniform',drop_out=0.1, init_nodes1 =64, init_nodes2 = 64,dim = 500):
    # define model
    model = Sequential()
    model.add(Dense(init_nodes1, kernel_initializer=init_mode, activation=tf.nn.relu, input_dim=dim)) 
    model.add(Dropout(drop_out))
    model.add(Dense(init_nodes2, kernel_initializer=init_mode, activation=tf.nn.relu))
    model.add(Dense(4, kernel_initializer=init_mode, activation=tf.nn.softmax))
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])
    return model

# %%
seed = 7
numpy.random.seed(seed)
batch_size = 128
epochs = 50

model_CV_binary = KerasClassifier(build_fn=createNN_tuning_binary,  
                           batch_size=batch_size, verbose=1,  )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   import sys

# %%
seed = 7
numpy.random.seed(seed)
batch_size = 128
epochs = 50

model_CV = KerasClassifier(build_fn=createNN_tuning,  
                           batch_size=batch_size, verbose=1,  )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   import sys

# %%
# define the grid search parameters
init_mode = ['uniform', 'lecun_uniform', 'normal']
init_nodes1 = [64,128,256]
init_nodes2 = [64,128,256]
drop_out = [0.1,0.3,0.5]
epochs = [30,50]

param_grid = dict(init_mode=init_mode, init_nodes1 = init_nodes1, init_nodes2 = init_nodes2, drop_out= drop_out,epochs= epochs)

# %%
grid_binary = GridSearchCV(estimator=model_CV_binary, param_grid=param_grid, n_jobs=-1, cv=3)

# %%
grid = GridSearchCV(estimator=model_CV, param_grid=param_grid, n_jobs=-1, cv=3)

# %%
#%%time
#grid_result_binary = grid_binary.fit(X_train_bi_binary, y_train_enc_binary,validation_data=(X_valid_bi_binary, y_valid_enc_binary))

# %%
#%%time
#grid_result = grid.fit(X_train_bi, y_train_seq,validation_data=(X_valid_bi, y_valid_seq))

# %%
#y_pred_binary= grid_result_binary.predict(X_test_binary)
#y_pred_enc_binary = [np.argmax(i) for i in y_pred_binary]
#f1_score(y_test_enc_binary, y_pred_enc_binary, average="weighted")

# %%
#from sklearn.metrics import f1_score
#y_pred= grid_result.predict(X_test_bi)
#y_pred_enc = [np.argmax(i) for i in y_pred]
#f1_score(y_test_enc, y_pred_enc, average="weighted")

# %%
#print(f'Best Accuracy for {grid_result_binary.best_score_} using {grid_result_binary.best_params_}')
#means_binary = grid_result_binary.cv_results_['mean_test_score']
#stds_binary = grid_result_binary.cv_results_['std_test_score']
#params_binary = grid_result_binary.cv_results_['params']
#for mean, stdev, param in zip(means_binary, stds_binary, params_binary):
#    print(f' mean={mean:.4}, std={stdev:.4} using {param}')

# %%
# print results
#print(f'Best Accuracy for {grid_result.best_score_} using {grid_result.best_params_}')
#means = grid_result.cv_results_['mean_test_score']
#stds = grid_result.cv_results_['std_test_score']
#params = grid_result.cv_results_['params']
#for mean, stdev, param in zip(means, stds, params):
#    print(f' mean={mean:.4}, std={stdev:.4} using {param}')

# %% [markdown]
# Best Accuracy for 0.5506073037783304 using {'drop_out': 0.5, 'epochs': 50, 'init_mode': 'normal', 'init_nodes1': 64, 'init_nodes2': 256}
#  mean=0.5471, std=0.01136 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 64, 'init_nodes2': 64}
#  mean=0.5444, std=0.009833 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 64, 'init_nodes2': 128}
#  mean=0.5366, std=0.01055 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 64, 'init_nodes2': 256}
#  mean=0.541, std=0.01032 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 128, 'init_nodes2': 64}
#  mean=0.5415, std=0.01118 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 128, 'init_nodes2': 128}
#  mean=0.5341, std=0.01009 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 128, 'init_nodes2': 256}
#  mean=0.5371, std=0.009729 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 256, 'init_nodes2': 64}
#  mean=0.5358, std=0.01328 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 256, 'init_nodes2': 128}
#  mean=0.5307, std=0.007499 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 256, 'init_nodes2': 256}
#  mean=0.5401, std=0.01408 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 64, 'init_nodes2': 64}
#  mean=0.5326, std=0.01122 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 64, 'init_nodes2': 128}
#  mean=0.5386, std=0.01049 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 64, 'init_nodes2': 256}
#  mean=0.5294, std=0.01242 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 128, 'init_nodes2': 64}
#  mean=0.53, std=0.00948 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 128, 'init_nodes2': 128}
#  mean=0.5231, std=0.01222 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 128, 'init_nodes2': 256}
#  mean=0.5278, std=0.006951 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 256, 'init_nodes2': 64}
#  mean=0.5238, std=0.005466 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 256, 'init_nodes2': 128}
#  mean=0.5155, std=0.01508 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 256, 'init_nodes2': 256}
#  mean=0.5417, std=0.00836 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'normal', 'init_nodes1': 64, 'init_nodes2': 64}
#  mean=0.5376, std=0.01222 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'normal', 'init_nodes1': 64, 'init_nodes2': 128}
#  mean=0.5374, std=0.01043 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'normal', 'init_nodes1': 64, 'init_nodes2': 256}

# %%
#_, accuracy_binary = grid_result_binary.evaluate(X_test_bi_binary, y_test_seq_binary)
#print('Accuracy: %.2f' % (accuracy_binary*100))

# %%
#_, accuracy = grid_result.evaluate(X_test_bi, y_test_seq)
#print('Accuracy: %.2f' % (accuracy*100))

# %%
#grid_result_binary.best_params_

# %%
#grid_result.best_params_

# %% [markdown]
# {'drop_out': 0.5, 'epochs': 50, 'init_nodes1': 64, 'init_nodes2': 128}

# %%
model_earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=5, verbose=0,
    mode='auto', baseline=None, restore_best_weights=False
)

# %%
nn_tune_binary= createNN_tuning_binary(drop_out=0.5, init_mode="normal",init_nodes1=64, init_nodes2 = 128)

# %%
nn_tune= createNN_tuning(drop_out=0.5, init_mode="normal",init_nodes1=64, init_nodes2 = 256)

# %%
history_tune_binary = nn_tune_binary.fit(X_train_bi_binary, y_train_enc_binary,validation_data=(X_valid_bi_binary, y_valid_enc_binary), epochs=30, batch_size=1024,callbacks=model_earlystop)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:450: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/sequential/dense/embedding_lookup_sparse/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/sequential/dense/embedding_lookup_sparse/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/sequential/dense/embedding_lookup_sparse/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 4/4 [==============================] - 1s 59ms/step - loss: 0.6922 - accuracy: 0.4342 - val_loss: 0.6839 - val_accuracy: 0.6053
# Epoch 2/30
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6722 - accuracy: 0.6404 - val_loss: 0.6644 - val_accuracy: 0.6534
# Epoch 3/30
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6512 - accuracy: 0.7054 - val_loss: 0.6441 - val_accuracy: 0.6907
# Epoch 4/30
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6222 - accuracy: 0.7463 - val_loss: 0.6178 - val_accuracy: 0.7028
# Epoch 5/30
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5902 - accuracy: 0.7608 - val_loss: 0.5863 - val_accuracy: 0.7160
# Epoch 6/30
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5462 - accuracy: 0.7782 - val_loss: 0.5577 - val_accuracy: 0.7184
# Epoch 7/30
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5019 - accuracy: 0.7963 - val_loss: 0.5445 - val_accuracy: 0.7184
# Epoch 8/30
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4627 - accuracy: 0.8044 - val_loss: 0.5548 - val_accuracy: 0.7268
# Epoch 9/30
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4200 - accuracy: 0.8231 - val_loss: 0.5869 - val_accuracy: 0.7353
# Epoch 10/30
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4065 - accuracy: 0.8279 - val_loss: 0.6263 - val_accuracy: 0.7389
# Epoch 11/30
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3881 - accuracy: 0.8342 - val_loss: 0.6645 - val_accuracy: 0.7389
# Epoch 12/30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3806 - accuracy: 0.8381 - val_loss: 0.6898 - val_accuracy: 0.7377

# %%
history_tune = nn_tune.fit(X_train_bi, y_train_seq,validation_data=(X_valid_bi, y_valid_seq), epochs=30, batch_size=512,callbacks=model_earlystop)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:450: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/sequential_1/dense_3/embedding_lookup_sparse/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/sequential_1/dense_3/embedding_lookup_sparse/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/sequential_1/dense_3/embedding_lookup_sparse/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 12/12 [==============================] - 1s 37ms/step - loss: 1.3127 - accuracy: 0.4005 - val_loss: 1.2573 - val_accuracy: 0.4285
# Epoch 2/30
# 12/12 [==============================] - 0s 12ms/step - loss: 1.1870 - accuracy: 0.4637 - val_loss: 1.2231 - val_accuracy: 0.4804
# Epoch 3/30
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1415 - accuracy: 0.4902 - val_loss: 1.2442 - val_accuracy: 0.4933
# Epoch 4/30
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0993 - accuracy: 0.5246 - val_loss: 1.2627 - val_accuracy: 0.4933
# Epoch 5/30
# 12/12 [==============================] - 0s 11ms/step - loss: 1.0736 - accuracy: 0.5314 - val_loss: 1.2611 - val_accuracy: 0.5121
# Epoch 6/30
# 12/12 [==============================] - 0s 13ms/step - loss: 1.0594 - accuracy: 0.5418 - val_loss: 1.2728 - val_accuracy: 0.5142
# Epoch 7/30
# 12/12 [==============================] - 0s 14ms/step - loss: 1.0468 - accuracy: 0.5511 - val_loss: 1.2738 - val_accuracy: 0.5135

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
plot_graphs(history_tune_binary, "accuracy")
plot_graphs(history_tune_binary, "loss")

# %%
plot_graphs(history_tune, "accuracy")
plot_graphs(history_tune, "loss")

# %%
_, accuracy_binary = nn_tune_binary.evaluate(X_test_bi_binary, y_test_enc_binary)
print('Accuracy: %.2f' % (accuracy_binary*100))
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0357 - accuracy: 0.6248
# Accuracy: 62.48

# %%
y_test_enc_binary
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
_, accuracy = nn_tune.evaluate(X_test_bi, y_test_seq)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 61/61 [==============================] - 0s 3ms/step - loss: 1.1868 - accuracy: 0.4756
# Accuracy: 47.56

# %%
from sklearn.metrics import f1_score
y_pred_binary= nn_tune_binary.predict(X_test_bi_binary)
y_pred_enc_binary =np.asarray(np.round(y_pred_binary)).astype(int)
f1_score(y_test_enc_binary, y_pred_enc_binary, average="weighted")
# Out:
# 0.6380260659303113

# %%
from sklearn.metrics import f1_score
y_pred= nn_tune.predict(X_test_bi)
y_pred_enc = [np.argmax(i) for i in y_pred]
f1_score(y_test_enc, y_pred_enc, average="weighted")
# Out:
# 0.48409203806271245

# %%
nn_tune_binary.save('NN_2sent.sav')
nn_tune.save("NN_4sent.sav")
# Out:
# INFO:tensorflow:Assets written to: NN_2sent.sav/assets
# INFO:tensorflow:Assets written to: NN_4sent.sav/assets

# %%
# !zip -r /.zip /content/Folder_To_Zip

# %%
from keras.models import load_model
nn_tune_binary = load_model('NN_2sent.sav')
nn_tune= load_model('NN_4sent.sav')

# %%
pred = le.inverse_transform([np.argmax(i) for i in y_pred])

# %%
pred
# Out:
# array([ 0,  1, -1, ..., -1,  1,  0])

# %%
test_set
# Out:
#                                                    text  sent
# 0     Tra 5 minuti presentazione piano scuola del go...     0
# 1     \@matteorenzi: Alle 10 appuntamento su http://...     1
# 2     #labuonascuola gli #evangelisti #digitali non ...    -1
# 3     Riforma scuola Tutto il discorso di  Renzi su ...     0
# 4     .@matteorenzi @MiurSocial #labuonascuola basta...     0
# ...                                                 ...   ...
# 1938  Anche prodotti alimentari tipici pugliesi in v...     0
# 1939         intensità di vita  https://t.co/jv4aARxzhz     0
# 1940  Oggi tutti che iniziano l'università e io sul ...     2
# 1941  @GliIntoccabili @nonleggerlo Ma Ferrero? il co...    -1
# 1942  Non vedi l'ora che venga qui, almeno lo sentir...     1
#
# [1943 rows x 2 columns]

# %%
visualizer(nn_tune, format='png', view=True)

# %%
from keras.utils.vis_utils import plot_model
 
plot_model(nn_tune, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
X_letters
# Out:
# <456x10 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1287 stored elements in Compressed Sparse Row format>

# %%
X_test_bi
# Out:
# <1943x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6725 stored elements in Compressed Sparse Row format>

# %%
X_letters_bi
# Out:
# <456x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2115 stored elements in Compressed Sparse Row format>

# %%
y_pred = nn_tune.predict(X_letters_bi)
y_pred_enc_bi = [np.argmax(i) for i in y_pred]
#f1_score(y_pred_enc_bi, y_pred_enc, average="weighted")

# %%
y_pred_bin = nn_tune_binary.predict(X_letters_bi_binary)
y_pred_enc_bi_bin =np.asarray(np.round(y_pred_bin)).astype(int)

# %%
letters_df
# Out:
#                     id  ... emotion_sentita
# CLET000002  CLET000002  ...             joy
# CLET000024  CLET000024  ...         sadness
# CLET000026  CLET000026  ...             joy
# CLET000028  CLET000028  ...         sadness
# CLET000029  CLET000029  ...             joy
# ...                ...  ...             ...
# CLET000782  CLET000782  ...         sadness
# CLET000783  CLET000783  ...             joy
# CLET000784  CLET000784  ...             joy
# CLET000785  CLET000785  ...             joy
# CLET000786  CLET000786  ...             joy
#
# [456 rows x 22 columns]

# %%
letters_df
# Out:
#                     id  ... emotion_sentita
# CLET000002  CLET000002  ...             joy
# CLET000024  CLET000024  ...         sadness
# CLET000026  CLET000026  ...             joy
# CLET000028  CLET000028  ...         sadness
# CLET000029  CLET000029  ...             joy
# ...                ...  ...             ...
# CLET000782  CLET000782  ...         sadness
# CLET000783  CLET000783  ...             joy
# CLET000784  CLET000784  ...             joy
# CLET000785  CLET000785  ...             joy
# CLET000786  CLET000786  ...             joy
#
# [456 rows x 22 columns]

# %%
letters_text_pred = letters_df[['text','year']]

# %%
letters_text_pred
# Out:
#                                                          text  year
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  1888
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  1888
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  1888
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  1888
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  1888
# ...                                                       ...   ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  1888
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  1888
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  1888
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  1888
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  1888
#
# [456 rows x 2 columns]

# %%
letters_text_pred['pred'] = y_pred_enc_bi
letters_df['pred'] = y_pred_enc_bi
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
letters_text_pred['pred_binary'] = y_pred_enc_bi_bin
letters_df['pred_binary'] = y_pred_enc_bi_bin
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
letters_text_pred
# Out:
#                                                          text  ...  pred_binary
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...            1
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...            0
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...            0
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...            0
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...            0
# ...                                                       ...  ...          ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...            1
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...            1
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...            1
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...            1
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...            0
#
# [456 rows x 4 columns]

# %% [markdown]
# <hr>
#
# <br>
# <br>
#
# # Sentita Sentiment and Emotion Classifiers
#
# <br>

# %%
letters_df = pd.read_pickle('https://github.com/Andreaierardi/sentiment-puccini/blob/main/dataset/puccini.pkl?raw=true')

# %%
letters_list = list(letters_df['text'])

# %%
letters_df
# Out:
#                     id  ...      linuga
# CLET000002  CLET000002  ...  [italiano]
# CLET000024  CLET000024  ...  [italiano]
# CLET000026  CLET000026  ...  [italiano]
# CLET000028  CLET000028  ...  [italiano]
# CLET000029  CLET000029  ...  [italiano]
# ...                ...  ...         ...
# CLET000782  CLET000782  ...  [italiano]
# CLET000783  CLET000783  ...  [italiano]
# CLET000784  CLET000784  ...  [italiano]
# CLET000785  CLET000785  ...  [italiano]
# CLET000786  CLET000786  ...  [italiano]
#
# [456 rows x 19 columns]

# %%
#%%capture
# !pip install feel-it
# Out:
# Collecting feel-it
#   Downloading feel_it-1.0.3-py2.py3-none-any.whl (5.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from feel-it) (1.19.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from feel-it) (1.10.0+cu111)
# Collecting transformers==4.3.3
#   Downloading transformers-4.3.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 7.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (3.4.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 36.1 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 41.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->feel-it) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.3.3->feel-it) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.3.3->feel-it) (3.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->feel-it) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->feel-it) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->feel-it) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->feel-it) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->feel-it) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->feel-it) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->feel-it) (7.1.2)
# Installing collected packages: tokenizers, sacremoses, transformers, feel-it
# Successfully installed feel-it-1.0.3 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.3.3

# %%
from feel_it import SentimentClassifier
sentiment_classifier = SentimentClassifier()
# Out:
# Downloading:   0%|          | 0.00/847 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/794k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.68M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/299 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
sentiments_letter = sentiment_classifier.predict(letters_list)

# %%
sentiment_test = sentiment_classifier.predict([i for i in x_test_binary['text']])

# %%
vector_converted = []
for i in y_test_enc_binary:
  if i == 0:
    vector_converted.append("negative")
  if i == 1:
    vector_converted.append("positive")

# %%
from sklearn.metrics import f1_score
print(f1_score(vector_converted, sentiment_test, average="weighted"))
# Out:
# 0.8546168958742633

# %%
§sentiments_letter[:10]
# Out:
# ['positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive']

# %%
from feel_it import EmotionClassifier
emotion_classifier = EmotionClassifier()
# Out:
# Downloading:   0%|          | 0.00/899 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/794k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.68M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/299 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
emotions_letter = emotion_classifier.predict(letters_list)

# %%
emotions_letter

# %% [markdown]
# <hr>
# <br>
# <br>
#
# # Sentita Model Results
#
# <br>

# %%
letters_df['sentiment_sentita'] = sentiments_letter

# %%
letters_df['emotion_sentita'] = emotions_letter

# %%
letters_df
# Out:
#                     id  ... pred_binary
# CLET000002  CLET000002  ...           1
# CLET000024  CLET000024  ...           0
# CLET000026  CLET000026  ...           0
# CLET000028  CLET000028  ...           0
# CLET000029  CLET000029  ...           0
# ...                ...  ...         ...
# CLET000782  CLET000782  ...           1
# CLET000783  CLET000783  ...           1
# CLET000784  CLET000784  ...           1
# CLET000785  CLET000785  ...           1
# CLET000786  CLET000786  ...           0
#
# [456 rows x 24 columns]

# %%
letters_df.groupby(by=['emotion_sentita','sentiment_sentita'])

# %%
print('Number of letters with positive sentiment:',len(letters_df[letters_df['sentiment_sentita'] == 'positive']))
print('Number of letters with negative sentiment:',len(letters_df[letters_df['sentiment_sentita'] == 'negative']))
# Out:
# Number of letters with positive sentiment: 216
# Number of letters with negative sentiment: 240

# %%
sent_agg = letters_df.groupby(by="sentiment_sentita").size()

# %%
letters_text_pred['sentiment_sentita'] = letters_df['sentiment_sentita']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
letters_text_pred['emotion_sentita'] = letters_df['emotion_sentita']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
letters_text_pred
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...          sadness
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# ...                                                       ...  ...              ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [456 rows x 6 columns]

# %%
letters_text_pred[['pred']] = letters_text_pred[['pred']].replace({0:"negative", 1:"neutral",2:"positive", 3:"both"})
letters_df[['pred']] = letters_df[['pred']].replace({0:"negative", 1:"neutral",2:"positive", 3:"both"})
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
letters_text_pred[['pred_binary']] = letters_text_pred[['pred_binary']].replace({0:"negative",1:"positive" })
letters_df[['pred_binary']] = letters_df[['pred_binary']].replace({0:"negative",1:"positive" })
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
letters_df.to_pickle('puccini_with_predictions.pkl')

# %%
letters_text_pred
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...          sadness
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# ...                                                       ...  ...              ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [456 rows x 6 columns]

# %%
print('Number of letters with joy emotion:',len(letters_text_pred[letters_text_pred['emotion_sentita'] == 'joy']))
print('Number of letters with fear emotion:',len(letters_text_pred[letters_text_pred['emotion_sentita'] == 'fear']))
print('Number of letters with anger emotion:',len(letters_text_pred[letters_text_pred['emotion_sentita'] == 'anger']))
print('Number of letters with sadness emotion:',len(letters_text_pred[letters_text_pred['emotion_sentita'] == 'sadness']))
# Out:
# Number of letters with joy emotion: 250
# Number of letters with fear emotion: 19
# Number of letters with anger emotion: 21
# Number of letters with sadness emotion: 166

# %%
emo_agg = letters_text_pred.groupby(by="emotion_sentita").size().sort_values( ascending=False)

# %%
emo_agg
# Out:
# emotion_sentita
# joy        250
# sadness    166
# anger       21
# fear        19
# dtype: int64

# %%
def plot_freq(names,counts, title = None):
  fig, ax = plt.subplots(figsize =(16, 9))

  name = names#emo_agg.index
  count = counts #emo_agg.values
  # Horizontal Bar Plot
  ax.barh(name, count)
  
  # Remove axes splines
  for s in ['top', 'bottom', 'left', 'right']:
      ax.spines[s].set_visible(False)
  
  # Remove x, y Ticks
  ax.xaxis.set_ticks_position('none')
  ax.yaxis.set_ticks_position('none')
  
  # Add padding between axes and labels
  ax.xaxis.set_tick_params(pad = 5)
  ax.yaxis.set_tick_params(pad = 10)
  
  # Add x, y gridlines
  ax.grid(b = True, color ='grey',
          linestyle ='-.', linewidth = 0.5,
          alpha = 0.2)
  
  # Show top values
  ax.invert_yaxis()
  
  # Add annotation to bars
  for i in ax.patches:
      plt.text(i.get_width()+0.2, i.get_y()+0.5,
              str(round((i.get_width()), 2)),
              fontsize = 20, fontweight ='bold',
              color ='grey')
  
  # Add Plot Title
  if title is None:
    ax.set_title('Distribution of predicted emotion',
                loc ='left', )
  else:
    ax.set_title(title,
                loc ='left', )
  # Show Plot
  plt.show()

# %%
plot_freq(sent_agg.index,sent_agg.values)

# %%
plot_freq(emo_agg.index,emo_agg.values)

# %%
distribution_emo_sent = letters_text_pred.groupby(['emotion_sentita','sentiment_sentita'],as_index=False).count().sort_values('text')
distribution_emo_sent
# Out:
#   emotion_sentita sentiment_sentita  text  year  pred  pred_binary
# 1            fear          negative    19    19    19           19
# 0           anger          negative    21    21    21           21
# 5         sadness          positive    23    23    23           23
# 2             joy          negative    57    57    57           57
# 4         sadness          negative   143   143   143          143
# 3             joy          positive   193   193   193          193

# %%
distribution_emo_sent = letters_text_pred.groupby(by=['emotion_sentita','sentiment_sentita']).size()

# %%
distribution_emo_sent =distribution_emo_sent.reset_index()
distribution_emo_sent.index = distribution_emo_sent['emotion_sentita']+"-"+distribution_emo_sent['sentiment_sentita']

# %%
distribution_emo_sent = distribution_emo_sent.reset_index()

# %%
distribution_emo_sent['count'] = distribution_emo_sent[0]

# %%
distribution_emo_sent = distribution_emo_sent.sort_values("count")

# %%
plot_freq(distribution_emo_sent['emotion_sentita']+"-"+distribution_emo_sent['sentiment_sentita'],distribution_emo_sent['count'])

# %%
letters_sent_year  = letters_text_pred.groupby(['year', 'sentiment_sentita'],as_index = False).agg('text').count()

# %%
letters_sent_year
# Out:
#     year sentiment_sentita  text
# 0   1888          negative     2
# 1   1888          positive     3
# 2   1889          negative     2
# 3   1889          positive     6
# 4   1890          negative     9
# 5   1890          positive     1
# 6   1891          negative     8
# 7   1891          positive     1
# 8   1892          negative    17
# 9   1892          positive    17
# 10  1893          negative    24
# 11  1893          positive    27
# 12  1894          negative    23
# 13  1894          positive    14
# 14  1895          negative    19
# 15  1895          positive    12
# 16  1896          negative    22
# 17  1896          positive    30
# 18  1897          negative    22
# 19  1897          positive    17
# 20  1898          negative    20
# 21  1898          positive    20
# 22  1899          negative    37
# 23  1899          positive    25
# 24  1900          negative    30
# 25  1900          positive    37
# 26  1901          negative     5
# 27  1901          positive     6

# %%
def add_value_labels(ax, spacing=5):
    """Add labels to the end of each bar in a bar chart.

    Arguments:
        ax (matplotlib.axes.Axes): The matplotlib object containing the axes
            of the plot to annotate.
        spacing (int): The distance between the labels and the bars.
    """

    # For each bar: Place a label
    for rect in ax.patches:
        # Get X and Y placement of label from rect.
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2

        # Number of points between bar and label. Change to your liking.
        space = spacing
        # Vertical alignment for positive values
        va = 'bottom'

        # If value of bar is negative: Place label below bar
        if y_value < 0:
            # Invert space to place label below
            space *= -1
            # Vertically align label at top
            va = 'top'

        # Use Y value as label and format number with one decimal place
        label = str(y_value)

        # Create annotation
        ax.annotate(
            label,                      # Use `label` as label
            (x_value, round(y_value)),         # Place label at end of the bar
            xytext=(0, space),          # Vertically shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            ha='center',                # Horizontally center label
            va=va,fontsize=15
            )                      # Vertically align label differently for
                                        # positive and negative values.

# %%
def year_plot_sent(x,x2):
  barWidth = 0.25
  fig, ax = plt.subplots(figsize =(24, 9))

  pos = x#letters_sent_year[letters_sent_year['sentiment_sentita'] == 'positive']['text']
  neg = x2#letters_sent_year[letters_sent_year['sentiment_sentita'] == 'negative']['text']
  br1 = np.arange(len(neg))
  br2 = [x + barWidth for x in br1]
  #br3 = [x + barWidth for x in br2]
  t = plt.bar(br1, neg, color ='b', width = barWidth,
          edgecolor ='grey', label ='Negative')
  plt.bar(br2, pos, color ='r', width = barWidth,
          edgecolor ='grey', label ='Positive')

  #plt.bar(br3, CSE, color ='b', width = barWidth,
  #        edgecolor ='grey', label ='CSE')


  # Adding Xticks
  plt.xlabel('Year', fontweight ='bold', fontsize = 15)
  plt.ylabel('Number of negative/positive letters', fontweight ='bold', fontsize = 15)
  plt.xticks([r + barWidth for r in range(len(pos))],
          letters_sent_year.year.unique())



  # Call the function above. All the magic happens there.
  add_value_labels(ax)
  plt.legend()
  plt.show()

# %%
x= letters_sent_year[letters_sent_year['sentiment_sentita'] == 'positive']['text']
x2 = letters_sent_year[letters_sent_year['sentiment_sentita'] == 'negative']['text']
year_plot(x = x, x2 = x2)

# %%
letters_emo_year  = letters_text_pred.groupby(['year', 'emotion_sentita'],as_index = True).count().unstack(fill_value=0).stack()['text'].reset_index()

# %%
letters_emo_year
# Out:
#     year emotion_sentita  text
# 0   1888           anger     0
# 1   1888            fear     0
# 2   1888             joy     3
# 3   1888         sadness     2
# 4   1889           anger     0
# 5   1889            fear     1
# 6   1889             joy     6
# 7   1889         sadness     1
# 8   1890           anger     0
# 9   1890            fear     0
# 10  1890             joy     4
# 11  1890         sadness     6
# 12  1891           anger     2
# 13  1891            fear     1
# 14  1891             joy     1
# 15  1891         sadness     5
# 16  1892           anger     2
# 17  1892            fear     3
# 18  1892             joy    19
# 19  1892         sadness    10
# 20  1893           anger     3
# 21  1893            fear     5
# 22  1893             joy    28
# 23  1893         sadness    15
# 24  1894           anger     0
# 25  1894            fear     0
# 26  1894             joy    20
# 27  1894         sadness    17
# 28  1895           anger     2
# 29  1895            fear     1
# 30  1895             joy    13
# 31  1895         sadness    15
# 32  1896           anger     2
# 33  1896            fear     0
# 34  1896             joy    32
# 35  1896         sadness    18
# 36  1897           anger     0
# 37  1897            fear     0
# 38  1897             joy    18
# 39  1897         sadness    21
# 40  1898           anger     2
# 41  1898            fear     2
# 42  1898             joy    27
# 43  1898         sadness     9
# 44  1899           anger     5
# 45  1899            fear     3
# 46  1899             joy    35
# 47  1899         sadness    19
# 48  1900           anger     3
# 49  1900            fear     3
# 50  1900             joy    37
# 51  1900         sadness    24
# 52  1901           anger     0
# 53  1901            fear     0
# 54  1901             joy     7
# 55  1901         sadness     4

# %%
def year_plot_emo(x,x2,x3,x4, names = None):
  barWidth = 0.20
  fig, ax = plt.subplots(figsize =(24, 9))

  joy = x 
  fear = x2
  sadness = x3
  anger = x4

  if names is None:
    names = []
    names.append('Joy')
    names.append('Fear')
    names.append('Sadness')
    names.append('Anger')
  else:
    names = names
  br1 = np.arange(len(joy))
  br2 = [x + barWidth for x in br1]
  br3 = [x + barWidth for x in br2]
  br4 = [x + barWidth for x in br3]

  plt.bar(br1, joy, color ='yellow', width = barWidth,
          edgecolor ='grey', label =names[0])
  plt.bar(br2, fear, color ='gray', width = barWidth,
          edgecolor ='grey', label =names[1])
  plt.bar(br3, sadness, color ='b', width = barWidth,
          edgecolor ='grey', label =names[2])
  plt.bar(br4, anger, color ='r', width = barWidth,
        edgecolor ='grey', label =names[3])

  
  # Adding Xticks
  plt.xlabel('Year', fontweight ='bold', fontsize = 15)
  plt.ylabel('Number of {}/{}/{}/{} letters'.format(names[0],names[1],names[2],names[3]), fontweight ='bold', fontsize = 15)
  plt.xticks([r + barWidth for r in range(len(pos))],
          letters_sent_year.year.unique())
  # Call the function above. All the magic happens there.
  add_value_labels(ax)
  plt.legend()
  plt.show()

# %%
x = letters_emo_year[letters_emo_year['emotion_sentita'] == 'joy']['text']
x2 = letters_emo_year[letters_emo_year['emotion_sentita'] == 'fear']['text']
x3 = letters_emo_year[letters_emo_year['emotion_sentita'] == 'sadness']['text']
x4 = letters_emo_year[letters_emo_year['emotion_sentita'] == 'anger']['text']
year_plot_emo(x,x2,x3,x4)

# %% [markdown]
# <hr>
#
#
#
# <br>
# <br>
#
# # Neural Networks Model Results
#
# <br>

# %%
pred_sent_grouped[pred_sent_grouped.index == 'positive']
# Out:
# pred
# positive    95
# dtype: int64

# %%
pred_sent_grouped =  letters_text_pred.groupby("pred").size()
pred_sent_grouped = pred_sent_grouped.sort_values(ascending=False)

# %%
pred_sent_grouped
# Out:
# pred
# negative    288
# positive     95
# neutral      70
# both          3
# dtype: int64

# %%
plot_freq(pred_sent_grouped.index, pred_sent_grouped.values)

# %%
pred_binary_sent_grouped = letters_text_pred.groupby("pred_binary").size()

# %%
plot_freq(pred_binary_sent_grouped.index, pred_binary_sent_grouped.values)

# %%
letters_sent_year_binary  = letters_text_pred.groupby(['year', 'pred_binary'],as_index = False).agg('text').count()

# %%
x = letters_sent_year_binary[letters_sent_year_binary['pred_binary'] == 'positive']['text']
x2 = letters_sent_year_binary[letters_sent_year_binary['pred_binary'] == 'negative']['text']
year_plot(x = x, x2 = x2)

# %%
letters_sent_pred  =  letters_text_pred.groupby(['year', 'pred'],as_index = True).count().unstack(fill_value=0).stack()['text'].reset_index()

# %%
letters_sent_pred
# Out:
#     year      pred  text
# 0   1888      both     1
# 1   1888  negative     3
# 2   1888   neutral     0
# 3   1888  positive     1
# 4   1889      both     0
# 5   1889  negative     3
# 6   1889   neutral     3
# 7   1889  positive     2
# 8   1890      both     0
# 9   1890  negative     4
# 10  1890   neutral     6
# 11  1890  positive     0
# 12  1891      both     0
# 13  1891  negative     4
# 14  1891   neutral     5
# 15  1891  positive     0
# 16  1892      both     0
# 17  1892  negative    18
# 18  1892   neutral     5
# 19  1892  positive    11
# 20  1893      both     0
# 21  1893  negative    30
# 22  1893   neutral     5
# 23  1893  positive    16
# 24  1894      both     0
# 25  1894  negative    27
# 26  1894   neutral     3
# 27  1894  positive     7
# 28  1895      both     0
# 29  1895  negative    21
# 30  1895   neutral     5
# 31  1895  positive     5
# 32  1896      both     0
# 33  1896  negative    41
# 34  1896   neutral     6
# 35  1896  positive     5
# 36  1897      both     0
# 37  1897  negative    27
# 38  1897   neutral     4
# 39  1897  positive     8
# 40  1898      both     1
# 41  1898  negative    21
# 42  1898   neutral     7
# 43  1898  positive    11
# 44  1899      both     0
# 45  1899  negative    43
# 46  1899   neutral     9
# 47  1899  positive    10
# 48  1900      both     1
# 49  1900  negative    40
# 50  1900   neutral    12
# 51  1900  positive    14
# 52  1901      both     0
# 53  1901  negative     6
# 54  1901   neutral     0
# 55  1901  positive     5

# %%
x = letters_sent_pred[letters_sent_pred['pred'] == 'positive']['text']
x2 = letters_sent_pred[letters_sent_pred['pred'] == 'negative']['text']
x3 = letters_sent_pred[letters_sent_pred['pred'] == 'neutral']['text']
x4 = letters_sent_pred[letters_sent_pred['pred'] == 'both']['text']
year_plot_emo(x,x2,x3,x4, names = ['positive',"negative","neutral","both"])

# %% [markdown]
# <hr>
#
#
#
# <br>
# <br>
#
# # Model comparison
#
# <br>

# %%
letters_text_pred
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...          sadness
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# ...                                                       ...  ...              ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [456 rows x 6 columns]

# %%
letters_text_pred[(letters_text_pred['pred_binary'] == "positive") & (letters_text_pred['sentiment_sentita'] == "positive")]
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000039  \nMaestro Puccini\nAlbergo Posta. Reggio Emili...  ...              joy
# CLET000055  \n31 luglio    9\nPrego Sig Maestro\nGiacomo P...  ...          sadness
# CLET000062  \n14 7bre  9\nCaris.o Puccini,\nUrgendoci aver...  ...              joy
# CLET000063  \n25 7mbre   89\nCariss.o Puccini.\nRicevo la ...  ...              joy
# ...                                                       ...  ...              ...
# CLET000768  \nPuccini.\nGrand Hôtel. Bruxelles.\nTito sarà...  ...              joy
# CLET000772  \nPuccini.\nTorrelago.\nBenissimo. Rievviva. S...  ...              joy
# CLET000776  \n21 gennaio 1901\nCaro Giacomo,\nRoma\nTi uni...  ...              joy
# CLET000779  \n10 Marzo      1\nCaro Puccini,\nRicevo la gr...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
#
# [124 rows x 6 columns]

# %%
letters_text_pred[letters_text_pred['pred_binary'] != letters_text_pred['sentiment_sentita']]
# Out:
#                                                          text  ...  emotion_sentita
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# CLET000053  \n18 Luglio     9\nCaris.o Puccini\nE l'indiri...  ...              joy
# CLET000086  \nMilano 23 Ott. 90\r\nCariss.mo Puccini.\r\nI...  ...              joy
# ...                                                       ...  ...              ...
# CLET000781  \nGiacomo Puccini.\nTorrelago\nContento lei co...  ...              joy
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [146 rows x 6 columns]

# %%
letters_text_pred
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...          sadness
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# ...                                                       ...  ...              ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [456 rows x 6 columns]

# %%
notin = letters_text_pred[letters_text_pred['pred_binary'] != letters_text_pred['sentiment_sentita']]
notin
# Out:
#                                                          text  ...  emotion_sentita
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# CLET000053  \n18 Luglio     9\nCaris.o Puccini\nE l'indiri...  ...              joy
# CLET000086  \nMilano 23 Ott. 90\r\nCariss.mo Puccini.\r\nI...  ...              joy
# ...                                                       ...  ...              ...
# CLET000781  \nGiacomo Puccini.\nTorrelago\nContento lei co...  ...              joy
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [146 rows x 6 columns]

# %%
plt.bar(notin.year.unique(), notin.groupby("year").size() / letters_df.groupby("year").size()*100)
# Out:
# <BarContainer object of 14 artists>

# %%
grouped = letters_text_pred.groupby(["pred_binary","sentiment_sentita"]).count()["text"]

# %%
grouped = grouped.sort_values(ascending=False)
grouped
# Out:
# pred_binary  sentiment_sentita
# negative     negative             186
# positive     positive             124
# negative     positive              92
# positive     negative              54
# Name: text, dtype: int64

# %%
grouped.index = grouped.reset_index()["pred_binary"] +"_"+ grouped.reset_index()["sentiment_sentita"]

# %%
grouped
# Out:
# negative_negative    186
# positive_positive    124
# negative_positive     92
# positive_negative     54
# Name: text, dtype: int64

# %%
plot_freq(grouped.index,grouped.values, title="Number of different and same predicted sentiments")

# %%
grouped[grouped['sentiment_sentita'] == grouped['pred_binary']]
# Out:
#   pred_binary sentiment_sentita  text  year  pred  emotion_sentita
# 0    negative          negative   186   186   186              186
# 3    positive          positive   124   124   124              124

# %%
grouped[grouped['sentiment_sentita'] != grouped['pred_binary']]
# Out:
#   pred_binary sentiment_sentita  text  year  pred  emotion_sentita
# 1    negative          positive    92    92    92               92
# 2    positive          negative    54    54    54               54

# %%
pos = len(letters_text_pred[letters_text_pred['pred_binary'] == letters_text_pred['sentiment_sentita']])

# %%
neg = len(letters_text_pred[letters_text_pred['pred_binary'] != letters_text_pred['sentiment_sentita']]
# Out:
#                                                          text  ...  emotion_sentita
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# CLET000053  \n18 Luglio     9\nCaris.o Puccini\nE l'indiri...  ...              joy
# CLET000086  \nMilano 23 Ott. 90\r\nCariss.mo Puccini.\r\nI...  ...              joy
# ...                                                       ...  ...              ...
# CLET000781  \nGiacomo Puccini.\nTorrelago\nContento lei co...  ...              joy
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [146 rows x 6 columns]

# %%
letters_df =  pd.read_pickle('https://github.com/Andreaierardi/sentiment-puccini/blob/main/dataset/puccini_with_predictions.pkl?raw=true')

# %%
letters_df
# Out:
#                     id  ... pred_binary
# CLET000002  CLET000002  ...    positive
# CLET000024  CLET000024  ...    negative
# CLET000026  CLET000026  ...    negative
# CLET000028  CLET000028  ...    negative
# CLET000029  CLET000029  ...    negative
# ...                ...  ...         ...
# CLET000782  CLET000782  ...    positive
# CLET000783  CLET000783  ...    positive
# CLET000784  CLET000784  ...    positive
# CLET000785  CLET000785  ...    positive
# CLET000786  CLET000786  ...    negative
#
# [456 rows x 24 columns]

# %%
f = open("pred_comparison.txt","w")
for index, row in letters_df.iterrows():
    f.write("=======================|  "+"Letter ID: "+index+"  |=======================")
    f.write(row['text'])
    f.write("\n_______________________________\n\n")
    f.write("2-sentiment prediction: "+row['pred_binary']+"\n")
    f.write("SentITA sentiment prediction: "+row['sentiment_sentita']+"\n")
    f.write("4-sentiment prediction: "+ row['pred']+"\n")

    f.write("SentITA emotion detection: "+row['emotion_sentita']+"\n")

    f.write("\n_______________________________\n\n")

# %%
#notequal = letters_df[letters_df['pred_binary'] != letters_df['sentiment_sentita']]

# %%
#list(notequal.iterrows())[100][1]['text']

#import random
#
#check = dict()
#for i in range(50):
#  index = random.randrange(0,len(list(notequal.iterrows())))
#  lett = list(notequal.iterrows())[index][1]['text']
#  id = list(notequal.iterrows())[index][1]['id']
#  print(lett)
#  sent = input()
#  check[id] = sent
#  print("========================== FINE ========================== \n")
  #random.randrange(len(list(notequal.iterrows())))
