# %% [markdown]
# <a href="https://colab.research.google.com/github/Andreaierardi/sentiment-puccini/blob/main/sentiment_Puccini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Puccini by mail**
#
# <br>
# <br>

# %% [markdown]
# ## Project description
#
# In 2024 will be the centenary of the death of Giacomo Puccini, one of the greatest authors of Casa Ricordi.
# The great interest of Puccini is not only linked to his universal notoriety nor to the constant and still current success of his works, but also to his language, rich in Tuscanisms and inventions. The letters of Puccini can be studied from the perspective of sentiment analysis in order to link the text to several aspects of the temperament of Puccini, the moments of depression and discouragement from which he suffered periodically, his insecurity about his own abilities, certain difficulties in the relationship with his librettists.
#
# The Ricordi Archive keeps 381 letters written by Puccini to various recipients of Casa Ricordi, and 1387 letters sent to him by the publishing house. To these are added another 120/130 letters present in the database but not kept in the archive. In total, therefore, it is about 2000 letters to be analyzed.
#
# The project aims at studying the letters with aspect based sentiment analysis techniques in order to extract not only the general sentiment polarity but also specific aspects and opinions that may be associated with the events of the life of Giacomo Puccini.

# %% [markdown]
# ### Dataset
# Provided by the Ricordi Archive [link](https://www.digitalarchivioricordi.com/it/people/display/2/Giacomo%20Puccini)
#
# Evalita 2016 Sentipolc [link](http://www.di.unito.it/~tutreeb/sentipolc-evalita16/index.html)
#
#
# <br>
# <br>
#
# ---

# %% [markdown]
# <br>
# <br>
#
# # Data Retrieval
#
# <br>

# %%
from os import path
from wordcloud import WordCloud

# %%
import requests
import lxml.html as lh
import pandas as pd
from matplotlib import pyplot as plt

# %%
url='https://www.digitalarchivioricordi.com/it/people/display/2/Giacomo%20Puccini?show=100&page='

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stopwords.words('italian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['ad',
#  'al',
#  'allo',
#  'ai',
#  'agli',
#  'all',
#  'agl',
#  'alla',
#  'alle',
#  'con',
#  'col',
#  'coi',
#  'da',
#  'dal',
#  'dallo',
#  'dai',
#  'dagli',
#  'dall',
#  'dagl',
#  'dalla',
#  'dalle',
#  'di',
#  'del',
#  'dello',
#  'dei',
#  'degli',
#  'dell',
#  'degl',
#  'della',
#  'delle',
#  'in',
#  'nel',
#  'nello',
#  'nei',
#  'negli',
#  'nell',
#  'negl',
#  'nella',
#  'nelle',
#  'su',
#  'sul',
#  'sullo',
#  'sui',
#  'sugli',
#  'sull',
#  'sugl',
#  'sulla',
#  'sulle',
#  'per',
#  'tra',
#  'contro',
#  'io',
#  'tu',
#  'lui',
#  'lei',
#  'noi',
#  'voi',
#  'loro',
#  'mio',
#  'mia',
#  'miei',
#  'mie',
#  'tuo',
#  'tua',
#  'tuoi',
#  'tue',
#  'suo',
#  'sua',
#  'suoi',
#  'sue',
#  'nostro',
#  'nostra',
#  'nostri',
#  'nostre',
#  'vostro',
#  'vostra',
#  'vostri',
#  'vostre',
#  'mi',
#  'ti',
#  'ci',
#  'vi',
#  'lo',
#  'la',
#  'li',
#  'le',
#  'gli',
#  'ne',
#  'il',
#  'un',
#  'uno',
#  'una',
#  'ma',
#  'ed',
#  'se',
#  'perché',
#  'anche',
#  'come',
#  'dov',
#  'dove',
#  'che',
#  'chi',
#  'cui',
#  'non',
#  'più',
#  'quale',
#  'quanto',
#  'quanti',
#  'quanta',
#  'quante',
#  'quello',
#  'quelli',
#  'quella',
#  'quelle',
#  'questo',
#  'questi',
#  'questa',
#  'queste',
#  'si',
#  'tutto',
#  'tutti',
#  'a',
#  'c',
#  'e',
#  'i',
#  'l',
#  'o',
#  'ho',
#  'hai',
#  'ha',
#  'abbiamo',
#  'avete',
#  'hanno',
#  'abbia',
#  'abbiate',
#  'abbiano',
#  'avrò',
#  'avrai',
#  'avrà',
#  'avremo',
#  'avrete',
#  'avranno',
#  'avrei',
#  'avresti',
#  'avrebbe',
#  'avremmo',
#  'avreste',
#  'avrebbero',
#  'avevo',
#  'avevi',
#  'aveva',
#  'avevamo',
#  'avevate',
#  'avevano',
#  'ebbi',
#  'avesti',
#  'ebbe',
#  'avemmo',
#  'aveste',
#  'ebbero',
#  'avessi',
#  'avesse',
#  'avessimo',
#  'avessero',
#  'avendo',
#  'avuto',
#  'avuta',
#  'avuti',
#  'avute',
#  'sono',
#  'sei',
#  'è',
#  'siamo',
#  'siete',
#  'sia',
#  'siate',
#  'siano',
#  'sarò',
#  'sarai',
#  'sarà',
#  'saremo',
#  'sarete',
#  'saranno',
#  'sarei',
#  'saresti',
#  'sarebbe',
#  'saremmo',
#  'sareste',
#  'sarebbero',
#  'ero',
#  'eri',
#  'era',
#  'eravamo',
#  'eravate',
#  'erano',
#  'fui',
#  'fosti',
#  'fu',
#  'fummo',
#  'foste',
#  'furono',
#  'fossi',
#  'fosse',
#  'fossimo',
#  'fossero',
#  'essendo',
#  'faccio',
#  'fai',
#  'facciamo',
#  'fanno',
#  'faccia',
#  'facciate',
#  'facciano',
#  'farò',
#  'farai',
#  'farà',
#  'faremo',
#  'farete',
#  'faranno',
#  'farei',
#  'faresti',
#  'farebbe',
#  'faremmo',
#  'fareste',
#  'farebbero',
#  'facevo',
#  'facevi',
#  'faceva',
#  'facevamo',
#  'facevate',
#  'facevano',
#  'feci',
#  'facesti',
#  'fece',
#  'facemmo',
#  'faceste',
#  'fecero',
#  'facessi',
#  'facesse',
#  'facessimo',
#  'facessero',
#  'facendo',
#  'sto',
#  'stai',
#  'sta',
#  'stiamo',
#  'stanno',
#  'stia',
#  'stiate',
#  'stiano',
#  'starò',
#  'starai',
#  'starà',
#  'staremo',
#  'starete',
#  'staranno',
#  'starei',
#  'staresti',
#  'starebbe',
#  'staremmo',
#  'stareste',
#  'starebbero',
#  'stavo',
#  'stavi',
#  'stava',
#  'stavamo',
#  'stavate',
#  'stavano',
#  'stetti',
#  'stesti',
#  'stette',
#  'stemmo',
#  'steste',
#  'stettero',
#  'stessi',
#  'stesse',
#  'stessimo',
#  'stessero',
#  'stando']

# %%
from bs4 import BeautifulSoup

all_letters_name = []
dfs = pd.DataFrame(["ciao"])

page_num = 0
while len(dfs)> 0:
  page_num += 1
  page = requests.get(url+str(page_num))
  soup = BeautifulSoup(page.text, 'html.parser')

  dfs = pd.read_html(page.text)
  dfs = dfs[0]

  fixed_names_list = dfs['Segnatura'].str.replace(r' >', '').to_list()
  all_letters_name += fixed_names_list

# %%
all_letters_name[:10]
# Out:
# ['LLET006891',
#  'LLET011812',
#  'LLET006894',
#  'LLET006895',
#  'LLET006896',
#  'LLET011820',
#  'LLET007441',
#  'LLET007443',
#  'LLET007444',
#  'LLET007442']

# %% [markdown]
#  **It is not possible to use page response because the page return always a page with empty tables**

# %%
len(all_letters_name)
# Out:
# 500

# %%
generic_letter_url = 'https://www.digitalarchivioricordi.com/it/letter/display/'

# %%
import time 
import re
import numpy as np


start_time = time.time()

letters_dict = {}

text_list = []
no_empty_letters = []
for letter_name in all_letters_name:
  letter_url =generic_letter_url+letter_name
  #print(letter_name)
  page = requests.get(letter_url)
  soup = BeautifulSoup(page.text, 'html.parser')
  text_html = soup.find_all('div',{'class':'transcription-text'})
  raw_text= text_html[0].get_text()
  
  if 'letters@archivioricordi.com' in raw_text:
    continue
  nospace_text = raw_text.replace("  ", "")
  letters_dict[letter_name]= dict()
  letters_dict[letter_name]['id'] = letter_name
  letters_dict[letter_name]['text'] = nospace_text

  titles = soup.find_all('div',{'id':'letter-info-top'})
  titles = titles[0]

  titles2 = soup.find_all('div',{'id':'letter-date-place'}) 
  titles2 = titles2[0]
  emit  = np.nan if re.sub('[^A-Za-z0-9]+', ' ', titles.find_all('h4')[0].get_text()).strip() == ''  else re.sub('[^A-Za-z0-9]+', ' ', titles.find_all('h4')[0].get_text()).strip()
  rec = np.nan if re.sub('[^A-Za-z0-9]+', ' ', titles.find_all('h5')[0].get_text()).strip() == ''  else re.sub('[^A-Za-z0-9]+', ' ', titles.find_all('h5')[0].get_text()).strip()
  #titles.find_all('h5')[0].get_text()
  date = titles2.find_all('b')[0].get_text().strip()
  place =titles2.find_all('b')[1].get_text()
  
  letters_dict[letter_name]['emit'] = emit
  letters_dict[letter_name]['rec'] = rec
  letters_dict[letter_name]['date'] = date
  letters_dict[letter_name]['place'] = place

  text_html = soup.find_all('div',{'id':'letter-show-details'})
  stringify  = text_html[0].get_text().split('Lettera titolo')
  other_info = re.sub('[^A-Za-z0-9-\n-\.]+', ' ', stringify[1]).strip().split('\n')
  other_info  = [el for el in other_info if el !='']
  #print(other_info)
  #letters_dict[letter_name]['title_letter'] = other_info[0]
  for index_str in range(1,len(other_info)):
    if "SFOGLIA" not in other_info[index_str]:
      key = ' '.join(other_info[index_str].split(' ')[0:-1]).strip().replace(" ", "_").lower()
      key = re.sub('[^A-Za-z0-9-\_]+', '',key.strip())
      val = other_info[index_str].split(' ')[-1]
      letters_dict[letter_name][key] = val

  divs_metadata = ['letter-show-details-named-people','letter-show-details-named-works','letter-show-details-named-places','letter-show-details-named-teatri','letter-show-details-tipologia','letter-show-details-sottotipologia','letter-show-details-scrittura','letter-show-details-linuga',
                   #'letter-show-details-metadati-fisici'
                   ]

  metadata_dict = {}
  for div in divs_metadata:
    name_key = div.split('letter-show-details-')[1].replace("-","_")

    metadata = soup.find_all('div',{'id':div})
    if div == 'letter-show-details-named-people':
      metadata = metadata[1]
    else:
      metadata = metadata[0]
    filtered_strings = re.sub('[^A-Za-z0-9-\n]+', ' ', metadata.get_text())
    if len(filtered_strings)>1:
      #print(len(filtered_strings))
      #print(div)

      #display(filtered_strings)
      filtered_fields = [field.strip() for field in filtered_strings.split("\n") if field!="" and field!=" "]
      if len(filtered_fields) > 1:
        letters_dict[letter_name][name_key] = [filtered_fields[index_field] for index_field in range(1,len(filtered_fields))]
      if len(filtered_fields) == 1:
        letters_dict[letter_name][name_key] = filtered_fields[0].split(" ")[1]
    else:
      #print("OUTSIDE",div)
      #print(filtered_strings)
      #print(len(filtered_strings))
      letters_dict[letter_name][name_key] = float('nan') 
    #print(nospace_text)
    #text_list.append(nospace_text)
    #no_empty_letters.append(letter_name)
    #cnt+=1
print("Processed", len(all_letters_name), "letters in ",(time.time() - start_time)/60," minutes")

letters_df = pd.DataFrame.from_dict(letters_dict, orient='index')
letters_df

letters_df['date'] = pd.to_datetime(letters_df['date'], format='%d/%m/%Y')
letters_df['year'] = letters_df['date'][0].year
#letters_df['id'] = no_empty_letters

print("Final shape: ", letters_df.shape)
# Out:
# Processed 500 letters in  6.9541923602422075  minutes
# Final shape:  (456, 20)

# %%
letters_df.shape
# Out:
# (456, 20)

# %%
letters_df[letters_df.id == 'LLET001738']['text']
# Out:
# LLET001738    \nSt Agata 17 Giug 1892\nC Giulio\nPiù si va a...
# Name: text, dtype: object

# %%
letters_list = list(letters_df['text'])

# %%
len(letters_list)
# Out:
# 456

# %%
letters_list
# Out:
# ['\nRicordi editore per Puccini\nNapoli\nnon dubito buon volere impresa ma esigete quanto occorre assicurare successo. Oltre cantanti curate molto messa scena intermezzo ridda finale. Sentite consigli qualche distinto pittore onde riuscire scena poetica fantastica. Saluti cordiali\nRicordi\n',
#  "\nMilano 11 Agosto\nSig.r Maestro G. Pucini\nChiasso\nAlbero Pizzameglio. San Simone\n(Svizzera)\nCarissimo Maestro\nIl tempo passa velocemente e bisogna pensare sul serio a preparare tutto quanto occorre per la di Lei opera. Anche oggi mi sono informato, ma con mio dispiacere ho saputo che mancavano ancora parecchi raccordi dei pezzi, una parte del 4° Atto, e così nulla si può completare. I Fratelli Corti sono ritornati per concludere definitivamente, ma io non volli legarmi: giacchè in coscienza non posso fare se non nel giorno in cui Ella mi avrà consegnato completissima la di Lei opera. Debbo quindi rinnovare la preghiera ed insistere perchè presto tale consegna sia un fatto compiuto: e sono persuaso ch'Ella stesso comprenderà l'importanza di tali osservazioni e la gravità del momento.\nIntanto la saluto cordialmente e con tutta amicizia e spero avere occasione di vederla presto\nAffmo Suo\nGiulio Ricordi\n",
#  "\n11 Sett\n\xa0\nCarissimo M° Puccini\nAlbergo Pizzamiglio\nChiasso p. S. Simone\n\xa0\nIl Sig Giulio mi ha incaricato di scriverle che urge la consegna della partitura Edgard intieramente finita. Si compiaccia di farmi sapere quando al più presto potrà consegnarcela.\nIl M° Faccio desidererebbe di udire lo spartito. Siccome egli si trattiene qui fin verso la fine di questo mese aspetto di Lei comandi per combinare un'appuntamento.\nIn attesa, m'è grato ripetermi colla più distinta stima\ndi Lei dev. aff°\npp G. Ricordi c C.\nEug Tornaghi\n",
, più esperto di noi, non dubitò d'approvare l'opera la quale, (ripetiamo, perché è tutto ciò che vi à di più convincente) ci fu anche pagata.\n\xa0 \xa0 \xa0Per noi, dunque, il primo libretto fatto era buono, anzi ottimo. Poteva restarci qualche dubbio sul 4° atto perché non ce lo vedemmo pagato: ma siamo ora rassicurati dalla di Lei tela che lo lascia quasi intatto.\n\xa0 \xa0 \xa0Concludendo: adesso Ella e l'egregio Puccini (il quale, malgrado il primo libretto consegnato sia ottimo come dicemmo, non si sente di musicarlo) ci chiedono di comporne un nuovo, sulla traccia da Loro fornita. Ci professiamo grati della novella fiducia affermataci, e ci dichiariamo pieni di buona volontà per accingerci all'opera, in cui metteremo tutto il nostro povero ingegno e quel po' di pratica di scena che possiamo aver acquisita.\n\xa0 \xa0 \xa0Non rimane quindi che metterci d'accordo sul prezzo. E siccome abbiamo la superbia di ritenerci più\xa0artisti\xa0che\xa0librettisti, siccome professiamo amore per l'arte e amicizia sincera per il nostro collaboratore Puccini e abbiam fede nel suo ingegno; noi speriamo e crediamo che quell'accordo sarà presto raggiunto.\n\xa0 \xa0 \xa0Pertanto, su questo argomento attendiamo - Signor Commendatore - le di Lei pregiate comunicazioni.\n\xa0 \xa0 \xa0Con profondo ossequio\n\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 Devotiss.i\n\xa0 \xa0 \xa0 \xa0 Domenico Oliva\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 Marco Praga\n",
#  "\nMilano, 22 Luglio 1890\nIll. Signor Comm. Giulio Ricordi\n\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0\xa0\xa0Città\n\xa0 \xa0 \xa0 A preg. Sua 22 corr.\n\xa0 \xa0 \xa0 E' pur necessario, se vogliamo intenderci ed arrivare all'accordo che Ella dice di desiderare come noi, ristabilire i fatti.\n\xa0 \xa0 \xa0 Ripetiamo: la\xa0tela\xa0fu approvata dal Maestro. Questo è il punto. Se poi tutti i difetti del libretto compiuto si riducessero alla forma, o per meglio dire alla lunghezza eccessiva, noi saremmo qui pronti a eseguire tagli e modificazioni, anche\xa0gratis, quantunque sappiamo che certe modificazioni se sono appena un po' importanti si usa pagarle comunemente oltre il prezzo convenuto per il libretto. Tant'è vero che a questo genere di lavoro eravamo e siamo disposti, che la 1a\xa0parte del 3° atto fu fatta due volte: che il 4° atto fu fatto tre volte. Né ci siamo lamentati, né abbiamo chiesto alcunché. Abbiamo fatto dunque, e faremmo ancora, tutto il necessario per raggiungere la\xa0musicabilità\xa0di cui ora si lamenta l'assenza.\n\xa0 \xa0 \xa0 \xa0Ma non è ciò che ci si chiede.\xa0Ci si cambia la tela. Si introduce il baritono al 1° atto, per esempio. Che c'entra la forma poetica\xa0sbagliata\xa0con questa innovazione che ci obbliga a rifare di pianta il 1° atto? Si muta la costruzione del 2° atto (che il Puccini in un biglietto che teniamo aveva dichiarato\xa0bellissimo): che c'entra la forma poetica? Si inventa di pianta un nuovo 3° atto mentre, ripetiamo, la\xa0tela\xa0di quello da noi composto era stata approvata: poi, fatto il 3° atto e non piaciuta la 1a\xa0parte, la si era rifatta d'accordo col Maestro e in base alle sue istruzioni.\n\xa0 \xa0 \xa0 \xa0Noi sfidiamo chiunque, (e siam
#  '\nPuccini\nTeatro Real. Madrid.\nEvviva. A rivederci.\nRicordi\n',
#  '\nGenova 31 Marzo 92\nC. Giulio\nGrazie della Mignon e grazie delle notizie Puccini, che non sono quali desideravo! - Malgrado restino buone le note basse, vi è sempre da temere se la voce segua la linea discendente. -\nLa parte è bassa e per me basterebbero queste note dal [esempio musicale]\nDomandate di nuovo a Puccini se queste note sono ancora buone e robuste, e soprattutto se può cantare in quel centro senza stancarsi\nSono di nuovo inchiodato in casa da tre giorni causa il mal tempo: oggi è bello e me ne vado...\nLa Peppina ha avuto per 48 ore le solite nausee senza poter prendere cibo... ah mondo mondo!!\nSaluti a tutti Ad Ad\nGVerdi\n',
#  '\nDOC02173.013CLET002711\xa0Seduta\r\ndel 14 Giugno 1892ore 1½\r\npom.\xa0Presenti: Giulio Ricordi gerente la Società\r\n(voti 2) - Ing. Cav. Luigi Brentano (voti 4) - Cav. F. Gnecchi (voti 1) - E.\r\nBozzotti (voti 1) - Comm. L. Erba (voti 4) - Giuseppe Pisa (voti 2) - Ing.\r\nGustavo Strazza (voti 2). ⎼ Totale voti 16\xa0Ricordi: dà lettura del precedente verbale,\r\nche è approvato.\xa0Pisa: chiede se nell’Atto Sociale non esista\r\nl’obbligo di preavvisare le sedute 8 giorni prima.\xa0Ricordi: non crede, perché in tal caso avrebbe\r\nsempre seguito il disposto: si può verificare.\xa0Dall’Atto Sociale non risulta il detto\r\nobbligo.\xa0Erba: chiede spiegazioni circa I Pagliacci\r\ndel M.o Leoncavallo.\xa0Ricordi: Il M.o Leoncavallo ebbe\r\nincarico dalla ditta di scrivere un opera: I Medici. Vi furono\r\ntrattative avanzate per darla lo scorso anno a Torino: ma essendo opera\r\ngrandiosa e di impegno, quell’Impresa si spaventò. Allora si suggerì al\r\nLeoncavallo di fare un’opera di piccole proporzioni, che poi l’Impresa suddetta\r\navrebbe messo in scena senza difficoltà. Leoncavallo accettò il consiglio, ed anzi\r\nmi diede lettura del libretto, che trovai buono, e lo incitai a musicarlo.\r\nDomandate varie volte notizie, rispose che stava lavorando, e che poi mi\r\navrebbe fatto udire l’opera finita. Non lo vidi per qualche tempo, quindi con\r\ngran sorpresa, essendo assente, lessi la notizia che Leoncavallo aveva venduto I\r\nPagliacci al Sonzogno. Si noti che non poteva vendere, senza prima\r\ninterpellare la Ditta, la quale per contratto aveva il diritto di prelazione.\r\nNel complesso Leoncavallo ha agito indegnamente, sconoscendo anche tutti gli\r\najuti accordatigli\xa0 dalla Casa, quando implorava lavoro.\xa0Pisa: I Medici sono della Casa, quindi\r\nbisogna agire contro Leoncavallo.\xa0Ricordi: Si è sempre a tempo: a dire la verità\r\nil mettersi ancora in mano ad avvocati, mi fa spavento, e non so se convenga\r\nspendere danari per questo fatto: mi fu parlato di una possibilità di\r\naccomodamento: se non si riescirà, allora incaricherò l’avvocato dei passi\r\nnecessari, anche per non lasciare lettera morta un patto contrattuale.\xa0Gnecchi = Desidererei che fossero più\r\nfrequenti le sedute, onde i Soci avessero maggiori informazioni: per esempio si\r\nè concor
#  '\nGiacomo Puccini.\nTorrelago\nContento lei contenti tutti lasciando dirigere magari dal mio ciabattino.\nSaluti cordiali.\nGiulio Ricordi\n',
#  '\nPuccini.\nTorrelago.\nCasa Palermo avvisami Laganà telegrafolle invitandolo cola prove Tosca. Crederei utilissima sua presenza per prove musicali sceniche. Tosca fu troppo lasciata balìa Imprese Direttori. Palermo parmi valga pena diretta sorveglianza autore. Spero anche possa darmi buone notizie salute Signor Edgar fino adesso di ignota dimora\nSaluti\nRicordi\n',
#  "\n18 Marzo 1901\nIllustre Maestro\nComm.e G. Puccini\nPisa per Torre del Lago\nCarissimo Maestro, D'incarico dell'ega Siga\xa0Elvira Le rimettiamo quì acclusa la somma di £ 500. che addebitiamo alla di Lei partita.\nAugurandole buon viaggio La salutiamo caramente\ndevot aff\n",
#  '\nMaestro Puccini\nTorre del Lago\nCome sa tenevasi precedenza impegno per Pagliano. Pozzali Corti non intendono rinunciarvi e stanno formando Compagnia modo assicurare ottima esecuzione. Telegrafi da Palermo notizie che auguro eccellenti. Buon viaggio Cordiali saluti.\nRicordi\n',
#  '\nMaestro Puccini\nTeatro Massimo. Palermo\nSono lieto avvertirla combinato Tosca Pagliano con Mugnone Bianchini Bassi Camera. Spero costì prove procederanno bene. Cordiali saluti.\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Giulio Ricordi\n',
#  '\nRicordi editore per Maestro Puccini.\nPalermo\nNuovo trionfo Tosca ne allieta immensamente. Con tutto cuore riprendo le antiche grida di Viva Doge sperando che la cortese firma del suo telegramma jeri risponda a verità e che quel carissimo suo ritorni veramente mio come nel rimpianto passato. Converrà rimanere per le tre Serate approvo poi sua gita Napoli. Ancora viva.\nRicordi\n']

# %% [markdown]
# <br>
# <br>
#
#
# # **Data Analysis**#

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

stopwords.words('italian')

# %%
#letters_df = pd.read_pickle('https://github.com/Andreaierardi/sentiment-puccini/blob/main/dataset/puccini.pkl?raw=true')
#letters_list = list(letters_df['text'])

# %%
for i in letters_list:
  if "salute" in i:
    print(i)
# Out:
# 31 luglio    9
# Prego Sig Maestro
# Giacomo Puccini
# Chiasso  p
# Pizzameglio
# In possesso della preg. sua da Monaco diretta al ns Sr Blanc ci affrettiamo rimetterle qui accluso un vaglia sull'Ufficio postale di Cernobbio per la somma di
# £200- in saldo della solita mensilità.
# Nella speranza che avrà fatto buon viaggio e si troverà in perfetta salute, ci è grata l'occasione per ripeterci
# suoi dev affi
# pp. G. Ricordi e C.
# Eug Tornaghi
#
#
# Milano 23 Ott. 90
# Cariss.mo Puccini.
# Il mio silenzio non significa ch'io non mi sia occupato di lei! ... al contrario, ho invece lavorato e fatto sedute anche con Leoncavallo - e qui le mando il frutto del lavoro- Credo utile ch'Ella lo veda prima, lo studi e se le va, può rimandarmelo che allora lo sottoporrò all'Oliva. Ora mi pare ben disegnato il duetto fra Manon e Renato e la chiusa proceda rapida e chiara.
# Press'a poco così [versi organizzati in una specie di tabella]:
# Rodolfo   |    Marcello              |   Mimi
#               |      No.                   | (ascolta ansiosamente Rodolfo)
#               |                              | Che vuol dire?
#               | (accenna a Rodolfo |  (quasi con un grido depresso)
#               |  di parlar piano)      |
#               |     Bada!                 | Morire!....
#               | (cerca di allontare   | (angosciata)
#               |   Rodolfo)               |
#               |   Vieni!..                 | ...ma insieme!..
#               | (addolorato prega   | (singhiozzando)
#               |  Rodolfo di non più  | Addio, speme!.
#               |      proseguire)        |
# Ella vede che in tal modo la scena è evidente. Del resto Illica è costi: e potrà con didascalie migliori delle mie, meglio spiegare la situazione.
# Dall'amico Illica poi ricevo stamane un letterone-capolavoro, che destino al mio Album d'autografi, poiché rimanga a commento storico della fantasia d'un poeta, unita a quella d'un maestro!!.... La descrizione Illiaca mi ha messo addosso una voglia matta di fare una visita al Castellaccio!... Quando?... ora non lo saprei: ma troverò fuori due o tre giorni prima della fine della campagna per venire ad inchinare il Doge e fare una corte spietata alla Dogaressa Elvira 1a!.
# e spero in qualche cascinale pittorico, che mi darà pretesto ad un pajo d'acquarelli da far impallidire Gignous, Sala & C.ri!!.
# e che saranno degni della Bohème. Ma....non creda ch'io mi mova pel Castellaccio!...anche oggi Illica nella sua lettera mi rompe le scatole con questo Atto 3°---- che proclama una meraviglia!.
# Oh!...poffarbaccone....ed io dovrei starmene a lungo assai così a bocca asciutta?...no, no!.
# Udrò ancor io questa meraviglia: Ma intanto gioisco di questo crescit eundo , che prepara il 4°; quello poi farà sdilinquire.... ne sono certo, e già fin d'ora grido:
# Evviva il Doge!
# Evviva l'Artigliere!...
# Evviva Puccini I° ed unico!
# e Crepino....chi so io....ma sono parecchi!!.
# Dunque a rivederci - in ogni modo un ritrovo con Lei è utile a necessario, che molto avremo a dire, ragionare, discutere dopo non breve assenza.
#  E pensando ai due Atti che ho quì (il 2° è già inciso tutto, ma non importa per la modificazione al fine settimino: saranno un pajo di lastre a rifare) - pensando dunque a 1° o 2° - pensando al 3° in gestazione, poi al 4° che attende opportuno coito, sento il bisogno d'abbracciarla..... ma non le nascondo che preferisco abbracciare la S.a Elvira, il che faccio con grande piacere, incaricandola però di ripassare costantemente l'abbraccio al Doge. Saluto la bella Fosca, lieto di saperla in ottima salute, mando cordiale stretta di mano al poeta Cesareo, ed altra a Lei.
# Aff Suo
# Giulio Ricordi
#
#
# Maestro Puccini.
# Torrelago.
# Dolentissimo notizie sua salute. Speriamo tutti presto guarito raccomandando riguardi. Stia fiducioso per Torino ove Delucia impossibile per pretese ed inutile mentre utilissimo Napoli. Spero presto completate le quattro buone compagnie fatto nuovo in arte. Prego rispondere mio telegramma jeri. Aspetto ansioso partitura anche perché mi sarà prova sua guarigione. Ritorni presto Cordiali saluti.
# Ricordi
#
#
# (R.P.)
# Maestro Puccini
# Torrelago.
# Ricevuto porzione partitura e metronomi. Grazie. Appena può mandi altre porzioni che mangeremo subito. Desideriamo notizie sua salute.
# Ricordi
#
#
# Maestro Giacomo Puccini.
# Torrelago.
# Per le opere Wagner, comunicai quanto scrivi a Campanari: esso è della mia opinione: cioè che le opere sieno di dominio pubblico in Inghilterra = ma che vi sia un certo pericolo per una Casa, che fondamentalmente è italiana, il ristampare dette opere sotto la forma del pubblico dominio: in ogni modo è cosa da studiarsi e da discutersi di presenza.
# Ho passato a Gazzetta il manoscritto, e gli spediranno i 50 estratti.
# Anche a Como la Bohéme ha riportato un successo strepitoso, davanti a un pubblico da Scala: ed a proposito di Scala, preparati a divertirti colla messa in scena del Crepuscolo, perchè io non voglio ammalarmi d’indigestione.
# Avendo scritto a Puccini ed a Mascagni ho fatto loro cenno di quanto mi scrivi per essi.
# Sta bene per Pavone, il quale avrà dunque le 6 £s settimanali.
# Mi hai spedito the ed impenetrabile?.... Prima che tu lasci Londra vorrei darti altra commissione: ho provato quei cartoncini per acquerelli, e sono eccellenti, ben superiori ai soliti blok = anzi te ne spedirò uno che feci per prova - le 2 marche R. N. che segnano la grana, sono buone tutt’e due: vorrei sapere i prezzi e se ve ne sono di formato più grande dei campioni speditimi, così ne farei una certa scorta, che io ne consumo molti.
# Tornaghi parte per la campagna alla fine di questa settimana: di solito la partenza di lui è segnale di pioggia!!! ma la stagione fu sino ad ora tanto orribile, ch’io spero sarà il contrario, il che gli auguro.
# Spero che tu e Cricrì starete benissimo: vi abbraccio con tutto l’affetto.
# Tuo Papà
# [post-scriptum] Saluti a Pawon esq.!
#
#
#
#
#
#
#
#
# 3 7mbre 96
# Caro Puccini,
# In possesso della grad.\a/ tua ti ringrazio anzitutto della tua premura per la mia salute. Ora sto molto meglio: ma di tanto in tanto la tosse mi si fa ancora sentire. Speriamo che se ne vada presto del tutto.
# Ho disposto subito per la rinnovazione del porto d'armi e spero domani di potere spedirtelo.
# In pacco postale ti ho fatto spedire N.° 6 copie Bohème per i soliti omaggi: ritengo ti basteranno. Colgo quest'occasione per compiegarti la solita mensilità, pregandoti di rimandarmi firmata l'acclusa quittanza. Il Sig Giulio attende ansiosamente una risposta alla sua ultima dovendosi in questi giorni decidere per l'affare Edgar a Napoli.
# Tanti cordiali saluti dal Sr Giulio e da tutti noi ed una stretta di mano dal
# tuo aff° amico
# C. Blanc
# Ho creduto bene di indirizzare il pacco postale contenente gli spartiti Bohème al Teatro del Giglio per non darti il fastidio di portarli tu a Lucca.
#
#
# Carissimo sig Giulio
# Torre del Lago 4.11.1896
# Viva dunque il second'atto riveduto e riguardato ripulito e congedato (?) per gli sgorbi del Puccini.
# Il 3° verrà veramente stupendo - c'è tutto che lo fa sperare-
# La salute è ottima niente artrite, niente febbri, niente dolori - Acqua da tutte le parti e dirò con brusio = desinit in piscem - ci manca poco! ciò non ostante si sta benone - caccia poca - ma a giorni ritorno in maremma a farne una scorpacciata
# Il lavoro incomincia per davvero - getto le basi con molta cautela (bagolone) e spero bene. Sarò a Milano alla fine di novembre e allora discuteremo proficuamente secondo il solito. -
# Fui a Firenze dove sentii una buona Manon - sabato andrà Bohème. Peccato davvero che Mugnone non si sia potuto avere alla Scala! assistei ad una prova e l'assicuro che l'esecuzione è splendida - salvo la Musetta, una certa Castagnoli che mi par cosa povera assai - vedremo come riuscirà davanti al pubblico. Tenga d'occhio per la Scala il basso Galli per Schaunard ottimo.
#                                                        -----------------------
# Quel Vanzo mi toglie il sonno!
#                                                        -----------------------
# Sapesse quanto ci penso!
#                                                         -----------------------
# Pensi un pò alla Bohème di Roma come scrissi al sig Tornaghi. Tanti saluti da Elvira e mi creda suo aff
# Giacomo Puccini
#
#
# Maestro Puccini
# Hôtel Nord   Firenze
# Gorga trovasi qui eccellente salute scritturato Venezia. Arrivederci Cordiali saluti nome tutti
# Ricordi
#
#
# E 1. Giugno 97.
# Caro Puccini.
#               A due lettere sue: se tardai un giorno a risponderle, era per avvertirla che oggi stesso le spedisco la copia del 1° Atto, con tutti i rimaneggiamenti, correzioni, aggiunte, varianti, tagli, didascalie, ecc. ecc. ecc –
# Le spedii pure le tazzine pel caffè alla turca: sono le più piccole che trovai da Ginori: volevo aggiungerci una Odalisca, ma non mi riuscì trovarla.... pensai anche alle unghie della signora Elvira, ed allora dismisi il pensiero!
# Ho riletto il 1° Atto: mi pare proprio perfetto, chiaro, logico: è di questo parere anche Leoncavallo, al quale lo comunicai, premendomi conoscere l’opinione di così grand’uomo! – Anzi, per non irritarlo maggiormente, credo sia meglio lasciargli dire tutte le bricconate che vuole, senza più altro occuparsi di lui.
# A Tamagno non ci pensi: invece riprenda il treno Tosca, almeno per mettere ancora un po’ di carbone nella macchina, prima di andare a Berlino.
# Spero si saranno divertiti a Venezia e che ora si troveranno tutti in eccellente salute nelle delizie capuane di Tordellago - Una affettuosa stretta di mano
#                                                                        dal Suo Giulio Ricordi
#
#
# Assicurata   6 luglio 97
# Caro Puccini,
# Sono in possesso delle grad tue del 4.
# Qui accluso ti rimetto un chèque su coda Banca per l'importo di f.i 200- pari a £441.- che ti addebitiamo a partita.
# Per posta ti mando le copie che desideri della Gazzetta.
# Sembra finalmente che l'affare del Dal Verme si combini con Toscanini: ma nulla di sicuro finora causa i tentennamenti di Piontelli...
# Molte furono le richieste di Bohème per la provincia: Siena - Asti - Rovigo - Novi - Este - Carpi. Urbino etc, ma finora non vennero combinate che queste due ultime Piazze oltre Genova e Dal Verme come tu già sai.
# Il Sr Ing. Tito non sa nulla della Bohème N°2 a Berlino: scrivendo al Sr Bock ce ne informeremo: del resto tutto è possibile per.... certa gente!
# Già da due giorni abbiamo spedito al Sr Dürer a Ostenda 2 copie di tutti i pezzi pubblicati per Banda su Manon e Bohème.
# Il M° Verdi è a Milano e per fortuna in ottima salute.
# Gradisci i più cordiali saluti di tutti noi ed in modo particolare del S.r Giulio e del Sigr Tornaghi e del tuo sempre aff°
# amico C. Blanc
# In tutta confidenza ti avverto che Zeni iersera piacque poco nel Lohengrin; io, già dopo la prova generale, parlando con Gatti-Casazza avevo fatto grandi riserve sul tenore per la Tosca - dovendo tu solo decidere in via definitiva, vedi quanto è urgente la tua presenza a Milano. Intanto mi parrebbe saggio che tu sondassi De Marchi perché non pigli impegni per la quaresima, senza dirgli di cosa si tratta. Iermattina ho veduto Toscanini alla Scala; mi ha comunicato la lista delle seconde parti che mi pare vadi bene - ho però risposto che bisogna aspettare la tua prossima venuta per decidere in via definitiva. Il pastorello sarà quello di Roma. L'aumento del Coro pel Te Deum è stato approvato puranche dal Toscanino e sarà fatto.
# Iermattina ho pure segnato coi pittori le piante delle scene sul palcoscenico - il panorama dell'ultimo atto avrà l'ampiezza di quello della Manon, cioè terrà tutto il palco in lungo e in largo. Avendo tenuta più ampia la chiesa, con maggiore intervallo fra la cancellata e l'abside, ho pensato anche di aumentare il numerativo della marcia. Ho letto sul Corriere delle feste a te fatte dall'Ortografia - evviva! evviva!
# Auguri per domani sera - telegrafa martedì mattina al pappà coll'indirizzo di via Borgonuovo; gli farai un vero regalo.
# Arrivederci presto.
# tuo aff°
# Tito
#
#
# 26 luglio 1900
# Illustre Maestro
# Com. Giacomo Puccini
# Pisa per Torre del Lago
# Racc.
# Cariss° amico M° Puccini,
# Confermandole il nostro telegramma colla notizia dello splendido esito della quarta rappresentazione Tosca a Londra, formiamo la presente per compiegarle:
# l'estratto del di Lei conto a tutto giugno u.s. per l'importo complessivo di £ 27264.09 di cui £ 8500- versate all'ega SigaElvira, £10.000- a Lei e £ 8764.09 che troverà qui accluso in diversi Boni Ba Italia, come a distinta in calce alla presente.
# la ricevuta per le suddette £ 8764.09 che vorrà ritornarci debitamente quittanzata, e l'estratto conto vendita del di Lei pezzo: E l'uccellino! da cui risulta un saldo a di Lei favore di £ 17.40 che Le accreditiamo a partita. Dovendo mandare il resoconto vendita anche all'autore delle parole favorisca farci tenere l'indirizzo del Sig. R. Fucini, non sapendo dove si trovi.
# Il ns Sigr Com. Giulio è da due giorni obbligato a letto per un fortissimo reuma al braccio destro che lo fa soffrire assai. Speriamo sia cosa passeggiera [sic] affinché egli possa presto recarsi in Svizzera per la cura prescrittagli dal dottore, della quale ha tanto bisogno.
# Augurandole un pò di fresco ed ottima salute, La preghiamo di gradire unitamente alla gentile di Lei famiglia i nostri più cordiali ed affettuosi saluti e di crederci sempre colla solita stima ed amicizia
# di Lei devoti affi
# pp G Ricordi e C
# Eug Tornaghi
# Elenco Boni Ba Italia contenuti nella presente:
# 1. N° 009523 C Milano 26/7 £1000-
# 1.  "  009524  "     "        "       " 1000-
# 1.  "  009525  "     "        "       " 1000-
# 1.  "  009526  "     "        "       " 1000-
# 1.  "  003821  " Napoli 21/7   " 1000-
# 1.  "  003822  "     "        "       " 1000-
# 1.  "  243121         "    23/7    " 1000-
# 1.  "  004831 B Milano 26/7  "   500-
# 1.  "  000763 A Padova 14/7  "  200-
# 1.  "  109120    Treviso 23/7  "  300-
# 1.  "  506279    Milano  28/7  " 764.09
#                                          £    8714.09
#
#
# 18 agosto 1900
# Carissimo Puccini,
# Ricevo la grad. tua c.p. d'jeri e ti faccio subito mandare per posta 6 libretti e 2 copie piano e canto Tosca.
# Il Sigr Giulio è sempre a Schöneck (Lago dei 4 Cantoni) ove si fermerà per tutto il corrente mese. Scrive oggi che da tre o quattro giorni sente un marcato giovamento nella sua salute. Speriamolo!
# Cordiali saluti dall'eg. Sigr Tornaghi ed una forte stretta di mano
# dal tuo aff°
# C. Blanc
# §  All'atto di chiudere la presente ricevo l'altra tua cartolina d'jeri e ti faccio spedire anche le Sinfonie Beethoven.
# Di nuovo aff
# C.B.
#
#
# Puccini.
# Torrelago.
# Casa Palermo avvisami Laganà telegrafolle invitandolo cola prove Tosca. Crederei utilissima sua presenza per prove musicali sceniche. Tosca fu troppo lasciata balìa Imprese Direttori. Palermo parmi valga pena diretta sorveglianza autore. Spero anche possa darmi buone notizie salute Signor Edgar fino adesso di ignota dimora
# Saluti
# Ricordi

# %%
text = (" ").join(letters_list)

remove = ['il',	'lo',	'la',	'l',	'i',	'gli',	'le',"pel",
'di'	,'del',	'dello',	'della',	'dell',	'dei'	,'degli'	,'delle',
'a',	'al'	,'allo',	'alla',	'all',	'ai',	'agli',	'alle',
'da',	'dal',	'dallo',	'dalla',	'dall',	'dai',	'dagli',	'dalle',
'in',	'nel'	,'nello',	'nella',	'nell',	'nei',	'negli',	'nelle',
'su',	'sul',	'sullo',	'sulla'	,'sull'	,'sui',	'sugli'	,'sulle',"proposito", "benissimo",
'se', 'si', 'mi', 'quale', 'mio','molto','tanto','Ma',"vero","credo","mai","occore","sapere","risposta","occorre","tale","far","ordine","speriamo","possesso","caso","va","pp","piacere","aspetto","gran","possa","cordialissimi","conto","auguro","Evviva","nome","cose","deve","dire","mando","utile","aff","fino","Gerente","momento","Carissimo","volta","Ditta","verso","possibile","cose","allora","troppo","altri","Soci","potrà","posso","notizie","fine","può","tre","cordiali","Saluti","buona","sera","ritorno","perchè","stato","dare","appena","prove","quel","né","nè","amico","bisogna","libretto","ogni","giorni","essere","colla","certo","stesso","poco","auguri","so","pare", "successo", "contratto","Caro","nuovo","opera","fra","solo", "domani", "tutte", "giorno","senza", 'stretta','mano','Spero','modo','mia','bene', 'così','fatto', 'subito','fare','sempre','sua', 'lei','lui','ciò','che','per','me', 'ad','ed','dopo','vi','quali','dice','grande','altre', 'presto','meglio','quando','quello', 'altro', 'ci', 'cui','poi','te','ma','proprio','Sig','avere','quindi','anche', 'come', 'sono','ora','più','sia','prima','parte','qui', 'tutta','assai','nulla','perché', 'non','fu','due','tu', 'pure','fa','però','qualche', 'col','ne','oggi','quando', 'io', 'tutto', 'dunque', 'ancora', 'ti', 'già','con','ho','cosa','intanto','ha' ]
remove_all = remove + list(stopwords.words('italian'))

wordcloud = WordCloud(max_font_size=50, max_words=40, stopwords=remove_all, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
 
plt.imshow(wordcloud)

# %%
import nltk
nltk.download('words')
words = set(nltk.corpus.words.words())

#sent = "Io andiamo to the beach with my amico."
#" ".join(w for w in nltk.wordpunct_tokenize(sent) \
#         if w.lower() in words or not w.isalpha())
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
words
# Out:
# {'theanthropophagy',
#  'transcend',
#  'vanaprastha',
#  'pachyhymenia',
#  'dotardly',
#  'Caranga',
#  'recorrection',
#  'microtelephone',
#  'physically',
#  'dinoflagellate',
#  'santon',
#  'regression',
#  'sporophoric',
#  'ley',
#  'deprecatingly',
#  'subglottic',
#  'unwinter',
#  'aestheticism',
#  'countenance',
#  'Epilobiaceae',
#  'adamant',
#  'subbase',
#  'hotspur',
#  'univoltine',
#  'epistolography',
#  'goldspink',
#  'countermount',
#  'Platonicism',
#  'revivalistic',
#  'enterosepsis',
#  'haggishness',
#  'reliable',
#  'sigmatism',
#  'yawnups',
#  'linchpinned',
#  'Cassidinae',
#  'bedazzlingly',
#  'procreatrix',
#  'splenectopia',
#  'tunlike',
#  'simonism',
#  'disoccupation',
#  'reanneal',
#  'almsgiving',
#  'bellyman',
#  'benjamin',
#  'tanked',
#  'squdge',
#  'Lophornis',
#  'burele',
#  'anguria',
#  'semiconsciously',
#  'telescopy',
#  'Odontolcae',
#  'copyholding',
#  'oroide',
#  'procyonine',
#  'paedonymy',
#  'Prunaceae',
#  'fruitwise',
#  'Neptune',
#  'greet',
#  'boroughlet',
#  'prolusory',
#  'misderive',
#  'Uskara',
#  'classificator',
#  'invigorate',
#  'Thomisidae',
#  'alkapton',
#  'immersion',
#  'venula',
#  'sicklewort',
#  'hypnosis',
#  'polyemic',
#  'emeer',
#  'redbud',
#  'paltriness',
#  'proboscislike',
#  'pranking',
#  'shyish',
#  'hydroquinol',
#  'sulfamerazine',
#  'thyroparathyroidectomy',
#  'featured',
#  'galeoid',
#  'whom',
#  'shadowfoot',
#  'styracaceous',
#  'bestower',
#  'curlylocks',
#  'tercet',
#  'laughy',
#  'benasty',
#  'limnologic',
#  'pithecanthrope',
#  'aerohydrotherapy',
#  'patellaroid',
#  'triorchis',
#  'familial',
#  'rufter',
#  'diphosphoric',
#  'unrespective',
#  'nonprincipled',
#  'radiothorium',
#  'belugite',
#  'Lichnophoridae',
#  'antidactyl',
#  'bluntish',
#  'vierling',
#  'helplessness',
#  'alypin',
#  'arsino',
#  'inextricably',
#  'synthetism',
#  'chemotherapy',
#  'reester',
#  'incopresentable',
#  'estrogenic',
#  'dimmet',
#  'anisogynous',
#  'headmaster',
#  'disenmesh',
#  'podsolic',
#  'Christianness',
#  'Kurukh',
#  'oligoplasmia',
#  'powerlessness',
#  'societified',
#  'brandling',
#  'unshiplike',
#  'eremitism',
#  'overhighly',
#  'cadaveric',
#  'Vance',
#  'angling',
#  'superingenious',
#  'narrative',
#  'anthropolithic',
#  'witnesser',
#  'knowe',
#  'hecatontarchy',
#  'menosepsis',
#  'rectocolitic',
#  'unpretending',
#  'breakerman',
#  'flaxtail',
#  'governor',
#  'newly',
#  'twalt',
#  'reticulatocoalescent',
#  'monodically',
#  'nonritualistic',
#  'saucerless',
#  'tachygen',
#  'leucoencephalitis',
#  'casually',
#  'abiotic',
#  'preterience',
#  'wholesalely',
#  'binauricular',
#  'carioling',
#  'recontract',
#  'nieveta',
#  'troubadour',
#  'druith',
#  'antipopery',
#  'depopulative',
#  'inguinoabdominal',
#  'servo',
#  'pelargomorph',
#  'interamnian',
#  'counterwill',
#  'inseverably',
#  'enticing',
#  'pseudoblepsis',
#  'firk',
#  'talismanically',
#  'unreverted',
#  'scincoid',
#  'supplicating',
#  'Apostolic',
#  'temporal',
#  'reciprocative',
#  'histogenic',
#  'eupsychics',
#  'lirellous',
#  'debunker',
#  'congratulatory',
#  'flavid',
#  'terebratuline',
#  'panorama',
#  'salpiform',
#  'doggone',
#  'undrab',
#  'erethisia',
#  'factitious',
#  'breadthways',
#  'Coccoloba',
#  'conscriptionist',
#  'reauthentication',
#  'preconsciously',
#  'diplocardiac',
#  'teston',
#  'harebrain',
#  'alicoche',
#  'catfish',
#  'institutionize',
#  'nonreinforcement',
#  'comb',
#  'sowlth',
#  'ghrush',
#  'harman',
#  'competitive',
#  'parnel',
#  'Lonchopteridae',
#  'lucanid',
#  'Breton',
#  'Cobitidae',
#  'apoblast',
#  'scrutator',
#  'Mononchus',
#  'Ricinulei',
#  'blowlamp',
#  'coswearer',
#  'proplasm',
#  'benne',
#  'stomatoscopy',
#  'hepatical',
#  'microphthalmos',
#  'physicality',
#  'unresting',
#  'haematite',
#  'Thomasite',
#  'beckoning',
#  'Castoridae',
#  'ceramography',
#  'convolution',
#  'familiarism',
#  'ghostified',
#  'physicianer',
#  'raptus',
#  'statesmanlike',
#  'chairmaker',
#  'lathhouse',
#  'benzophenone',
#  'diffusibility',
#  'epinastically',
#  'sai',
#  'sphenoethmoidal',
#  'Tyndallize',
#  'contrafocal',
#  'amidid',
#  'chaulmoogra',
#  'hamiform',
#  'reactivate',
#  'tsungtu',
#  'dragoonade',
#  'shillhouse',
#  'vitriolization',
#  'impalpability',
#  'janker',
#  'playsome',
#  'isotrope',
#  'bradyglossia',
#  'Macrosporium',
#  'Mussulmanish',
#  'moodish',
#  'calmant',
#  'facileness',
#  'misdescriptive',
#  'chloride',
#  'everylike',
#  'mewer',
#  'nearsightedly',
#  'Xenophontine',
#  'chemicophysics',
#  'gorbet',
#  'femoral',
#  'Biblicism',
#  'chondroglossus',
#  'amellus',
#  'qualmyish',
#  'cytolysis',
#  'handlike',
#  'homopteran',
#  'satellitory',
#  'silicosis',
#  'mutule',
#  'heretofore',
#  'aortoptosis',
#  'disquiparancy',
#  'unheedingly',
#  'veterinarian',
#  'woven',
#  'wloka',
#  'chrysazol',
#  'knickknackish',
#  'anticeremonialism',
#  'Darwinian',
#  'beneath',
#  'serenify',
#  'tessella',
#  'molehead',
#  'Melampyrum',
#  'aquascutum',
#  'disincrust',
#  'starcraft',
#  'intelligence',
#  'tripestone',
#  'proliturgist',
#  'hysterolith',
#  'lathyrism',
#  'peltatifid',
#  'Albigensian',
#  'bibation',
#  'mulloway',
#  'osteocolla',
#  'erythrodextrin',
#  'theistic',
#  'unwalled',
#  'manufactural',
#  'hydremic',
#  'dimoric',
#  'sectionalist',
#  'evade',
#  'roed',
#  'unflooded',
#  'keelman',
#  'sheer',
#  'trithing',
#  'matricular',
#  'diploplacula',
#  'jawbreakingly',
#  'recoilingly',
#  'superbeloved',
#  'enfolden',
#  'Vaticanization',
#  'basipterygium',
#  'counterconversion',
#  'flueless',
#  'samphire',
#  'embryoplastic',
#  'overbreed',
#  'osculiferous',
#  'polychromasia',
#  'Donet',
#  'steapsin',
#  'feathered',
#  'finalist',
#  'predesolation',
#  'semireticulate',
#  'kamerad',
#  'prediminishment',
#  'terrestrialize',
#  'voeten',
#  'carest',
#  'cometical',
#  'unwatered',
#  'prezygapophysis',
#  'antipleuritic',
#  'Parmentiera',
#  'redescribe',
#  'sabbat',
#  'Athenianly',
#  'chagan',
#  'grainsick',
#  'Germanophobe',
#  'gleyde',
#  'archmagirist',
#  'lieutenancy',
#  'fistuca',
#  'unconfutable',
#  'opticon',
#  'snackman',
#  'acca',
#  'brugh',
#  'hemeralopic',
#  'sixte',
#  'undermediator',
#  'rigamajig',
#  'compliable',
#  'Peratae',
#  'Luchuan',
#  'Protozoa',
#  'findal',
#  'Enterocoela',
#  'borsht',
#  'hypopituitarism',
#  'untimedness',
#  'farsalah',
#  'fanwork',
#  'heptagon',
#  'nonvintage',
#  'streetful',
#  'dystrophic',
#  'mooting',
#  'ancestress',
#  'cosmozoism',
#  'saintology',
#  'neurophysiological',
#  'tidingless',
#  'unconniving',
#  'muscologic',
#  'Trematodes',
#  'weri',
#  'tapalo',
#  'clottedness',
#  'noumenism',
#  'staphylotome',
#  'crawlerize',
#  'oldish',
#  'actor',
#  'myiasis',
#  'quiniretin',
#  'preformulation',
#  'syncretistic',
#  'postresurrection',
#  'lathe',
#  'shrubless',
#  'assassinist',
#  'Monorhina',
#  'oligotrophic',
#  'overscrawl',
#  'pugged',
#  'afterthoughted',
#  'equivocation',
#  'pacable',
#  'Aegean',
#  'hecticness',
#  'quetch',
#  'inoxidable',
#  'overdoze',
#  'paramorphine',
#  'gossiping',
#  'coccous',
#  'Cyrenian',
#  'epistemological',
#  'crepitus',
#  'pipeman',
#  'refract',
#  'reprotection',
#  'scutella',
#  'tacheography',
#  'militarily',
#  'clamorist',
#  'northeasternmost',
#  'submotive',
#  'drank',
#  'regretter',
#  'Romaean',
#  'trunkmaker',
#  'precept',
#  'rubrification',
#  'undoctrined',
#  'Padda',
#  'confesser',
#  'interferant',
#  'Longicornia',
#  'slew',
#  'inspectrix',
#  'unshielded',
#  'hydrophobist',
#  'epistolical',
#  'brotheler',
#  'gaunted',
#  'Closterium',
#  'bayish',
#  'dornick',
#  'rattener',
#  'profeminism',
#  'Leontocebus',
#  'pachynema',
#  'palinuroid',
#  'Agnes',
#  'Hainanese',
#  'unnameably',
#  'unsmacked',
#  'untoiling',
#  'brume',
#  'propterygial',
#  'ironize',
#  'Spaniolize',
#  'mohnseed',
#  'antiperistasis',
#  'commutant',
#  'foilsman',
#  'dendrography',
#  'factiously',
#  'Sporochnus',
#  'santene',
#  'spondaic',
#  'jittery',
#  'nonerroneous',
#  'chromocratic',
#  'pentacosane',
#  'octodecimal',
#  'abdat',
#  'isoalantolactone',
#  'prejudiciously',
#  'nodosariform',
#  'acanthopore',
#  'jutka',
#  'nonretentive',
#  'articulary',
#  'coagent',
#  'want',
#  'escrol',
#  'molybdenite',
#  'omnigenous',
#  'sloo',
#  'ginghamed',
#  'unplotted',
#  'photoinhibition',
#  'Cocle',
#  'speculatrices',
#  'trichosporangium',
#  'autoharp',
#  'Luvish',
#  'gonochoristic',
#  'unascertainableness',
#  'parsonish',
#  'undiscomfitable',
#  'contortion',
#  'fingerparted',
#  'hyperalgebra',
#  'nary',
#  'sprucify',
#  'thyroprivia',
#  'undersill',
#  'unevitably',
#  'Gaffkya',
#  'fairgrass',
#  'wheatear',
#  'dogedom',
#  'electrolyte',
#  'uval',
#  'vaucheriaceous',
#  'oscheocarcinoma',
#  'Czechization',
#  'mundaneness',
#  'ungeneric',
#  'payment',
#  'underflooring',
#  'rayonnance',
#  'raillike',
#  'untangling',
#  'unperused',
#  'discretiveness',
#  'ineffervescence',
#  'accreditation',
#  'scutiferous',
#  'uncellar',
#  'steamerful',
#  'tommycod',
#  'Climacium',
#  'silver',
#  'ultraproud',
#  'autonomy',
#  'sluicer',
#  'rabies',
#  'vaporish',
#  'hyperpiesis',
#  'undeification',
#  'Asclepiadic',
#  'mentonniere',
#  'penetrate',
#  'coeducationalism',
#  'singly',
#  'meteorographic',
#  'thoracical',
#  'hambroline',
#  'specklessly',
#  'lovably',
#  'blueback',
#  'depth',
#  'telegram',
#  'syndication',
#  'recorrect',
#  'degrease',
#  'copolymerize',
#  'mysticetous',
#  'polysyllogistic',
#  'unborough',
#  'lettering',
#  'merit',
#  'linework',
#  'misproduce',
#  'rhinocerial',
#  'whand',
#  'uberousness',
#  'intaxable',
#  'pursuance',
#  'pentapterous',
#  'unassailing',
#  'greeny',
#  'micasize',
#  'Chiltern',
#  'regenerative',
#  'supercentral',
#  'mansioneer',
#  'uncomputably',
#  'bonewort',
#  'Armado',
#  'overset',
#  'pleadingness',
#  'malgovernment',
#  'taborin',
#  'bredbergite',
#  'preceptive',
#  'ideology',
#  'dichronous',
#  'floriferous',
#  'canoeload',
#  'bargainee',
#  'hyposternal',
#  'selihoth',
#  'emmensite',
#  'Helianthoidean',
#  'smore',
#  'choirlike',
#  'connateness',
#  'lactarious',
#  'tuffing',
#  'electrokinetics',
#  'Hydrodamalis',
#  'erythroscope',
#  'penetratingly',
#  'unfactorable',
#  'forecovert',
#  'exhortator',
#  'mimmood',
#  'antihelminthic',
#  'appositionally',
#  'prerequest',
#  'unwarm',
#  'monosiphonic',
#  'nidatory',
#  'bekick',
#  'stabilizer',
#  'compressively',
#  'accusatorially',
#  'detassel',
#  'dendrobe',
#  'Iberism',
#  'ungutted',
#  'grateful',
#  'sirple',
#  'porrection',
#  'confrication',
#  'twinkling',
#  'buccopharyngeal',
#  'reflectional',
#  'inkstandish',
#  'prestigiate',
#  'blacknob',
#  'unhandiness',
#  'ecchondrosis',
#  'nauther',
#  'preconsumer',
#  'somewheres',
#  'ancientry',
#  'extraparochial',
#  'grouser',
#  'Nankin',
#  'unwitch',
#  'cymaphyte',
#  'entreating',
#  'paradromic',
#  'dextrotropous',
#  'goyim',
#  'epicoelian',
#  'Madecase',
#  'latewhile',
#  'penstick',
#  'Characeae',
#  'swatchway',
#  'Biddelian',
#  'gorbellied',
#  'petrol',
#  'strackling',
#  'trifoliolate',
#  'undogmatical',
#  'anthropogeographer',
#  'khir',
#  'roughet',
#  'bagatelle',
#  'vallancy',
#  'southbound',
#  'cantic',
#  'proinjunction',
#  'bullfrog',
#  'pilliwinks',
#  'undecorticated',
#  'potbank',
#  'Tame',
#  'nonfertile',
#  'inosite',
#  'predestruction',
#  'sinistrad',
#  'spongology',
#  'vasodentine',
#  'nuciculture',
#  'basilary',
#  'loyalize',
#  'vestry',
#  'fact',
#  'compatriotism',
#  'rumblegarie',
#  'doublet',
#  'unignominious',
#  'willinghood',
#  'methylator',
#  'bewray',
#  'arsenation',
#  'palaeocrystal',
#  'insomniac',
#  'strontic',
#  'hardily',
#  'undirectly',
#  'budge',
#  'provincialize',
#  'oidiomycotic',
#  'seigneur',
#  'unspectrelike',
#  'sarpler',
#  'theophanic',
#  'behatted',
#  'nauplius',
#  'amphicreatinine',
#  'endobronchial',
#  'subordinal',
#  'mesocaecum',
#  'Chrysopa',
#  'amorist',
#  'amphithecium',
#  'academization',
#  'antikenotoxin',
#  'arsmetrik',
#  'unforbid',
#  'pelick',
#  'abdominoposterior',
#  'Dimna',
#  'homegoer',
#  'lagen',
#  'lucrific',
#  'prancing',
#  'stillroom',
#  'cogitantly',
#  'potential',
#  'carpid',
#  'soullessness',
#  'downbeard',
#  'planigraph',
#  'hipple',
#  'microcosm',
#  'clavolae',
#  'cyclotomy',
#  'ruthfully',
#  'nonvariant',
#  'twofoldly',
#  'boxthorn',
#  'jolty',
#  'arthrodynic',
#  'disfoliage',
#  'oxyhematin',
#  'dateless',
#  'whoosh',
#  'thankful',
#  'starter',
#  'varicolorous',
#  'flexuosity',
#  'nonsiccative',
#  'blastogranitic',
#  'elaioleucite',
#  'homotatic',
#  'undosed',
#  'blendcorn',
#  'planktology',
#  'Macraucheniidae',
#  'azelate',
#  'manakin',
#  'sacrificially',
#  'pervasiveness',
#  'nomenclate',
#  'slyish',
#  'brothy',
#  'incorporeal',
#  'unreducibly',
#  'blepharosymphysis',
#  'imagines',
#  'hyperboreal',
#  'protoprism',
#  'Uintatherium',
#  'lemuriform',
#  'cutlass',
#  'ceride',
#  'clasher',
#  'daubster',
#  'Tommer',
#  'aught',
#  'geggery',
#  'biunity',
#  'snaphead',
#  'nondefilement',
#  'affluent',
#  'gushing',
#  'chirotonsory',
#  'indazine',
#  'fasciolar',
#  'lithangiuria',
#  'courante',
#  'diarchial',
#  'cyclographer',
#  'swordtail',
#  'unbrief',
#  'Savonnerie',
#  'weasel',
#  'cometology',
#  'udasi',
#  'predacity',
#  'hulky',
#  'pommey',
#  'dal',
#  'cerebrose',
#  'pathognostic',
#  'conjugable',
#  'Yin',
#  'omission',
#  'lazyship',
#  'delead',
#  'puggish',
#  'snood',
#  'hydrospire',
#  'amphigony',
#  'hepatatrophy',
#  'Hystrix',
#  'Bowdichia',
#  'honesty',
#  'wolfhood',
#  'tetraptote',
#  'erade',
#  'madder',
#  'Net',
#  'hospitant',
#  'teletherapy',
#  'Owenia',
#  'cadmia',
#  'polygamously',
#  'civility',
#  'cultrate',
#  'fevercup',
#  'capitelliform',
#  'prosodially',
#  'vitriolic',
#  'participiality',
#  'requarantine',
#  'childbed',
#  'catchwater',
#  'praxis',
#  'brocatello',
#  'perfection',
#  'collodium',
#  'pustulated',
#  'rubasse',
#  'dronepipe',
#  'heterofermentative',
#  'similarly',
#  'emerald',
#  'attributable',
#  'Astragalus',
#  'acatalectic',
#  'preadjournment',
#  'cockshy',
#  'tergiversant',
#  'Bullockite',
#  'aliyah',
#  'bacchantes',
#  'conceive',
#  'lyric',
#  'coquito',
#  'phosphor',
#  'expergefacient',
#  'designer',
#  'Chambioa',
#  'dashmaker',
#  'unincreasing',
#  'stresslessness',
#  'curtailed',
#  'outtravel',
#  'projectively',
#  'unforbidding',
#  'pulpitful',
#  'silty',
#  'intestinovesical',
#  'Philip',
#  'photofinish',
#  'Rhamphorhynchus',
#  'dismal',
#  'Pataria',
#  'busman',
#  'cynodont',
#  'torchman',
#  'Corallina',
#  'triseptate',
#  'unpoetized',
#  'phylloptosis',
#  'technicological',
#  'pacemaker',
#  'superspecies',
#  'teratoscopy',
#  'unlured',
#  'Panhellenium',
#  'outpouring',
#  'isovalerianate',
#  'rhymemaker',
#  'inhabitancy',
#  'tidesman',
#  'hippomancy',
#  'infraclusion',
#  'oxycopaivic',
#  'panicked',
#  'ammoniojarosite',
#  'scumfish',
#  'diverge',
#  'navarch',
#  'sacred',
#  'anabiotic',
#  'brisken',
#  'Duhr',
#  'antieugenic',
#  'unnail',
#  'otic',
#  'armorer',
#  'chorda',
#  'doulocracy',
#  'Bakuninism',
#  'Centauridium',
#  'gorgonlike',
#  'subunequal',
#  'immortification',
#  'hippotomical',
#  'antiprohibitionist',
#  'Siceliot',
#  'seedness',
#  'disprobabilization',
#  'mokum',
#  'transinsular',
#  'tenuicostate',
#  'esterification',
#  'unfruitful',
#  'outstandingly',
#  'doodle',
#  'twitchy',
#  'Cyclopean',
#  'Isoetales',
#  'melanian',
#  'semimercerized',
#  'scupful',
#  'porcelainize',
#  'paroophoron',
#  'Phaca',
#  'dioxindole',
#  'calambac',
#  'aerugo',
#  'chanchito',
#  'detumescence',
#  'mispossessed',
#  'pleuroperitonaeal',
#  'ginglymostomoid',
#  'commando',
#  'overconfidence',
#  'bathmic',
#  'parchy',
#  'didelphous',
#  'aphroditous',
#  'hexa',
#  'unbeclouded',
#  'Xiraxara',
#  'acquisible',
#  'parsettensite',
#  'diffusor',
#  'pseudoapoplexy',
#  'thinghood',
#  'cinchotine',
#  'sesquialterous',
#  'graphalloy',
#  'thumbtack',
#  'holochoanoidal',
#  'unlettering',
#  'diotic',
#  'repetitious',
#  'aerocurve',
#  'Unitarian',
#  'stirringly',
#  'adjectivally',
#  'proredemption',
#  'Heritiera',
#  'consolable',
#  'coproducer',
#  ...}

# %% [markdown]
# <br>
# <br>
#
#
# # **Pre-processing data**#

# %%
train = pd.read_csv('https://raw.githubusercontent.com/Andreaierardi/sentiment-puccini/main/dataset/training_set_sentipolc16%203.csv')
train
# Out:
#                idtwitter  ...                                               text
# 0     122449983151669248  ...  Intanto la partita per Via Nazionale si compli...
# 1     125485104863780865  ...  False illusioni, sgradevoli realtà Mario Monti...
# 2     125513454315507712  ...  False illusioni, sgradevoli realtà #editoriale...
# 3     125524238290522113  ...  Mario Monti: Berlusconi risparmi all'Italia il...
# 4     125527933224886272  ...  Mario Monti: Berlusconi risparmi all'Italia il...
# ...                  ...  ...                                                ...
# 7405  135136897000415233  ...  che ci frega di mario monti, noi abbiamo mario...
# 7406  143471916534087680  ...  Strepitoso il titolo in prima di Libero sul go...
# 7407  153955345411219456  ...  @nataliacavalli Consolati, il governo #Monti h...
# 7408  190835515552047104  ...  @SheisCandida beh, beate loro! Io nn possiedo ...
# 7409  193068210763993088  ...  Caro #Renzi,se #Grillo spaccava i computer e o...
#
# [7410 rows x 9 columns]

# %%
def get_sent_feature(df):
  sent = []
  for i, j in df[['opos','oneg', 'text']].iterrows():
    if j['opos'] == 1 and j['oneg'] == 1:
      sent.append(2)
    elif j['opos'] == 0 and j['oneg'] == 1:
      sent.append(-1)
    elif j['opos'] == 1 and  j['oneg'] == 0:
      sent.append(1)
    else:
      sent.append(0)
  return sent

# %%
def get_sent_feature_binary(df):
  sent = []
  for i, j in df[['opos','oneg', 'text']].iterrows():
    if j['opos'] == 1 and j['oneg'] == 1:
      sent.append(2)
    elif j['opos'] == 0 and j['oneg'] == 1:
      sent.append(-1)
    elif j['opos'] == 1 and  j['oneg'] == 0:
      sent.append(1)
    else:
      sent.append(2)
  return sent

# %%
train['sent'] = get_sent_feature(train)

# %%
train_binary = train.copy()
train_binary['sent'] = get_sent_feature_binary(train)
train_binary = train_binary[train_binary['sent'] !=2]

# %%
training_set = train.drop(labels=[ "idtwitter", 'subj','opos','oneg','lpos','lneg', 'top','iro'], axis=1)

# %%
training_set_binary = train_binary.drop(labels=[ "idtwitter", 'subj','opos','oneg','lpos','lneg', 'top','iro'], axis=1)

# %%
training_set
# Out:
#                                                    text  sent
# 0     Intanto la partita per Via Nazionale si compli...    -1
# 1     False illusioni, sgradevoli realtà Mario Monti...    -1
# 2     False illusioni, sgradevoli realtà #editoriale...    -1
# 3     Mario Monti: Berlusconi risparmi all'Italia il...    -1
# 4     Mario Monti: Berlusconi risparmi all'Italia il...    -1
# ...                                                 ...   ...
# 7405  che ci frega di mario monti, noi abbiamo mario...     1
# 7406  Strepitoso il titolo in prima di Libero sul go...     1
# 7407  @nataliacavalli Consolati, il governo #Monti h...    -1
# 7408  @SheisCandida beh, beate loro! Io nn possiedo ...     1
# 7409  Caro #Renzi,se #Grillo spaccava i computer e o...     1
#
# [7410 rows x 2 columns]

# %%
training_set_binary
# Out:
#                                                    text  sent
# %%
test_set
# Out:
#                idtwitter  ...                                               text
# 0     507074506880712705  ...  Tra 5 minuti presentazione piano scuola del go...
# 1     507075789456961536  ...  \@matteorenzi: Alle 10 appuntamento su http://...
# 2     507077511902425088  ...  #labuonascuola gli #evangelisti #digitali non ...
# 3     507079183315787777  ...  Riforma scuola Tutto il discorso di  Renzi su ...
# 4     507080190225563648  ...  .@matteorenzi @MiurSocial #labuonascuola basta...
# ...                  ...  ...                                                ...
# 1938  645372190645481472  ...  Anche prodotti alimentari tipici pugliesi in v...
# 1939  645628412225265664  ...         intensità di vita  https://t.co/jv4aARxzhz
# 1940  645919232367161344  ...  Oggi tutti che iniziano l'università e io sul ...
# 1941  648567080107790336  ...  @GliIntoccabili @nonleggerlo Ma Ferrero? il co...
# 1942  648595040999239680  ...  Non vedi l'ora che venga qui, almeno lo sentir...
#
# [1943 rows x 9 columns]

# %%
test_set['sent'] = get_sent_feature(test_set)

# %%
test_set_binary = test_set.copy()
test_set_binary['sent'] = get_sent_feature_binary(test_set)
test_set_binary = test_set_binary[test_set_binary['sent'] != 2]

# %%
test_set = test_set.drop(labels=[ "idtwitter", 'subj','opos','oneg','lpos','lneg', 'top','iro'], axis=1)

# %%
test_set_binary = test_set_binary.drop(labels=[ "idtwitter", 'subj','opos','oneg','lpos','lneg', 'top','iro'], axis=1)

# %%
test_set
# Out:
#                                                    text  sent
# 0     Tra 5 minuti presentazione piano scuola del go...     0
# 1     \@matteorenzi: Alle 10 appuntamento su http://...     1
# 2     #labuonascuola gli #evangelisti #digitali non ...    -1
# 3     Riforma scuola Tutto il discorso di  Renzi su ...     0
# 4     .@matteorenzi @MiurSocial #labuonascuola basta...     0
# ...                                                 ...   ...
# 1938  Anche prodotti alimentari tipici pugliesi in v...     0
# 1939         intensità di vita  https://t.co/jv4aARxzhz     0
# 1940  Oggi tutti che iniziano l'università e io sul ...     2
# 1941  @GliIntoccabili @nonleggerlo Ma Ferrero? il co...    -1
# 1942  Non vedi l'ora che venga qui, almeno lo sentir...     1
#
# [1943 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.utils import shuffle


x_train = training_set.drop(["sent"],axis=1)
y_train = training_set["sent"]

x_train, y_train =  shuffle(x_train, y_train)
x_train = x_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)


x_train_binary = training_set_binary.drop(["sent"],axis=1)
y_train_binary = training_set_binary["sent"]

x_train_binary, y_train_binary =  shuffle(x_train_binary, y_train_binary)
x_train_binary = x_train_binary.reset_index(drop=True)
y_train_binary = y_train_binary.reset_index(drop=True)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.20)

# %%
x_train_binary, x_valid_binary, y_train_binary, y_valid_binary = train_test_split(x_train_binary, y_train_binary, test_size=0.20)

# %%
x_test = test_set.drop(["sent"],axis=1)
y_test = test_set["sent"]

x_test, y_test =  shuffle(x_test, y_test)
x_test = x_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
x_test_binary = test_set_binary.drop(["sent"],axis=1)
y_test_binary = test_set_binary["sent"]

x_test_binary, y_test_binary =  shuffle(x_test_binary, y_test_binary)
x_test_binary = x_test_binary.reset_index(drop=True)
y_test_binary = y_test_binary.reset_index(drop=True)

# %%
print("Shapes")
print("Train")
print("x_train",x_train.shape)
print("y_train",y_train.shape)
print("")
print("Valid")
print("x_valid",x_valid.shape)
print("y_valid",y_valid.shape)
print("")
print("Test")
print("x_test",x_test.shape)
print("y_test",y_test.shape)
# Out:
# Shapes
# Train
# x_train (5928, 1)
# y_train (5928,)
#
# Valid
# x_valid (1482, 1)
# y_valid (1482,)
#
# Test
# x_test (1943, 1)
# y_test (1943,)

# %%
print("Shapes")
print("Train_binary")
print("x_train_binary",x_train_binary.shape)
print("y_train_binary",y_train_binary.shape)
print("")
print("Valid")
print("x_valid_binary",x_valid_binary.shape)
print("y_valid_binary",y_valid_binary.shape)
print("")
print("Test")
print("x_test_binary",x_test_binary.shape)
print("y_test_binary",y_test_binary.shape)
# Out:
# Shapes
# Train_binary
# x_train_binary (3323, 1)
# y_train_binary (3323,)
#
# Valid
# x_valid_binary (831, 1)
# y_valid_binary (831,)
#
# Test
# x_test_binary (1018, 1)
# y_test_binary (1018,)

# %%
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer

# Custom Transformer (Inheriting from classes)
class CleanText( BaseEstimator, TransformerMixin ):
    
   
    def __init__( self, lang = "italian"):
        self.lang = lang
        self.stemmer = SnowballStemmer(self.lang)
    
       
    def fit( self, X, y = None ):
        return self 
    
   
    def clean( self, x ):
        words   = [self.stemmer.stem(word) for word in word_tokenize(x.lower()) if word.isalpha() and word not in stopwords.words("italian")]
        return " ".join(words)
    
   
    def transform( self, X, y = None ):
        return X["text"].apply(self.clean)

# %%
class CustomFeatures( BaseEstimator, TransformerMixin ):
    
    def __init__( self ):
        return
    
    def fit( self, X, y = None ):
        return self 
        
    def transform( self, X, y = None ):
        f           = pd.DataFrame()
        f['len']    = X['text'].str.len()
        f['digits'] = X['text'].str.findall(r'\d').str.len()
        f['punct']  = X['text'].str.findall(r'[^a-zA-Z\d\s:]').str.len()
        return f[['len','digits','punct']]

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import StandardScaler


pipe = Pipeline([("extract", FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                               ('tfidf', TfidfVectorizer())])),
                                           ("custom", CustomFeatures())])),
                 ("select", SelectKBest(score_func = chi2)),
                 ("scale", StandardScaler(with_mean = False))])

pipe_binary = Pipeline([("extract", FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                               ('tfidf', TfidfVectorizer())])),
                                           ("custom", CustomFeatures())])),
                 ("select", SelectKBest(score_func = chi2)),
                 ("scale", StandardScaler(with_mean = False))])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('extract',
#                  FeatureUnion(transformer_list=[('terms',
#                                                  Pipeline(steps=[('clean',
#                                                                   CleanText()),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())])),
#                                                 ('custom', CustomFeatures())])),
#                 ('select',
#                  SelectKBest(score_func=<function chi2 at 0x7f44cdbaeb00>)),
#                 ('scale', StandardScaler(with_mean=False))])

# %%
pipe_binary.fit(x_train_binary,y_train_binary)
# Out:
# Pipeline(steps=[('extract',
#                  FeatureUnion(transformer_list=[('terms',
#                                                  Pipeline(steps=[('clean',
#                                                                   CleanText()),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())])),
#                                                 ('custom', CustomFeatures())])),
#                 ('select',
#                  SelectKBest(score_func=<function chi2 at 0x7f44cdbaeb00>)),
#                 ('scale', StandardScaler(with_mean=False))])

# %%
X_train = pipe.fit_transform(x_train,y_train)

# %%
X_train_binary= pipe_binary.fit_transform(x_train_binary,y_train_binary)

# %%
X_valid = pipe.transform(x_valid)
X_test = pipe.transform(x_test)
X_letters = pipe.transform(letters_df[['text']])

# %%
X_valid_binary = pipe_binary.transform(x_valid_binary)
X_test_binary = pipe_binary.transform(x_test_binary)
X_letters_binary = pipe_binary.transform(letters_df[['text']])

# %%
# extract features
pipe_extract = FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                 ('tfidf', TfidfVectorizer())])),
                             ("custom", CustomFeatures())])

# select and scale features
pipe_select_scale = Pipeline([("select", SelectKBest(score_func = chi2)),
                              ("scale", StandardScaler(with_mean = False))])


# extract features
# you can also use bi-grams:
X_extract = pipe_extract.set_params(terms__tfidf__ngram_range = (1,2)).fit_transform(x_train, y_train)

X_extract_test = pipe_extract.set_params(terms__tfidf__ngram_range = (1,2)).transform(x_test)

X_extract_letters =  pipe_extract.set_params(terms__tfidf__ngram_range = (1,2)).transform(letters_df[['text']] )
print(X_extract)

X_select_scale = pipe_select_scale.set_params(select__k = 500).fit_transform(X_extract, y_train)
print(X_select_scale)

X_select_scale_test = pipe_select_scale.set_params(select__k = 500).transform(X_extract_test)
print(X_select_scale)

X_select_scale_letters = pipe_select_scale.set_params(select__k = 500).transform(X_extract_letters)
# Out:
#   (0, 5408)	0.13989288391446933
#   (0, 7153)	0.2494956545485103
#   (0, 7154)	0.2494956545485103
#   (0, 9268)	0.2494956545485103
#   (0, 9269)	0.2494956545485103
#   (0, 20833)	0.17090570808542976
#   (0, 20854)	0.2494956545485103
#   (0, 27334)	0.13457005707469727
#   (0, 27356)	0.2494956545485103
#   (0, 33973)	0.23026858154127533
#   (0, 33975)	0.2494956545485103
#   (0, 39048)	0.4481576931155918
#   (0, 39050)	0.2494956545485103
#   (0, 39052)	0.2494956545485103
#   (0, 40372)	0.23824853784064987
#   (0, 40374)	0.2494956545485103
#   (0, 44935)	125.0
#   (0, 44937)	4.0
#   (1, 3670)	0.1173087823112039
#   (1, 6197)	0.15839969021017855
#   (1, 6211)	0.2223119944323623
#   (1, 8340)	0.10760238537004903
#   (1, 8537)	0.24752839197867293
#   (1, 13063)	0.10794531919829956
#   (1, 13093)	0.2363699583052245
#   :	:
#   (5926, 3670)	0.26241342744672896
#   (5926, 3687)	0.2555184425081828
#   (5926, 3772)	0.27685384013783804
#   (5926, 14070)	0.1465260419220017
#   (5926, 14072)	0.27685384013783804
#   (5926, 30190)	0.18788683214622537
#   (5926, 30191)	0.27685384013783804
#   (5926, 37548)	0.27685384013783804
#   (5926, 43207)	0.15706177303850016
#   (5926, 43292)	0.27685384013783804
#   (5926, 44932)	0.27685384013783804
#   (5926, 44933)	0.27685384013783804
#   (7, 47)	13.432347649917919
#   (7, 169)	6.699147547799773
#   (7, 497)	3.558237309761353
#   :	:
#   (5922, 195)	1.657256795921336
#   (5922, 277)	3.147605584866814
#   (5922, 497)	4.054057262760885
#   (5922, 498)	1.6225084526289446
#   (5922, 499)	1.9261395772753134
#   (5923, 176)	2.4554154655862366
#   (5923, 497)	3.9373937444080545
#   (5923, 498)	1.6225084526289446
#   (5923, 499)	3.8522791545506267
#   (5924, 32)	4.751566152304246
#   (5924, 195)	1.7518478032076517
#   (5924, 198)	5.691305382233214
#   (5924, 497)	2.9749197179971967
#   (5924, 498)	0.5408361508763149
#   (5924, 499)	2.476465170782546
#   (5925, 64)	10.260293511801116
#   (5925, 176)	2.1296902144161165
#   (5925, 497)	4.083223142349094
#   (5925, 498)	1.6225084526289446
#   (5925, 499)	3.3019535610433945
#   (5926, 32)	8.602191205025479
#   (5926, 497)	4.054057262760885
#   (5926, 499)	3.3019535610433945
#   (5927, 497)	1.4582939794103906
#   (5927, 499)	0.5503255935072324

# %%
# extract features
pipe_extract_binary = FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                 ('tfidf', TfidfVectorizer())])),
                             ("custom", CustomFeatures())])

# select and scale features
pipe_select_scale_binary = Pipeline([("select", SelectKBest(score_func = chi2)),
                              ("scale", StandardScaler(with_mean = False))])


# extract features
# you can also use bi-grams:
X_extract_binary = pipe_extract_binary.set_params(terms__tfidf__ngram_range = (1,2)).fit_transform(x_train_binary, y_train_binary)

X_extract_test_binary = pipe_extract_binary.set_params(terms__tfidf__ngram_range = (1,2)).transform(x_test_binary)

X_extract_letters_binary =  pipe_extract_binary.set_params(terms__tfidf__ngram_range = (1,2)).transform(letters_df[['text']] )
print(X_extract_binary)

X_select_scale_binary = pipe_select_scale_binary.set_params(select__k = 500).fit_transform(X_extract_binary, y_train_binary)
print(X_select_scale_binary)

X_select_scale_test_binary = pipe_select_scale_binary.set_params(select__k = 500).transform(X_extract_test_binary)
print(X_select_scale_binary)

X_select_scale_letters_binary = pipe_select_scale_binary.set_params(select__k = 500).transform(X_extract_letters_binary)
# Out:
#   (0, 7678)	0.3947096042281229
#   (0, 13035)	0.3947096042281229
#   (0, 13036)	0.3947096042281229
#   (0, 16572)	0.3947096042281229
#   (0, 16573)	0.3947096042281229
#   (0, 19889)	0.25539375477969606
#   (0, 19905)	0.3947096042281229
#   (0, 27543)	60.0
#   (0, 27544)	2.0
#   (0, 27545)	5.0
#   (1, 1533)	0.2605938624352017
#   (1, 1534)	0.27378457465152056
#   (1, 4926)	0.21549451948567247
#   (1, 4929)	0.22142585892378444
#   (1, 5905)	0.2183251996366009
#   (1, 5906)	0.27378457465152056
#   (1, 6766)	0.19432941012145588
#   (1, 6782)	0.27378457465152056
#   (1, 9957)	0.0696215204661255
#   (1, 10012)	0.07213381039780346
#   (1, 10866)	0.08298099292474484
#   (1, 10946)	0.15675573583711094
#   (1, 12566)	0.1732258566870717
#   (1, 12581)	0.2512349031767559
#   (1, 14621)	0.05777414730611443
#   :	:
#   (3321, 26934)	0.5187086316619189
#   (3321, 26935)	0.5187086316619189
#   (2, 319)	14.637374980467385
#   (2, 498)	3.7740711842776795
#   (3, 195)	10.037878739701656
#   (3, 324)	9.864581303645211
#   (3, 498)	1.7862016292001233
#   (4, 103)	8.059894477905603
#   (4, 218)	2.1035620422217747
#   (4, 233)	5.142413414063637
#   (4, 340)	5.912653515391819
#   (4, 430)	12.105469719313472
#   (4, 498)	4.033358517548665
#   (5, 61)	12.718214663269395
#   (5, 218)	2.637158291093318
#   :	:
#   (3315, 324)	9.932503232754067
#   (3315, 498)	1.6997725181097947
#   (3316, 498)	3.5435935547034703
#   (3317, 498)	0.6914328887226283
#   (3318, 184)	32.60929028230209
#   (3318, 289)	2.1758287977778084
#   (3318, 400)	16.229911823018686
#   (3318, 498)	1.8726307402904518
#   (3319, 63)	5.081127054283435
#   (3319, 119)	19.62834900558029
#   (3319, 199)	3.0727855661422243
#   (3319, 200)	1.6928065846819416
#   (3319, 289)	1.4320242706003217
#   (3319, 498)	4.033358517548665
#   (3320, 498)	2.852160665980842
#   (3321, 24)	31.81328076692721
#   (3321, 25)	46.836599263385516
#   (3321, 57)	7.6199767300410635
#   (3321, 498)	0.8354814072065092
#   (3322, 63)	4.917333032310978
#   (3322, 199)	1.4868659850634676
#   (3322, 200)	1.6382376679899702
#   (3322, 289)	1.385861871522726
#   (3322, 340)	6.572240664763857
#   (3322, 498)	4.004548813851889

# %%
# extract features
pipe_bi = Pipeline([("extract", FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                               ('tfidf', TfidfVectorizer(ngram_range = (1,2)))])),
                                           ("custom", CustomFeatures())])),
                 ("select", SelectKBest(score_func = chi2,k = 500)),
                 ("scale", StandardScaler(with_mean = False))])

# %%
# extract features
pipe_bi_binary = Pipeline([("extract", FeatureUnion([("terms", Pipeline([('clean', CleanText()), 
                                                               ('tfidf', TfidfVectorizer(ngram_range = (1,2)))])),
                                           ("custom", CustomFeatures())])),
                 ("select", SelectKBest(score_func = chi2,k = 500)),
                 ("scale", StandardScaler(with_mean = False))])

# %%
X_train_bi =pipe_bi.fit_transform(x_train,y_train)
X_valid_bi = pipe_bi.transform(x_valid)
X_test_bi = pipe_bi.transform(x_test)

X_letters_bi = pipe_bi.transform(letters_df[['text']])

# %%
X_train_bi_binary =pipe_bi_binary.fit_transform(x_train_binary,y_train_binary)
X_valid_bi_binary = pipe_bi_binary.transform(x_valid_binary)
X_test_bi_binary = pipe_bi_binary.transform(x_test_binary)

X_letters_bi_binary = pipe_bi_binary.transform(letters_df[['text']])

# %%
from sklearn import preprocessing
le_binary = preprocessing.LabelEncoder()

y_train_enc_binary = le_binary.fit_transform(y_train_binary)
y_valid_enc_binary = le_binary.transform(y_valid_binary)
y_test_enc_binary = le_binary.transform(y_test_binary)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

y_train_enc = le.fit_transform(y_train)
y_valid_enc = le.transform(y_valid)
y_test_enc = le.transform(y_test)

# %%
import numpy as np
from keras.utils import np_utils

no_of_classes = len(np.unique(y_train))
y_train_seq = np_utils.to_categorical(y_train_enc,no_of_classes)
y_valid_seq = np_utils.to_categorical(y_valid_enc,no_of_classes)
y_test_seq= np_utils.to_categorical(y_test_enc,no_of_classes)

# %%
import numpy as np
from keras.utils import np_utils

no_of_classes_binary = len(np.unique(y_train_binary))
y_train_seq_binary = np_utils.to_categorical(y_train_enc_binary,no_of_classes_binary)
y_valid_seq_binary = np_utils.to_categorical(y_valid_enc_binary,no_of_classes_binary)
y_test_seq_binary= np_utils.to_categorical(y_test_enc_binary,no_of_classes_binary)

# %% [markdown]
# # Logistic

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Select best hyperparameters by cross validation
from sklearn.model_selection import GridSearchCV
import numpy as np

# Model
logistic = LogisticRegression(max_iter=10000, tol=0.1, solver='lbfgs')

param_logistic = {
    'C': np.logspace(-4, 4, 4),
}


cv_logistic = GridSearchCV(logistic, param_logistic, cv=10, scoring="f1_weighted")
cv_logistic.fit(X_train_bi_binary, y_train_enc_binary)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(max_iter=10000, tol=0.1),
#              param_grid={'C': array([1.00000000e-04, 4.64158883e-02, 2.15443469e+01, 1.00000000e+04])},
#              scoring='f1_weighted')

# %%
print(cv_logistic.best_score_)
# Out:
# 0.8120010793671704

# %%
from sklearn.metrics import f1_score
y_pred = cv_logistic.predict(X_test_bi_binary)
print(f1_score(y_test_enc_binary, y_pred, average="weighted"))
# Out:
# 0.6318610344312837

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score


rf =  RandomForestClassifier(n_estimators=100,max_depth=None)

# %%
rf.fit(X_train_bi,y_train_enc)
y_pred = rf.predict(X_test_bi)
f1_score(y_test_enc, y_pred, average="weighted")
# Out:
# 0.4077977950535332

# %% [markdown]
# <hr>
# <br>
# <br>
#
# # CV Neural Networks
#
# <br>

# %%
# !pip install keras-visualizer
# Out:
# Requirement already satisfied: keras-visualizer in /usr/local/lib/python3.7/dist-packages (2.4)

# %%
from keras_visualizer import visualizer 
from keras.callbacks import History
import tensorflow as tf
import keras
from keras import layers
from keras import models
from keras import utils
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import Activation
from keras.regularizers import l2
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop

# %%
def createNN_tuning_binary(init_mode='uniform',drop_out=0.1, init_nodes1 =64, init_nodes2 = 64,dim = 500):
    # define model
    model = Sequential()
    model.add(Dense(init_nodes1, kernel_initializer=init_mode, activation=tf.nn.relu, input_dim=dim)) 
    model.add(Dropout(drop_out))
    model.add(Dense(init_nodes2, kernel_initializer=init_mode, activation=tf.nn.relu))
    model.add(Dense(1, kernel_initializer=init_mode, activation=tf.nn.sigmoid))
    # compile model
    model.compile(loss='binary_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
    return model

# %%
import numpy
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

def createNN_tuning(init_mode='uniform',drop_out=0.1, init_nodes1 =64, init_nodes2 = 64,dim = 500):
    # define model
    model = Sequential()
    model.add(Dense(init_nodes1, kernel_initializer=init_mode, activation=tf.nn.relu, input_dim=dim)) 
    model.add(Dropout(drop_out))
    model.add(Dense(init_nodes2, kernel_initializer=init_mode, activation=tf.nn.relu))
    model.add(Dense(4, kernel_initializer=init_mode, activation=tf.nn.softmax))
    # compile model
    model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])
    return model

# %%
seed = 7
numpy.random.seed(seed)
batch_size = 128
epochs = 50

model_CV_binary = KerasClassifier(build_fn=createNN_tuning_binary,  
                           batch_size=batch_size, verbose=1,  )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   import sys

# %%
seed = 7
numpy.random.seed(seed)
batch_size = 128
epochs = 50

model_CV = KerasClassifier(build_fn=createNN_tuning,  
                           batch_size=batch_size, verbose=1,  )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   import sys

# %%
# define the grid search parameters
init_mode = ['uniform', 'lecun_uniform', 'normal']
init_nodes1 = [64,128,256]
init_nodes2 = [64,128,256]
drop_out = [0.1,0.3,0.5]
epochs = [30,50]

param_grid = dict(init_mode=init_mode, init_nodes1 = init_nodes1, init_nodes2 = init_nodes2, drop_out= drop_out,epochs= epochs)

# %%
grid_binary = GridSearchCV(estimator=model_CV_binary, param_grid=param_grid, n_jobs=-1, cv=3)

# %%
grid = GridSearchCV(estimator=model_CV, param_grid=param_grid, n_jobs=-1, cv=3)

# %%
#%%time
#grid_result_binary = grid_binary.fit(X_train_bi_binary, y_train_enc_binary,validation_data=(X_valid_bi_binary, y_valid_enc_binary))

# %%
#%%time
#grid_result = grid.fit(X_train_bi, y_train_seq,validation_data=(X_valid_bi, y_valid_seq))

# %%
#y_pred_binary= grid_result_binary.predict(X_test_binary)
#y_pred_enc_binary = [np.argmax(i) for i in y_pred_binary]
#f1_score(y_test_enc_binary, y_pred_enc_binary, average="weighted")

# %%
#from sklearn.metrics import f1_score
#y_pred= grid_result.predict(X_test_bi)
#y_pred_enc = [np.argmax(i) for i in y_pred]
#f1_score(y_test_enc, y_pred_enc, average="weighted")

# %%
#print(f'Best Accuracy for {grid_result_binary.best_score_} using {grid_result_binary.best_params_}')
#means_binary = grid_result_binary.cv_results_['mean_test_score']
#stds_binary = grid_result_binary.cv_results_['std_test_score']
#params_binary = grid_result_binary.cv_results_['params']
#for mean, stdev, param in zip(means_binary, stds_binary, params_binary):
#    print(f' mean={mean:.4}, std={stdev:.4} using {param}')

# %%
# print results
#print(f'Best Accuracy for {grid_result.best_score_} using {grid_result.best_params_}')
#means = grid_result.cv_results_['mean_test_score']
#stds = grid_result.cv_results_['std_test_score']
#params = grid_result.cv_results_['params']
#for mean, stdev, param in zip(means, stds, params):
#    print(f' mean={mean:.4}, std={stdev:.4} using {param}')

# %% [markdown]
# Best Accuracy for 0.5506073037783304 using {'drop_out': 0.5, 'epochs': 50, 'init_mode': 'normal', 'init_nodes1': 64, 'init_nodes2': 256}
#  mean=0.5471, std=0.01136 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 64, 'init_nodes2': 64}
#  mean=0.5444, std=0.009833 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 64, 'init_nodes2': 128}
#  mean=0.5366, std=0.01055 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 64, 'init_nodes2': 256}
#  mean=0.541, std=0.01032 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 128, 'init_nodes2': 64}
#  mean=0.5415, std=0.01118 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 128, 'init_nodes2': 128}
#  mean=0.5341, std=0.01009 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 128, 'init_nodes2': 256}
#  mean=0.5371, std=0.009729 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 256, 'init_nodes2': 64}
#  mean=0.5358, std=0.01328 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 256, 'init_nodes2': 128}
#  mean=0.5307, std=0.007499 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'uniform', 'init_nodes1': 256, 'init_nodes2': 256}
#  mean=0.5401, std=0.01408 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 64, 'init_nodes2': 64}
#  mean=0.5326, std=0.01122 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 64, 'init_nodes2': 128}
#  mean=0.5386, std=0.01049 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 64, 'init_nodes2': 256}
#  mean=0.5294, std=0.01242 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 128, 'init_nodes2': 64}
#  mean=0.53, std=0.00948 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 128, 'init_nodes2': 128}
#  mean=0.5231, std=0.01222 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 128, 'init_nodes2': 256}
#  mean=0.5278, std=0.006951 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 256, 'init_nodes2': 64}
#  mean=0.5238, std=0.005466 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 256, 'init_nodes2': 128}
#  mean=0.5155, std=0.01508 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'lecun_uniform', 'init_nodes1': 256, 'init_nodes2': 256}
#  mean=0.5417, std=0.00836 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'normal', 'init_nodes1': 64, 'init_nodes2': 64}
#  mean=0.5376, std=0.01222 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'normal', 'init_nodes1': 64, 'init_nodes2': 128}
#  mean=0.5374, std=0.01043 using {'drop_out': 0.1, 'epochs': 50, 'init_mode': 'normal', 'init_nodes1': 64, 'init_nodes2': 256}

# %%
#_, accuracy_binary = grid_result_binary.evaluate(X_test_bi_binary, y_test_seq_binary)
#print('Accuracy: %.2f' % (accuracy_binary*100))

# %%
#_, accuracy = grid_result.evaluate(X_test_bi, y_test_seq)
#print('Accuracy: %.2f' % (accuracy*100))

# %%
#grid_result_binary.best_params_

# %%
#grid_result.best_params_

# %% [markdown]
# {'drop_out': 0.5, 'epochs': 50, 'init_nodes1': 64, 'init_nodes2': 128}

# %%
model_earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=5, verbose=0,
    mode='auto', baseline=None, restore_best_weights=False
)

# %%
nn_tune_binary= createNN_tuning_binary(drop_out=0.5, init_mode="normal",init_nodes1=64, init_nodes2 = 128)

# %%
nn_tune= createNN_tuning(drop_out=0.5, init_mode="normal",init_nodes1=64, init_nodes2 = 256)

# %%
history_tune_binary = nn_tune_binary.fit(X_train_bi_binary, y_train_enc_binary,validation_data=(X_valid_bi_binary, y_valid_enc_binary), epochs=30, batch_size=1024,callbacks=model_earlystop)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:450: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/sequential_6/dense_18/embedding_lookup_sparse/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/sequential_6/dense_18/embedding_lookup_sparse/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/sequential_6/dense_18/embedding_lookup_sparse/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 4/4 [==============================] - 1s 67ms/step - loss: 0.6927 - accuracy: 0.5998 - val_loss: 0.6804 - val_accuracy: 0.6173
# Epoch 2/30
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6733 - accuracy: 0.6286 - val_loss: 0.6735 - val_accuracy: 0.6197
# Epoch 3/30
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6540 - accuracy: 0.6804 - val_loss: 0.6556 - val_accuracy: 0.6883
# Epoch 4/30
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6302 - accuracy: 0.7307 - val_loss: 0.6285 - val_accuracy: 0.7244
# Epoch 5/30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6022 - accuracy: 0.7605 - val_loss: 0.5982 - val_accuracy: 0.7365
# Epoch 6/30
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5633 - accuracy: 0.7803 - val_loss: 0.5714 - val_accuracy: 0.7485
# Epoch 7/30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5154 - accuracy: 0.7999 - val_loss: 0.5569 - val_accuracy: 0.7497
# Epoch 8/30
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4685 - accuracy: 0.8119 - val_loss: 0.5659 - val_accuracy: 0.7485
# Epoch 9/30
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4261 - accuracy: 0.8264 - val_loss: 0.6042 - val_accuracy: 0.7425
# Epoch 10/30
# 4/4 [==============================] - 0s 22ms/step - loss: 0.4015 - accuracy: 0.8312 - val_loss: 0.6617 - val_accuracy: 0.7377
# Epoch 11/30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3775 - accuracy: 0.8369 - val_loss: 0.7201 - val_accuracy: 0.7353
# Epoch 12/30
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3766 - accuracy: 0.8381 - val_loss: 0.7662 - val_accuracy: 0.7365

# %%
history_tune = nn_tune.fit(X_train_bi, y_train_seq,validation_data=(X_valid_bi, y_valid_seq), epochs=30, batch_size=512,callbacks=model_earlystop)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:450: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/sequential_7/dense_21/embedding_lookup_sparse/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/sequential_7/dense_21/embedding_lookup_sparse/Reshape:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/sequential_7/dense_21/embedding_lookup_sparse/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 12/12 [==============================] - 1s 28ms/step - loss: 1.3275 - accuracy: 0.4167 - val_loss: 1.2514 - val_accuracy: 0.4825
# Epoch 2/30
# 12/12 [==============================] - 0s 11ms/step - loss: 1.2016 - accuracy: 0.4880 - val_loss: 1.2063 - val_accuracy: 0.5034
# Epoch 3/30
# 12/12 [==============================] - 0s 14ms/step - loss: 1.1372 - accuracy: 0.5083 - val_loss: 1.2085 - val_accuracy: 0.5108
# Epoch 4/30
# 12/12 [==============================] - 0s 13ms/step - loss: 1.1018 - accuracy: 0.5243 - val_loss: 1.2106 - val_accuracy: 0.5128
# Epoch 5/30
# 12/12 [==============================] - 0s 13ms/step - loss: 1.0714 - accuracy: 0.5369 - val_loss: 1.2171 - val_accuracy: 0.5189
# Epoch 6/30
# 12/12 [==============================] - 0s 12ms/step - loss: 1.0579 - accuracy: 0.5476 - val_loss: 1.2245 - val_accuracy: 0.5270
# Epoch 7/30
# 12/12 [==============================] - 0s 11ms/step - loss: 1.0519 - accuracy: 0.5467 - val_loss: 1.2308 - val_accuracy: 0.5209

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
plot_graphs(history_tune_binary, "accuracy")
plot_graphs(history_tune_binary, "loss")

# %%
plot_graphs(history_tune, "accuracy")
plot_graphs(history_tune, "loss")

# %%
_, accuracy_binary = nn_tune_binary.evaluate(X_test_bi_binary, y_test_enc_binary)
print('Accuracy: %.2f' % (accuracy_binary*100))
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0740 - accuracy: 0.6110
# Accuracy: 61.10

# %%
y_test_enc_binary
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
_, accuracy = nn_tune.evaluate(X_test_bi, y_test_seq)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 61/61 [==============================] - 0s 2ms/step - loss: 1.3651 - accuracy: 0.4508
# Accuracy: 45.08

# %%
from sklearn.metrics import f1_score
y_pred_binary= nn_tune_binary.predict(X_test_bi_binary)
y_pred_enc_binary =np.asarray(np.round(y_pred_binary)).astype(int)
f1_score(y_test_enc_binary, y_pred_enc_binary, average="weighted")
# Out:
# 0.62312390348252

# %%
from sklearn.metrics import f1_score
y_pred= nn_tune.predict(X_test_bi)
y_pred_enc = [np.argmax(i) for i in y_pred]
f1_score(y_test_enc, y_pred_enc, average="weighted")
# Out:
# 0.46735078936164925

# %%
#NN_cv.save('NN_cv.sav')

# %%
pred = le.inverse_transform([np.argmax(i) for i in y_pred])

# %%
pred
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %%
test_set
# Out:
#                                                    text  sent
# 0     Tra 5 minuti presentazione piano scuola del go...     0
# 1     \@matteorenzi: Alle 10 appuntamento su http://...     1
# 2     #labuonascuola gli #evangelisti #digitali non ...    -1
# 3     Riforma scuola Tutto il discorso di  Renzi su ...     0
# 4     .@matteorenzi @MiurSocial #labuonascuola basta...     0
# ...                                                 ...   ...
# 1938  Anche prodotti alimentari tipici pugliesi in v...     0
# 1939         intensità di vita  https://t.co/jv4aARxzhz     0
# 1940  Oggi tutti che iniziano l'università e io sul ...     2
# 1941  @GliIntoccabili @nonleggerlo Ma Ferrero? il co...    -1
# 1942  Non vedi l'ora che venga qui, almeno lo sentir...     1
#
# [1943 rows x 2 columns]

# %%
visualizer(nn_tune, format='png', view=True)

# %%
from keras.utils.vis_utils import plot_model
 
plot_model(nn_tune, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
X_letters
# Out:
# <456x10 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1287 stored elements in Compressed Sparse Row format>

# %%
X_test_bi
# Out:
# <1943x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6725 stored elements in Compressed Sparse Row format>

# %%
X_letters_bi
# Out:
# <456x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2115 stored elements in Compressed Sparse Row format>

# %%
y_pred = nn_tune.predict(X_letters_bi)
y_pred_enc_bi = [np.argmax(i) for i in y_pred]
#f1_score(y_pred_enc_bi, y_pred_enc, average="weighted")

# %%
y_pred_bin = nn_tune_binary.predict(X_letters_bi_binary)
y_pred_enc_bi_bin =np.asarray(np.round(y_pred_bin)).astype(int)

# %%
letters_df
# Out:
#                     id  ... emotion_sentita
# CLET000002  CLET000002  ...             joy
# CLET000024  CLET000024  ...         sadness
# CLET000026  CLET000026  ...             joy
# CLET000028  CLET000028  ...         sadness
# CLET000029  CLET000029  ...             joy
# ...                ...  ...             ...
# CLET000782  CLET000782  ...         sadness
# CLET000783  CLET000783  ...             joy
# CLET000784  CLET000784  ...             joy
# CLET000785  CLET000785  ...             joy
# CLET000786  CLET000786  ...             joy
#
# [456 rows x 22 columns]

# %%
letters_df
# Out:
#                     id  ... emotion_sentita
# CLET000002  CLET000002  ...             joy
# CLET000024  CLET000024  ...         sadness
# CLET000026  CLET000026  ...             joy
# CLET000028  CLET000028  ...         sadness
# CLET000029  CLET000029  ...             joy
# ...                ...  ...             ...
# CLET000782  CLET000782  ...         sadness
# CLET000783  CLET000783  ...             joy
# CLET000784  CLET000784  ...             joy
# CLET000785  CLET000785  ...             joy
# CLET000786  CLET000786  ...             joy
#
# [456 rows x 22 columns]

# %%
letters_text_pred = letters_df[['text','year']]

# %%
letters_text_pred
# Out:
#                                                          text  year
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  1888
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  1888
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  1888
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  1888
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  1888
# ...                                                       ...   ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  1888
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  1888
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  1888
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  1888
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  1888
#
# [456 rows x 2 columns]

# %%
letters_text_pred['pred'] = y_pred_enc_bi
letters_df['pred'] = y_pred_enc_bi
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
letters_text_pred['pred_binary'] = y_pred_enc_bi_bin
letters_df['pred_binary'] = y_pred_enc_bi_bin
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
letters_text_pred
# Out:
#                                                          text  ...  pred_binary
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...            1
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...            0
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...            0
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...            0
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...            0
# ...                                                       ...  ...          ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...            1
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...            1
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...            1
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...            1
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...            0
#
# [456 rows x 4 columns]

# %% [markdown]
# <hr>
#
# <br>
# <br>
#
# # Sentita Sentiment and Emotion Classifiers
#
# <br>

# %%
letters_df = pd.read_pickle('https://github.com/Andreaierardi/sentiment-puccini/blob/main/dataset/puccini.pkl?raw=true')

# %%
letters_list = list(letters_df['text'])

# %%
letters_df
# Out:
#                     id  ...      linuga
# CLET000002  CLET000002  ...  [italiano]
# CLET000024  CLET000024  ...  [italiano]
# CLET000026  CLET000026  ...  [italiano]
# CLET000028  CLET000028  ...  [italiano]
# CLET000029  CLET000029  ...  [italiano]
# ...                ...  ...         ...
# CLET000782  CLET000782  ...  [italiano]
# CLET000783  CLET000783  ...  [italiano]
# CLET000784  CLET000784  ...  [italiano]
# CLET000785  CLET000785  ...  [italiano]
# CLET000786  CLET000786  ...  [italiano]
#
# [456 rows x 19 columns]

# %%
#%%capture
# !pip install feel-it
# Out:
# Collecting feel-it
#   Downloading feel_it-1.0.3-py2.py3-none-any.whl (5.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from feel-it) (1.19.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from feel-it) (1.10.0+cu111)
# Collecting transformers==4.3.3
#   Downloading transformers-4.3.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 7.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (3.4.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 36.1 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 41.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->feel-it) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->feel-it) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.3.3->feel-it) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.3.3->feel-it) (3.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->feel-it) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->feel-it) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->feel-it) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->feel-it) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->feel-it) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->feel-it) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->feel-it) (7.1.2)
# Installing collected packages: tokenizers, sacremoses, transformers, feel-it
# Successfully installed feel-it-1.0.3 sacremoses-0.0.46 tokenizers-0.10.3 transformers-4.3.3

# %%
from feel_it import SentimentClassifier
sentiment_classifier = SentimentClassifier()
# Out:
# Downloading:   0%|          | 0.00/847 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/794k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.68M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/299 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
sentiments_letter = sentiment_classifier.predict(letters_list)

# %%
sentiment_test = sentiment_classifier.predict([i for i in x_test_binary['text']])

# %%
vector_converted = []
for i in y_test_enc_binary:
  if i == 0:
    vector_converted.append("negative")
  if i == 1:
    vector_converted.append("positive")

# %%
from sklearn.metrics import f1_score
print(f1_score(vector_converted, sentiment_test, average="weighted"))
# Out:
# 0.8546168958742633

# %%
§sentiments_letter[:10]
# Out:
# ['positive',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive']

# %%
from feel_it import EmotionClassifier
emotion_classifier = EmotionClassifier()
# Out:
# Downloading:   0%|          | 0.00/899 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/794k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.68M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/299 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
emotions_letter = emotion_classifier.predict(letters_list)

# %%
emotions_letter
# Out:
# ['joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'sadness',
#  'sadness',
#  'anger',
#  'sadness',
#  'joy',
#  'fear',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'fear',
#  'anger',
#  'fear',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'anger',
#  'joy',
#  'anger',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'sadness',
#  'fear',
#  'sadness',
#  'fear',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'fear',
#  'joy',
#  'sadness',
#  'joy',
#  'fear',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'anger',
#  'joy',
#  'fear',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'anger',
#  'anger',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'fear',
#  'anger',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'anger',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'sadness',
#  'joy',
#  'fear',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'fear',
#  'fear',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'fear',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'sadness',
#  'anger',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'joy']

# %% [markdown]
# <hr>
# <br>
# <br>
#
# # Sentita Model Results
#
# <br>

# %%
letters_df['sentiment_sentita'] = sentiments_letter

# %%
letters_df['emotion_sentita'] = emotions_letter

# %%
letters_df
# Out:
#                     id  ... pred_binary
# CLET000002  CLET000002  ...           1
# CLET000024  CLET000024  ...           0
# CLET000026  CLET000026  ...           0
# CLET000028  CLET000028  ...           0
# CLET000029  CLET000029  ...           0
# ...                ...  ...         ...
# CLET000782  CLET000782  ...           1
# CLET000783  CLET000783  ...           1
# CLET000784  CLET000784  ...           1
# CLET000785  CLET000785  ...           1
# CLET000786  CLET000786  ...           0
#
# [456 rows x 24 columns]

# %%
letters_df.groupby(by=['emotion_sentita','sentiment_sentita'])

# %%
print('Number of letters with positive sentiment:',len(letters_df[letters_df['sentiment_sentita'] == 'positive']))
print('Number of letters with negative sentiment:',len(letters_df[letters_df['sentiment_sentita'] == 'negative']))
# Out:
# Number of letters with positive sentiment: 216
# Number of letters with negative sentiment: 240

# %%
sent_agg = letters_df.groupby(by="sentiment_sentita").size()

# %%
letters_text_pred['sentiment_sentita'] = letters_df['sentiment_sentita']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
letters_text_pred['emotion_sentita'] = letters_df['emotion_sentita']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
letters_text_pred
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...          sadness
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# ...                                                       ...  ...              ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [456 rows x 6 columns]

# %%
letters_text_pred[['pred']] = letters_text_pred[['pred']].replace({0:"negative", 1:"neutral",2:"positive", 3:"both"})
letters_df[['pred']] = letters_df[['pred']].replace({0:"negative", 1:"neutral",2:"positive", 3:"both"})
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
letters_text_pred[['pred_binary']] = letters_text_pred[['pred_binary']].replace({0:"negative",1:"positive" })
letters_df[['pred_binary']] = letters_df[['pred_binary']].replace({0:"negative",1:"positive" })
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
letters_df.to_pickle('puccini_with_predictions.pkl')

# %%
letters_text_pred
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...          sadness
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# ...                                                       ...  ...              ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [456 rows x 6 columns]

# %%
print('Number of letters with joy emotion:',len(letters_text_pred[letters_text_pred['emotion_sentita'] == 'joy']))
print('Number of letters with fear emotion:',len(letters_text_pred[letters_text_pred['emotion_sentita'] == 'fear']))
print('Number of letters with anger emotion:',len(letters_text_pred[letters_text_pred['emotion_sentita'] == 'anger']))
print('Number of letters with sadness emotion:',len(letters_text_pred[letters_text_pred['emotion_sentita'] == 'sadness']))
# Out:
# Number of letters with joy emotion: 250
# Number of letters with fear emotion: 19
# Number of letters with anger emotion: 21
# Number of letters with sadness emotion: 166

# %%
emo_agg = letters_text_pred.groupby(by="emotion_sentita").size().sort_values( ascending=False)

# %%
emo_agg
# Out:
# emotion_sentita
# joy        250
# sadness    166
# anger       21
# fear        19
# dtype: int64

# %%
def plot_freq(names,counts, title = None):
  fig, ax = plt.subplots(figsize =(16, 9))

  name = names#emo_agg.index
  count = counts #emo_agg.values
  # Horizontal Bar Plot
  ax.barh(name, count)
  
  # Remove axes splines
  for s in ['top', 'bottom', 'left', 'right']:
      ax.spines[s].set_visible(False)
  
  # Remove x, y Ticks
  ax.xaxis.set_ticks_position('none')
  ax.yaxis.set_ticks_position('none')
  
  # Add padding between axes and labels
  ax.xaxis.set_tick_params(pad = 5)
  ax.yaxis.set_tick_params(pad = 10)
  
  # Add x, y gridlines
  ax.grid(b = True, color ='grey',
          linestyle ='-.', linewidth = 0.5,
          alpha = 0.2)
  
  # Show top values
  ax.invert_yaxis()
  
  # Add annotation to bars
  for i in ax.patches:
      plt.text(i.get_width()+0.2, i.get_y()+0.5,
              str(round((i.get_width()), 2)),
              fontsize = 20, fontweight ='bold',
              color ='grey')
  
  # Add Plot Title
  if title is None:
    ax.set_title('Distribution of predicted emotion',
                loc ='left', )
  else:
    ax.set_title(title,
                loc ='left', )
  # Show Plot
  plt.show()

# %%
plot_freq(sent_agg.index,sent_agg.values)

# %%
plot_freq(emo_agg.index,emo_agg.values)

# %%
distribution_emo_sent = letters_text_pred.groupby(['emotion_sentita','sentiment_sentita'],as_index=False).count().sort_values('text')
distribution_emo_sent
# Out:
#   emotion_sentita sentiment_sentita  text  year  pred  pred_binary
# 1            fear          negative    19    19    19           19
# 0           anger          negative    21    21    21           21
# 5         sadness          positive    23    23    23           23
# 2             joy          negative    57    57    57           57
# 4         sadness          negative   143   143   143          143
# 3             joy          positive   193   193   193          193

# %%
distribution_emo_sent = letters_text_pred.groupby(by=['emotion_sentita','sentiment_sentita']).size()

# %%
distribution_emo_sent =distribution_emo_sent.reset_index()
distribution_emo_sent.index = distribution_emo_sent['emotion_sentita']+"-"+distribution_emo_sent['sentiment_sentita']

# %%
distribution_emo_sent = distribution_emo_sent.reset_index()

# %%
distribution_emo_sent['count'] = distribution_emo_sent[0]

# %%
distribution_emo_sent = distribution_emo_sent.sort_values("count")

# %%
plot_freq(distribution_emo_sent['emotion_sentita']+"-"+distribution_emo_sent['sentiment_sentita'],distribution_emo_sent['count'])

# %%
letters_sent_year  = letters_text_pred.groupby(['year', 'sentiment_sentita'],as_index = False).agg('text').count()

# %%
letters_sent_year
# Out:
#     year sentiment_sentita  text
# 0   1888          negative     2
# 1   1888          positive     3
# 2   1889          negative     2
# 3   1889          positive     6
# 4   1890          negative     9
# 5   1890          positive     1
# 6   1891          negative     8
# 7   1891          positive     1
# 8   1892          negative    17
# 9   1892          positive    17
# 10  1893          negative    24
# 11  1893          positive    27
# 12  1894          negative    23
# 13  1894          positive    14
# 14  1895          negative    19
# 15  1895          positive    12
# 16  1896          negative    22
# 17  1896          positive    30
# 18  1897          negative    22
# 19  1897          positive    17
# 20  1898          negative    20
# 21  1898          positive    20
# 22  1899          negative    37
# 23  1899          positive    25
# 24  1900          negative    30
# 25  1900          positive    37
# 26  1901          negative     5
# 27  1901          positive     6

# %%
def add_value_labels(ax, spacing=5):
    """Add labels to the end of each bar in a bar chart.

    Arguments:
        ax (matplotlib.axes.Axes): The matplotlib object containing the axes
            of the plot to annotate.
        spacing (int): The distance between the labels and the bars.
    """

    # For each bar: Place a label
    for rect in ax.patches:
        # Get X and Y placement of label from rect.
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2

        # Number of points between bar and label. Change to your liking.
        space = spacing
        # Vertical alignment for positive values
        va = 'bottom'

        # If value of bar is negative: Place label below bar
        if y_value < 0:
            # Invert space to place label below
            space *= -1
            # Vertically align label at top
            va = 'top'

        # Use Y value as label and format number with one decimal place
        label = str(y_value)

        # Create annotation
        ax.annotate(
            label,                      # Use `label` as label
            (x_value, round(y_value)),         # Place label at end of the bar
            xytext=(0, space),          # Vertically shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            ha='center',                # Horizontally center label
            va=va,fontsize=15
            )                      # Vertically align label differently for
                                        # positive and negative values.

# %%
def year_plot_sent(x,x2):
  barWidth = 0.25
  fig, ax = plt.subplots(figsize =(24, 9))

  pos = x#letters_sent_year[letters_sent_year['sentiment_sentita'] == 'positive']['text']
  neg = x2#letters_sent_year[letters_sent_year['sentiment_sentita'] == 'negative']['text']
  br1 = np.arange(len(neg))
  br2 = [x + barWidth for x in br1]
  #br3 = [x + barWidth for x in br2]
  t = plt.bar(br1, neg, color ='b', width = barWidth,
          edgecolor ='grey', label ='Negative')
  plt.bar(br2, pos, color ='r', width = barWidth,
          edgecolor ='grey', label ='Positive')

  #plt.bar(br3, CSE, color ='b', width = barWidth,
  #        edgecolor ='grey', label ='CSE')


  # Adding Xticks
  plt.xlabel('Year', fontweight ='bold', fontsize = 15)
  plt.ylabel('Number of negative/positive letters', fontweight ='bold', fontsize = 15)
  plt.xticks([r + barWidth for r in range(len(pos))],
          letters_sent_year.year.unique())



  # Call the function above. All the magic happens there.
  add_value_labels(ax)
  plt.legend()
  plt.show()

# %%
x= letters_sent_year[letters_sent_year['sentiment_sentita'] == 'positive']['text']
x2 = letters_sent_year[letters_sent_year['sentiment_sentita'] == 'negative']['text']
year_plot(x = x, x2 = x2)

# %%
letters_emo_year  = letters_text_pred.groupby(['year', 'emotion_sentita'],as_index = True).count().unstack(fill_value=0).stack()['text'].reset_index()

# %%
letters_emo_year
# Out:
#     year emotion_sentita  text
# 0   1888           anger     0
# 1   1888            fear     0
# 2   1888             joy     3
# 3   1888         sadness     2
# 4   1889           anger     0
# 5   1889            fear     1
# 6   1889             joy     6
# 7   1889         sadness     1
# 8   1890           anger     0
# 9   1890            fear     0
# 10  1890             joy     4
# 11  1890         sadness     6
# 12  1891           anger     2
# 13  1891            fear     1
# 14  1891             joy     1
# 15  1891         sadness     5
# 16  1892           anger     2
# 17  1892            fear     3
# 18  1892             joy    19
# 19  1892         sadness    10
# 20  1893           anger     3
# 21  1893            fear     5
# 22  1893             joy    28
# 23  1893         sadness    15
# 24  1894           anger     0
# 25  1894            fear     0
# 26  1894             joy    20
# 27  1894         sadness    17
# 28  1895           anger     2
# 29  1895            fear     1
# 30  1895             joy    13
# 31  1895         sadness    15
# 32  1896           anger     2
# 33  1896            fear     0
# 34  1896             joy    32
# 35  1896         sadness    18
# 36  1897           anger     0
# 37  1897            fear     0
# 38  1897             joy    18
# 39  1897         sadness    21
# 40  1898           anger     2
# 41  1898            fear     2
# 42  1898             joy    27
# 43  1898         sadness     9
# 44  1899           anger     5
# 45  1899            fear     3
# 46  1899             joy    35
# 47  1899         sadness    19
# 48  1900           anger     3
# 49  1900            fear     3
# 50  1900             joy    37
# 51  1900         sadness    24
# 52  1901           anger     0
# 53  1901            fear     0
# 54  1901             joy     7
# 55  1901         sadness     4

# %%
def year_plot_emo(x,x2,x3,x4, names = None):
  barWidth = 0.20
  fig, ax = plt.subplots(figsize =(24, 9))

  joy = x 
  fear = x2
  sadness = x3
  anger = x4

  if names is None:
    names = []
    names.append('Joy')
    names.append('Fear')
    names.append('Sadness')
    names.append('Anger')
  else:
    names = names
  br1 = np.arange(len(joy))
  br2 = [x + barWidth for x in br1]
  br3 = [x + barWidth for x in br2]
  br4 = [x + barWidth for x in br3]

  plt.bar(br1, joy, color ='yellow', width = barWidth,
          edgecolor ='grey', label =names[0])
  plt.bar(br2, fear, color ='gray', width = barWidth,
          edgecolor ='grey', label =names[1])
  plt.bar(br3, sadness, color ='b', width = barWidth,
          edgecolor ='grey', label =names[2])
  plt.bar(br4, anger, color ='r', width = barWidth,
        edgecolor ='grey', label =names[3])

  
  # Adding Xticks
  plt.xlabel('Year', fontweight ='bold', fontsize = 15)
  plt.ylabel('Number of {}/{}/{}/{} letters'.format(names[0],names[1],names[2],names[3]), fontweight ='bold', fontsize = 15)
  plt.xticks([r + barWidth for r in range(len(pos))],
          letters_sent_year.year.unique())
  # Call the function above. All the magic happens there.
  add_value_labels(ax)
  plt.legend()
  plt.show()

# %%
x = letters_emo_year[letters_emo_year['emotion_sentita'] == 'joy']['text']
x2 = letters_emo_year[letters_emo_year['emotion_sentita'] == 'fear']['text']
x3 = letters_emo_year[letters_emo_year['emotion_sentita'] == 'sadness']['text']
x4 = letters_emo_year[letters_emo_year['emotion_sentita'] == 'anger']['text']
year_plot_emo(x,x2,x3,x4)

# %% [markdown]
# <hr>
#
#
#
# <br>
# <br>
#
# # Neural Networks Model Results
#
# <br>

# %%
pred_sent_grouped[pred_sent_grouped.index == 'positive']
# Out:
# pred
# positive    95
# dtype: int64

# %%
pred_sent_grouped =  letters_text_pred.groupby("pred").size()
pred_sent_grouped = pred_sent_grouped.sort_values(ascending=False)

# %%
pred_sent_grouped
# Out:
# pred
# negative    288
# positive     95
# neutral      70
# both          3
# dtype: int64

# %%
plot_freq(pred_sent_grouped.index, pred_sent_grouped.values)

# %%
pred_binary_sent_grouped = letters_text_pred.groupby("pred_binary").size()

# %%
plot_freq(pred_binary_sent_grouped.index, pred_binary_sent_grouped.values)

# %%
letters_sent_year_binary  = letters_text_pred.groupby(['year', 'pred_binary'],as_index = False).agg('text').count()

# %%
x = letters_sent_year_binary[letters_sent_year_binary['pred_binary'] == 'positive']['text']
x2 = letters_sent_year_binary[letters_sent_year_binary['pred_binary'] == 'negative']['text']
year_plot(x = x, x2 = x2)

# %%
letters_sent_pred  =  letters_text_pred.groupby(['year', 'pred'],as_index = True).count().unstack(fill_value=0).stack()['text'].reset_index()

# %%
letters_sent_pred
# Out:
#     year      pred  text
# 0   1888      both     1
# 1   1888  negative     3
# 2   1888   neutral     0
# 3   1888  positive     1
# 4   1889      both     0
# 5   1889  negative     3
# 6   1889   neutral     3
# 7   1889  positive     2
# 8   1890      both     0
# 9   1890  negative     4
# 10  1890   neutral     6
# 11  1890  positive     0
# 12  1891      both     0
# 13  1891  negative     4
# 14  1891   neutral     5
# 15  1891  positive     0
# 16  1892      both     0
# 17  1892  negative    18
# 18  1892   neutral     5
# 19  1892  positive    11
# 20  1893      both     0
# 21  1893  negative    30
# 22  1893   neutral     5
# 23  1893  positive    16
# 24  1894      both     0
# 25  1894  negative    27
# 26  1894   neutral     3
# 27  1894  positive     7
# 28  1895      both     0
# 29  1895  negative    21
# 30  1895   neutral     5
# 31  1895  positive     5
# 32  1896      both     0
# 33  1896  negative    41
# 34  1896   neutral     6
# 35  1896  positive     5
# 36  1897      both     0
# 37  1897  negative    27
# 38  1897   neutral     4
# 39  1897  positive     8
# 40  1898      both     1
# 41  1898  negative    21
# 42  1898   neutral     7
# 43  1898  positive    11
# 44  1899      both     0
# 45  1899  negative    43
# 46  1899   neutral     9
# 47  1899  positive    10
# 48  1900      both     1
# 49  1900  negative    40
# 50  1900   neutral    12
# 51  1900  positive    14
# 52  1901      both     0
# 53  1901  negative     6
# 54  1901   neutral     0
# 55  1901  positive     5

# %%
x = letters_sent_pred[letters_sent_pred['pred'] == 'positive']['text']
x2 = letters_sent_pred[letters_sent_pred['pred'] == 'negative']['text']
x3 = letters_sent_pred[letters_sent_pred['pred'] == 'neutral']['text']
x4 = letters_sent_pred[letters_sent_pred['pred'] == 'both']['text']
year_plot_emo(x,x2,x3,x4, names = ['positive',"negative","neutral","both"])

# %% [markdown]
# <hr>
#
#
#
# <br>
# <br>
#
# # Model comparison
#
# <br>

# %%
letters_text_pred
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...          sadness
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# ...                                                       ...  ...              ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [456 rows x 6 columns]

# %%
letters_text_pred[(letters_text_pred['pred_binary'] == "positive") & (letters_text_pred['sentiment_sentita'] == "positive")]
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000039  \nMaestro Puccini\nAlbergo Posta. Reggio Emili...  ...              joy
# CLET000055  \n31 luglio    9\nPrego Sig Maestro\nGiacomo P...  ...          sadness
# CLET000062  \n14 7bre  9\nCaris.o Puccini,\nUrgendoci aver...  ...              joy
# CLET000063  \n25 7mbre   89\nCariss.o Puccini.\nRicevo la ...  ...              joy
# ...                                                       ...  ...              ...
# CLET000768  \nPuccini.\nGrand Hôtel. Bruxelles.\nTito sarà...  ...              joy
# CLET000772  \nPuccini.\nTorrelago.\nBenissimo. Rievviva. S...  ...              joy
# CLET000776  \n21 gennaio 1901\nCaro Giacomo,\nRoma\nTi uni...  ...              joy
# CLET000779  \n10 Marzo      1\nCaro Puccini,\nRicevo la gr...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
#
# [124 rows x 6 columns]

# %%
letters_text_pred[letters_text_pred['pred_binary'] != letters_text_pred['sentiment_sentita']]
# Out:
#                                                          text  ...  emotion_sentita
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# CLET000053  \n18 Luglio     9\nCaris.o Puccini\nE l'indiri...  ...              joy
# CLET000086  \nMilano 23 Ott. 90\r\nCariss.mo Puccini.\r\nI...  ...              joy
# ...                                                       ...  ...              ...
# CLET000781  \nGiacomo Puccini.\nTorrelago\nContento lei co...  ...              joy
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [146 rows x 6 columns]

# %%
letters_text_pred
# Out:
#                                                          text  ...  emotion_sentita
# CLET000002  \nRicordi editore per Puccini\nNapoli\nnon dub...  ...              joy
# CLET000024  \nMilano 11 Agosto\nSig.r Maestro G. Pucini\nC...  ...          sadness
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# ...                                                       ...  ...              ...
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000784  \nMaestro Puccini\nTorre del Lago\nCome sa ten...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [456 rows x 6 columns]

# %%
notin = letters_text_pred[letters_text_pred['pred_binary'] != letters_text_pred['sentiment_sentita']]
notin
# Out:
#                                                          text  ...  emotion_sentita
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# CLET000053  \n18 Luglio     9\nCaris.o Puccini\nE l'indiri...  ...              joy
# CLET000086  \nMilano 23 Ott. 90\r\nCariss.mo Puccini.\r\nI...  ...              joy
# ...                                                       ...  ...              ...
# CLET000781  \nGiacomo Puccini.\nTorrelago\nContento lei co...  ...              joy
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [146 rows x 6 columns]

# %%
plt.bar(notin.year.unique(), notin.groupby("year").size() / letters_df.groupby("year").size()*100)
# Out:
# <BarContainer object of 14 artists>

# %%
grouped = letters_text_pred.groupby(["pred_binary","sentiment_sentita"]).count()["text"]

# %%
grouped = grouped.sort_values(ascending=False)
grouped
# Out:
# pred_binary  sentiment_sentita
# negative     negative             186
# positive     positive             124
# negative     positive              92
# positive     negative              54
# Name: text, dtype: int64

# %%
grouped.index = grouped.reset_index()["pred_binary"] +"_"+ grouped.reset_index()["sentiment_sentita"]

# %%
grouped
# Out:
# negative_negative    186
# positive_positive    124
# negative_positive     92
# positive_negative     54
# Name: text, dtype: int64

# %%
plot_freq(grouped.index,grouped.values, title="Number of different and same predicted sentiments")

# %%
grouped[grouped['sentiment_sentita'] == grouped['pred_binary']]
# Out:
#   pred_binary sentiment_sentita  text  year  pred  emotion_sentita
# 0    negative          negative   186   186   186              186
# 3    positive          positive   124   124   124              124

# %%
grouped[grouped['sentiment_sentita'] != grouped['pred_binary']]
# Out:
#   pred_binary sentiment_sentita  text  year  pred  emotion_sentita
# 1    negative          positive    92    92    92               92
# 2    positive          negative    54    54    54               54

# %%
pos = len(letters_text_pred[letters_text_pred['pred_binary'] == letters_text_pred['sentiment_sentita']])

# %%
neg = len(letters_text_pred[letters_text_pred['pred_binary'] != letters_text_pred['sentiment_sentita']]
# Out:
#                                                          text  ...  emotion_sentita
# CLET000026  \n11 Sett\n \nCarissimo M° Puccini\nAlbergo Pi...  ...              joy
# CLET000028  \n16 7bre    8\nPreg.° S.° Maestro G. Puccini,...  ...          sadness
# CLET000029  \n2 Novembre   8\nPreg° Sig Maestro\nGiacomo P...  ...              joy
# CLET000053  \n18 Luglio     9\nCaris.o Puccini\nE l'indiri...  ...              joy
# CLET000086  \nMilano 23 Ott. 90\r\nCariss.mo Puccini.\r\nI...  ...              joy
# ...                                                       ...  ...              ...
# CLET000781  \nGiacomo Puccini.\nTorrelago\nContento lei co...  ...              joy
# CLET000782  \nPuccini.\nTorrelago.\nCasa Palermo avvisami ...  ...          sadness
# CLET000783  \n18 Marzo 1901\nIllustre Maestro\nComm.e G. P...  ...              joy
# CLET000785  \nMaestro Puccini\nTeatro Massimo. Palermo\nSo...  ...              joy
# CLET000786  \nRicordi editore per Maestro Puccini.\nPalerm...  ...              joy
#
# [146 rows x 6 columns]

# %%
letters_df =  pd.read_pickle('https://github.com/Andreaierardi/sentiment-puccini/blob/main/dataset/puccini_with_predictions.pkl?raw=true')

# %%
letters_df
# Out:
#                     id  ... pred_binary
# CLET000002  CLET000002  ...    positive
# CLET000024  CLET000024  ...    negative
# CLET000026  CLET000026  ...    negative
# CLET000028  CLET000028  ...    negative
# CLET000029  CLET000029  ...    negative
# ...                ...  ...         ...
# CLET000782  CLET000782  ...    positive
# CLET000783  CLET000783  ...    positive
# CLET000784  CLET000784  ...    positive
# CLET000785  CLET000785  ...    positive
# CLET000786  CLET000786  ...    negative
#
# [456 rows x 24 columns]

# %%
#notequal = letters_df[letters_df['pred_binary'] != letters_df['sentiment_sentita']]

# %%
#list(notequal.iterrows())[100][1]['text']

#import random
#
#check = dict()
#for i in range(50):
#  index = random.randrange(0,len(list(notequal.iterrows())))
#  lett = list(notequal.iterrows())[index][1]['text']
#  id = list(notequal.iterrows())[index][1]['id']
#  print(lett)
#  sent = input()
#  check[id] = sent
#  print("========================== FINE ========================== \n")
  #random.randrange(len(list(notequal.iterrows())))

# %%
#for index, row in notequal.iterrows():
#    print(row['text'], row['pred'])
